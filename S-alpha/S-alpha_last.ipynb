# %%
# %run ~/Documents/PhD/j_model/Lissa.ipynb

sa_T     = []
sa_Tn    = []
sa_Z     = []
sa_T_avg = []
sa_Z_avg = []
sa_X_avg = []
sa_Σ     = []
sa_zf_nl = []
sa_zf    = []
sa_decay = []
# Out:
# loading successful!

# %%
#111111111111111111111111111111111111111#
#1 STee maker & file loader            1#
#1 for S-alpha geometry, q0=0.8, omt=6 1#
#111111111111111111111111111111111111111#

# Load data
filename = 'q0-0.8'

nkx0 = 384
nky0 = 64
Lx = 128.205
kxmin = 0.049
kymin = 0.05

Ts = 350    
Tm = 2160   
ps = 0.0027
pm = 0.0018

shat   = 0.78
trpeps = 0.10
R0     = 4.0
Lr     = 1.65
factor = 1

P = 0
norm = 'r'
omt = ([6, 10])

tzfnl_q8          = nonlinear(P, plotphi=False, plotq=True, plot=True)
#tzf_q8, dec_q8    = gamget(P, plot=True)
#T_q8, Tn_q8, Z_q8 = fluct(P, plot=True)
#Σ_q8              = grorat(P, plot=True)

# %%
norm = 'R'
tzfnl_q8          = nonlinear(P, plotphi=False, plotq=True, plot=True)

# %%
norm = 'T'
tzfnl_q8          = nonlinear(P, plotphi=False, plotq=True, plot=True)

# %%
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############
spectra_q8 = pylab.loadtxt('q0-0.8/ITGa_NL/omt6/timetrace/spectraions_act.dat')
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############

# %%
T_avg_q8, Z_avg_q8, chi_avg_q8, T_q8, Z_q8, chi_q8, time_q8 = timetrace(6, spectra_q8, P=0, plot=True, 
                                                                        crop=True, t0=1000)
