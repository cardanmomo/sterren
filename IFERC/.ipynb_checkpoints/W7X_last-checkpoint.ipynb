# %%
# %run ~/Documents/PhD/j_model/Lissa.ipynb

w7x_T     = []
w7x_Tn    = []
w7x_Z     = []
w7x_T_avg = []
w7x_Z_avg = []
w7x_X_avg = []
w7x_Σ     = []
w7x_zf_nl = []
w7x_zf    = []
w7x_decay = []

# %%
#######################################
# File loader and analiser
# For: High Iota Configuration s: 0.5
#######################################

filename = 'W7Xhiotas05'

nkx0    = 384
nky0    = 64 
Lx      = 665.979
kxmin   = 0.0094
kymin   = 0.05

a  = 0.4950306
R0  = 5.5120202
factor = ((1/a)/(1/R0))**2
factor = 1

omt = 1
P = 0
tzfnl_w7xhi5                     = nonlinear(P, plotphi=True, plotq=False, plot=False)
T_w7xhi5,    Tn_w7xhi5, Z_w7xhi5 = fluct(P, plot=False)
tzf_w7xhi5,  dec_w7xhi5          = gamget(P, plot=False)
Tl_w7xhi5                        = grorat(P, plot=False)

P = 1
tzfnl_w7xhi5P                       = nonlinear(P, plotphi=True, plotq=False, plot=False)
T_w7xhi5P,    Tn_w7xhi5P, Z_w7xhi5P = fluct(P, plot=False)
tzf_w7xhi5P,  dec_w7xhi5P           = gamget(P, plot=False)
Tl_w7xhi5P                          = grorat(P, plot=False)

# %%
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############
spectra1 = pylab.loadtxt('W7Xhiotas05/ITGa_NL/omt1/timetrace/spectraions_act.dat')
spectra2 = pylab.loadtxt('W7Xhiotas05/ITGa_NL/omt1_P/timetrace/spectraions_act.dat')
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############

# %%
T_avg_P, Z_avg_P, chi_avg_P, T_P, Z_P, chi_P, time_P = timetrace(omt, spectra2, P=1, plot=False,
                                                                 crop=True, t0=1400)
T_avg, Z_avg, chi_avg, T, Z, chi, time = timetrace(omt, spectra1, P=0, plot=False, 
                                                   crop=True, t0=1400, tf=time_P[-1])

# %%
## Now the most important: the graphics that compare ZF and turbulent oscillations against Xi es
plt.figure(figsize=(12, 5))
plt.plot(time, T, label='Te')
plt.plot(time, Z, label='Zet')
plt.plot(time, T/np.sqrt(Z), label='T / sqrt Z')
plt.plot(time_P, T_P, label='Te PEST')
plt.plot(time_P, Z_P, label='Zet PEST')
plt.plot(time_P, T_P/np.sqrt(Z_P), label='T / sqrt Z PEST')
plt.xlabel('time')
plt.ylabel('Magnitude (a.u.)')
plt.yscale('log')
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
plt.scatter(T, np.sqrt(Z), color='r')
plt.scatter(T_P, np.sqrt(Z_P), color='b')
plt.xlabel('T')
plt.ylabel('Z$^{1/2}$')
plt.legend(['omt:1', 'omt:1 PEST'])
plt.show()

plt.figure(figsize=(12, 5))
plt.scatter(T, chi, color='r')
plt.scatter(T_P, chi_P, color='b')
plt.xlabel('T')
plt.ylabel('$\\chi$')
plt.legend(['omt:1', 'omt:1 PEST'])
plt.show()

plt.figure(figsize=(12, 5))
plt.scatter(T/np.sqrt(Z), chi, color='r')
plt.scatter(T_P/np.sqrt(Z_P), chi_P, color='b')
plt.ylabel('$\\chi$')
plt.xlabel('T / Z$^{1/2}$')
plt.legend(['omt:1', 'omt:1 PEST'])
plt.show()

# %%
w7x_T.extend([T_w7xhi5, T_w7xhi5P])
w7x_Tn.extend([Tn_w7xhi5, Tn_w7xhi5P])
w7x_Z.extend([Z_w7xhi5, Z_w7xhi5P])
w7x_Σ.extend([Tl_w7xhi5, Tl_w7xhi5P])
w7x_zf_nl.extend([tzfnl_w7xhi5, tzfnl_w7xhi5P])
w7x_zf.extend([tzf_w7xhi5, tzf_w7xhi5P])
w7x_decay.extend([dec_w7xhi5, dec_w7xhi5P])

w7x_T_avg.extend([T_avg, T_avg_P])
w7x_Z_avg.extend([Z_avg, Z_avg_P])
w7x_chi_avg.extend([chi_avg, chi_avg_P])

print('W7X High Iota Configuration s05')
print('T total  : ', 'omt1: ', w7x_T[0], 'PEST: ', w7x_T[1])
print('T Nunami : ', 'omt1: ', w7x_Tn[0], 'PEST: ', w7x_Tn[1])
print('Z total  : ', 'omt1: ', w7x_Z[0], 'PEST: ', w7x_Z[1])
print('T avg    : ', 'omt1: ', w7x_T_avg[0], 'PEST: ', w7x_T_avg[1])
print('Z avg    : ', 'omt1: ', w7x_Z_avg[0], 'PEST: ', w7x_Z_avg[1])
print('Sum g/k^2: ', 'omt1: ', w7x_Σ[0], 'PEST: ', w7x_Σ[1])
print('Tau ZF NL: ', 'omt1: ', w7x_zf_nl[0], 'PEST: ', w7x_zf_nl[1])
print('Tau ZF   : ', 'omt1: ', w7x_zf[0], 'PEST: ', w7x_zf[1])
print('Decay    : ', 'omt1: ', w7x_decay[0], 'PEST: ', w7x_decay[1])

# %%
#######################################
# File loader and analiser
# For: High Mirror Configuration s: 0.36
#######################################

filename = 'W7Xhms036'

nkx0    = 100
nky0    = 64
Lx      = 530.418
kxmin   = 0.0118
kymin   = 0.05

a  = 0.5211343
R0  = 5.4832239
factor = ((1/a)/(1/R0))**2
factor = 1

omt = 1
P = 1
tzfnl_w7xhm36P                       = nonlinear(P, plotphi=True, plotq=False, plot=True)
T_w7xhm36P,    Tn_w7xhm36P, Z_w7xhm36P = fluct(P, plot=False)
tzf_w7xhm36P,  dec_w7xhm36P           = gamget(P, plot=False)
Tl_w7xhm36P                          = grorat(P, plot=False)

# %%
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############
spectra3 = pylab.loadtxt('W7Xhms036/ITGa_NL/omt1_P/timetrace/spectraions_act.dat')
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############

# %%
nkx0 = 200
T_avg, Z_avg, chi_avg, T, Z, chi, time = timetrace(omt, spectra3, P=1, plot=True, 
                                                   crop=True, t0=150)

# %%
######################################
# File loader and analiser
# For: Standard Configuration s: 0.6
######################################

filename = 'W7Xsds06'

nkx0 = 384
nky0 = 64 
Lx = 198.992
kxmin = 0.0315
kymin = 0.05

a = 0.5387892  # Minor radius W7X sd s06
R0 = 5.5079880  # Major radius W7X sd s06
factor = ((1/a)/(1/R0))**2
factor = 1

omt = ([1, 2, 3])
P = 0
tzfnl_w7xsd6                     = nonlinear(P, plotphi=False, plotq=True, plot=True)
T_w7xsd6,    Tn_w7xsd6, Z_w7xsd6 = fluct(P, plot=False)
tzf_w7xsd6,  dec_w7xsd6          = gamget(P, plot=False)
Tl_w7xsd6                        = grorat(P, plot=False)

# %%
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############
spectra4 = pylab.loadtxt('W7Xsds06/ITGa_NL/omt1/timetrace/spectraions_act.dat')
spectra5 = pylab.loadtxt('W7Xsds06/ITGa_NL/omt2/timetrace/spectraions_act.dat')
spectra6 = pylab.loadtxt('W7Xsds06/ITGa_NL/omt3/timetrace/spectraions_act.dat')
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############

# %%
T_avg1, Z_avg1, chi_avg1, T1, Z1, chi1, time1 = timetrace(1, spectra4, P=0, plot=True, 
                                                          crop=True, t0=50)
T_avg2, Z_avg2, chi_avg2, T2, Z2, chi2, time2 = timetrace(2, spectra5, P=0, plot=True,
                                                          crop=True, t0=50, tf=time1[-1])
T_avg3, Z_avg3, chi_avg3, T3, Z3, chi3, time3 = timetrace(3, spectra6, P=0, plot=True,
                                                          crop=True, t0=50, tf=time1[-1])

# %%
plt.figure(figsize=(12, 5))

plt.plot(time1, T1, label='T1')
plt.plot(time1, Z1, label='Z1')
plt.plot(time1, chi1, label='$\\chi_{es}$1')
plt.plot(time1, T1/np.sqrt(Z1), label='T1 / sqrt Z1')

plt.plot(time2, T2, label='T2')
plt.plot(time2, Z2, label='Z2')
plt.plot(time2, chi2, label='$\\chi_{es}$2')
plt.plot(time2, T2/np.sqrt(Z2), label='T2 / sqrt Z2')

plt.plot(time3, T3, label='T3')
plt.plot(time3, Z3, label='Z3')
plt.plot(time3, chi3, label='$\\chi_{es}$3')
plt.plot(time3, T3/np.sqrt(Z3), label='T3 / sqrt Z3')

plt.xlabel('time')
plt.ylabel('Magnitude (a.u.)')
plt.yscale('log')
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
plt.scatter(T1, np.sqrt(Z1), color='r')
plt.scatter(T2, np.sqrt(Z2), color='g')
plt.scatter(T3, np.sqrt(Z3), color='b')
plt.xlabel('T')
plt.ylabel('Z$^{1/2}$')
plt.legend(['1', '2', '3'])
plt.show()

plt.figure(figsize=(12, 5))
plt.scatter(T1, chi1, color='r')
plt.scatter(T2, chi2, color='g')
plt.scatter(T3, chi3, color='b')
plt.xlabel('T')
plt.ylabel('$\\chi$')
plt.legend(['1', '2', '3'])
plt.show()

plt.figure(figsize=(12, 5))
plt.scatter(T1/np.sqrt(Z1), chi1, color='r')
plt.scatter(T2/np.sqrt(Z2), chi2, color='g')
plt.scatter(T3/np.sqrt(Z3), chi3, color='b')
plt.ylabel('$\\chi$')
plt.xlabel('T / Z$^{1/2}$')
plt.legend(['1', '2', '3'])
plt.show()

# %%
w7x_T.extend([T_w7xsd6])
w7x_Tn.extend([Tn_w7xsd6])
w7x_Z.extend([Z_w7xsd6])
w7x_Σ.extend([Tl_w7xsd6])
w7x_zf_nl.extend([tzfnl_w7xsd6])
w7x_zf.extend([tzf_w7xsd6])
w7x_decay.extend([dec_w7xsd6])

w7x_T_avg.extend([T_avg])
w7x_Z_avg.extend([Z_avg])
w7x_chi_avg.extend([chi_avg])

print('W7X Standard Configuration s = 0.6')
print('T total  : ', 'omt1: ', w7x_T[2])
print('T Nunami : ', 'omt1: ', w7x_Tn[2])
print('Z total  : ', 'omt1: ', w7x_Z[2])
print('T avg    : ', 'omt1: ', w7x_T_avg[2])
print('Z avg    : ', 'omt1: ', w7x_Z_avg[2])
print('Sum g/k^2: ', 'omt1: ', w7x_Σ[2])
print('Tau ZF NL: ', 'omt1: ', w7x_zf_nl[2])
print('Tau ZF   : ', 'omt1: ', w7x_zf[2])
print('Decay    : ', 'omt1: ', w7x_decay[2])

# %%
#########################################
# File loader and analiser
# For: High Mirror Configuration s: 0.5
#########################################

filename = 'W7Xhms05'

nkx0 = 384
nky0 = 64 
Lx = 310.957
kxmin = 0.0202
kymin = 0.05

a = 0.5387892
Lr = 1.65
R0 = 5.5079880
factor = 1  # ((1/a)/(1/R0))**2

omt = ([1, 2, 3])
P = 1

tzfnl_w7xhm5                     = nonlinear(P, plotphi=False, plotq=True, plot=True)
T_w7xhm5,    Tn_w7xhm5, Z_w7xhm5 = fluct(P, plot=False)
tzf_w7xhm5,  dec_w7xhm5          = gamget(P, plot=False)
Tl_w7xhm5                        = grorat(P, plot=False)

# %%
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############
spectra7 = pylab.loadtxt('W7Xhms05/ITGa_NL/omt1_P/timetrace/spectraions_act.dat')
spectra8 = pylab.loadtxt('W7Xhms05/ITGa_NL/omt2_P/timetrace/spectraions_act.dat')
spectra9 = pylab.loadtxt('W7Xhms05/ITGa_NL/omt3_P/timetrace/spectraions_act.dat')
###############     CAREFUL: TAKES LONG TO LOAD     ###############
###############     CAREFUL: TAKES LONG TO LOAD     ###############

# %%
T_avg6, Z_avg6, chi_avg6, T6, Z6, chi6, time6 = timetrace(3, spectra9, 1, plot=False, 
                                                          crop=True, t0=50)
T_avg5, Z_avg5, chi_avg5, T5, Z5, chi5, time5 = timetrace(2, spectra8, 1, plot=False, 
                                                          crop=True, t0=50)  # , tf=time6[-1])
T_avg4, Z_avg4, chi_avg4, T4, Z4, chi4, time4 = timetrace(1, spectra7, 1, plot=False, 
                                                          crop=True, t0=50)  # , tf=time6[-1])

# %%
plt.figure(figsize=(12, 5))

"""
plt.plot(time1, T1, label='T1')
plt.plot(time1, Z1, label='Z1')
plt.plot(time1, chi1, label='$\\chi_{es}$1')
plt.plot(time1, T1/np.sqrt(Z1), label='T1 / sqrt Z1')

plt.plot(time2, T2, label='T2')
plt.plot(time2, Z2, label='Z2')
plt.plot(time2, chi2, label='$\\chi_{es}$2')
plt.plot(time2, T2/np.sqrt(Z2), label='T2 / sqrt Z2')

plt.plot(time3, T3, label='T3')
plt.plot(time3, Z3, label='Z3')
plt.plot(time3, chi3, label='$\\chi_{es}$3')
plt.plot(time3, T3/np.sqrt(Z3), label='T3 / sqrt Z3')
"""
plt.plot(time4, T4, label='T4')
plt.plot(time4, Z4, label='Z4')
plt.plot(time4, chi4, label='$\\chi_{es}$4')
plt.plot(time4, T4/np.sqrt(Z4), label='T4 / sqrt Z4')

plt.plot(time5, T5, label='T5')
plt.plot(time5, Z5, label='Z5')
plt.plot(time5, chi5, label='$\\chi_{es}$5')
plt.plot(time5, T5/np.sqrt(Z5), label='T5 / sqrt Z5')

plt.plot(time6, T6, label='T6')
plt.plot(time6, Z6, label='Z6')
plt.plot(time6, chi6, label='$\\chi_{es}$6')
plt.plot(time6, T6/np.sqrt(Z6), label='T6 / sqrt Z6')

plt.xlabel('time')
plt.ylabel('Magnitude (a.u.)')
plt.yscale('log')
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
#plt.scatter(T1, np.sqrt(Z1), color='r')
#plt.scatter(T2, np.sqrt(Z2), color='g')
#plt.scatter(T3, np.sqrt(Z3), color='b')
plt.scatter(T4, np.sqrt(Z4))
plt.scatter(T5, np.sqrt(Z5))
plt.scatter(T6, np.sqrt(Z6))
plt.xlabel('T')
plt.ylabel('Z$^{1/2}$')
plt.legend(['1', '2', '3', '4', '5', '6'])
plt.show()

plt.figure(figsize=(12, 5))
#plt.scatter(T1, chi1, color='r')
#plt.scatter(T2, chi2, color='g')
#plt.scatter(T3, chi3, color='b')
plt.scatter(T4, chi4)
plt.scatter(T5, chi5)
plt.scatter(T6, chi6)
plt.xlabel('T')
plt.ylabel('$\\chi$')
plt.legend(['1', '2', '3', '4', '5', '6'])
plt.show()

plt.figure(figsize=(12, 5))
#plt.scatter(T1/np.sqrt(Z1), chi1, color='r')
#plt.scatter(T2/np.sqrt(Z2), chi2, color='g')
#plt.scatter(T3/np.sqrt(Z3), chi3, color='b')
plt.scatter(T4/np.sqrt(Z4), chi4)
plt.scatter(T5/np.sqrt(Z5), chi5)
plt.scatter(T6/np.sqrt(Z6), chi6)
plt.ylabel('$\\chi$')
plt.xlabel('T / Z$^{1/2}$')
plt.legend(['1', '2', '3', '4', '5', '6'])
plt.show()

# %%
plt.figure(figsize=(12, 5))

"""
plt.plot(time1, T1, label='T1')
plt.plot(time1, Z1, label='Z1')
plt.plot(time1, chi1, label='$\\chi_{es}$1')
plt.plot(time1, T1/np.sqrt(Z1), label='T1 / sqrt Z1')

plt.plot(time2, T2, label='T2')
plt.plot(time2, Z2, label='Z2')
plt.plot(time2, chi2, label='$\\chi_{es}$2')
plt.plot(time2, T2/np.sqrt(Z2), label='T2 / sqrt Z2')

plt.plot(time3, T3, label='T3')
plt.plot(time3, Z3, label='Z3')
plt.plot(time3, chi3, label='$\\chi_{es}$3')
plt.plot(time3, T3/np.sqrt(Z3), label='T3 / sqrt Z3')
"""
plt.plot(time4, T4, label='T4')
plt.plot(time4, Z4, label='Z4')
plt.plot(time4, chi4, label='$\\chi_{es}$4')
plt.plot(time4, T4/np.sqrt(Z4), label='T4 / sqrt Z4')

plt.plot(time5, T5, label='T5')
plt.plot(time5, Z5, label='Z5')
plt.plot(time5, chi5, label='$\\chi_{es}$5')
plt.plot(time5, T5/np.sqrt(Z5), label='T5 / sqrt Z5')

plt.plot(time6, T6, label='T6')
plt.plot(time6, Z6, label='Z6')
plt.plot(time6, chi6, label='$\\chi_{es}$6')
plt.plot(time6, T6/np.sqrt(Z6), label='T6 / sqrt Z6')

plt.xlabel('time')
plt.ylabel('Magnitude (a.u.)')
plt.yscale('log')
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
#plt.scatter(T1, np.sqrt(Z1), color='r')
#plt.scatter(T2, np.sqrt(Z2), color='g')
#plt.scatter(T3, np.sqrt(Z3), color='b')
plt.scatter(T4, np.sqrt(Z4))
plt.scatter(T5, np.sqrt(Z5))
plt.scatter(T6, np.sqrt(Z6))
plt.xlabel('T')
plt.ylabel('Z$^{1/2}$')
plt.legend(['1', '2', '3', '4', '5', '6'])
plt.show()

plt.figure(figsize=(12, 5))
#plt.scatter(T1, chi1, color='r')
#plt.scatter(T2, chi2, color='g')
#plt.scatter(T3, chi3, color='b')
plt.scatter(T4, chi4)
plt.scatter(T5, chi5)
plt.scatter(T6, chi6)
plt.xlabel('T')
plt.ylabel('$\\chi$')
plt.legend(['1', '2', '3', '4', '5', '6'])
plt.show()

plt.figure(figsize=(12, 5))
#plt.scatter(T1/np.sqrt(Z1), chi1, color='r')
#plt.scatter(T2/np.sqrt(Z2), chi2, color='g')
#plt.scatter(T3/np.sqrt(Z3), chi3, color='b')
plt.scatter(T4/np.sqrt(Z4), chi4)
plt.scatter(T5/np.sqrt(Z5), chi5)
plt.scatter(T6/np.sqrt(Z6), chi6)
plt.ylabel('$\\chi$')
plt.xlabel('T / Z$^{1/2}$')
plt.legend(['1', '2', '3', '4', '5', '6'])
plt.show()

# %%
w7x_T.extend([T_w7xhm5])
w7x_Tn.extend([Tn_w7xhm5])
w7x_Z.extend([Z_w7xhm5])
w7x_Σ.extend([Tl_w7xhm5])
w7x_zf_nl.extend([tzfnl_w7xhm5])
w7x_zf.extend([tzf_w7xhm5])
w7x_decay.extend([dec_w7xhm5])

w7x_T_avg.extend([T_avg])
w7x_Z_avg.extend([Z_avg])
w7x_chi_avg.extend([chi_avg])

# %%
######################################
# File loader and analiser
# For: Standard Configuration s: 0.9
######################################

filename = 'W7Xsds09'

nkx0 = 96
nky0 = 96 
Lx = 59.952
kxmin = 0.1048
kymin = 0.05

a = 0.5387892  # Minor radius W7X sd s06
Lref = 1.65
R0 = 5.5079880  # Major radius W7X sd s06
factor = 1  # ((1/a)/(1/R0))**2
omt = ([1])
P = 0
tzfnl_w7xsd6                     = nonlinear(filename, omt, P, plotphi=True, plotq=True, plot=True)
T_w7xsd6,    Tn_w7xsd6, Z_w7xsd6 = fluct(filename, omt, nkx0, nky0, factor, kxmin, kymin, P, plot=True)
tzf_w7xsd6,  dec_w7xsd6          = gamget(filename, Lx, P, plot=True)
Tl_w7xsd6                        = grorat(filename, omt, P, plot=True)

# %%
spectrasds09 = pylab.loadtxt('{0}/ITGa_NL/omt{1}/timetrace/spectraions_act.dat'.format(filename, omt[0]))

# %%
T_avg1, Z_avg1, chi_avg, T1, Z1, chi1, time1 = timetrace('W7Xsds09', 1, spectrasds09, nkx0, nky0, kxmin, kymin, 
                                                         factor, P, plot=True, crop=True, t0=200)

# %%
w7x_T.extend([T_w7xsd6])
w7x_Tn.extend([Tn_w7xsd6])
w7x_Z.extend([Z_w7xsd6])
w7x_Σ.extend([Tl_w7xsd6])
w7x_zf_nl.extend([tzfnl_w7xsd6])
w7x_zf.extend([tzf_w7xsd6])
w7x_decay.extend([dec_w7xsd6])

w7x_T_avg.extend([T_avg])
w7x_Z_avg.extend([Z_avg])
w7x_chi_avg.extend([chi_avg])
