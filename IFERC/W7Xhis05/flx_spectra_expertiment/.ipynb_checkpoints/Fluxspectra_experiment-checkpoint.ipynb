# %%
# %run ~/Documents/PhD/j_model/Lissa.ipynb
# Out:
# loading successful!

# %%
fx_256_24 = [( pylab.loadtxt('fx_256_24.dat',usecols = (0, 2)))][0]
kx_256_24 = np.trapz(fx_256_24[:129, 1], fx_256_24[:129, 0])
ky_256_24 = np.trapz(fx_256_24[129:, 1], fx_256_24[129:, 0])

fx_192_24 = [( pylab.loadtxt('fx_192_24.dat',usecols = (0, 2)))][0]
kx_192_24 = np.trapz(fx_192_24[:97, 1], fx_192_24[:97, 0])
ky_192_24 = np.trapz(fx_192_24[97:, 1], fx_192_24[97:, 0])

fx_128_24 = [( pylab.loadtxt('fx_128_24.dat',usecols = (0, 2)))][0]
kx_128_24 = np.trapz(fx_128_24[:65, 1], fx_128_24[:65, 0])
ky_128_24 = np.trapz(fx_128_24[65:, 1], fx_128_24[65:, 0])

fx_96_24 = [( pylab.loadtxt('fx_96_24.dat',usecols = (0, 2)))][0]
kx_96_24 = np.trapz(fx_96_24[:49, 1], fx_96_24[:49, 0])
ky_96_24 = np.trapz(fx_96_24[49:, 1], fx_96_24[49:, 0])

fx_192_73 = [( pylab.loadtxt('fx_192_73.dat',usecols = (0, 2)))][0]
kx_192_73 = np.trapz(fx_192_73[:97, 1], fx_192_73[:97, 0])
ky_192_73 = np.trapz(fx_192_73[97:, 1], fx_192_73[97:, 0])

fx_128_73 = [( pylab.loadtxt('fx_128_73.dat',usecols = (0, 2)))][0]
kx_128_73 = np.trapz(fx_128_73[:65, 1], fx_128_73[:65, 0])
ky_128_73 = np.trapz(fx_128_73[65:, 1], fx_128_73[65:, 0])

fx_96_73 = [( pylab.loadtxt('fx_96_73.dat',usecols = (0, 2)))][0]
kx_96_73 = np.trapz(fx_96_73[:49, 1], fx_96_73[:49, 0])
ky_96_73 = np.trapz(fx_96_73[49:, 1], fx_96_73[49:, 0])

fx_128_153 = [( pylab.loadtxt('fx_128_153.dat',usecols = (0, 2)))][0]
kx_128_153 = np.trapz(fx_128_153[:65, 1], fx_128_153[:65, 0])
ky_128_153 = np.trapz(fx_128_153[65:, 1], fx_128_153[65:, 0])

fx_96_153 = [( pylab.loadtxt('fx_96_153.dat',usecols = (0, 2)))][0]
kx_96_153 = np.trapz(fx_96_153[:49, 1], fx_96_153[:49, 0])
ky_96_153 = np.trapz(fx_96_153[49:, 1], fx_96_153[49:, 0])

fx_96_258 = [( pylab.loadtxt('fx_96_258.dat',usecols = (0, 2)))][0]
kx_96_258 = np.trapz(fx_96_258[:49, 1], fx_96_258[:49, 0])
ky_96_258 = np.trapz(fx_96_258[49:, 1], fx_96_258[49:, 0])

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('24 time units, all', fontsize=20)
ax1 = fig.add_subplot(121)
ax1.plot(fx_256_24[:129, 0], fx_256_24[:129, 1], label='256')
ax1.plot(fx_192_24[:97, 0], fx_192_24[:97, 1], label='192', marker='o')
ax1.plot(fx_128_24[:65, 0], fx_128_24[:65, 1], label='128')
ax1.plot(fx_96_24[:49, 0], fx_96_24[:49, 1], label='96', marker='x')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.set_xlabel('$k_{x}$', fontsize=16)
ax1.set_ylabel('$Q_{es}$', fontsize=16)
ax1.legend()
ax2 = fig.add_subplot(122)
ax2.plot(fx_256_24[129:, 0], fx_256_24[129:, 1], label='256')
ax2.plot(fx_192_24[97:, 0], fx_192_24[97:, 1], label='192', marker='o')
ax2.plot(fx_128_24[65:, 0], fx_128_24[65:, 1], label='128')
ax2.plot(fx_96_24[49:, 0], fx_96_24[49:, 1], label='96', marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$k_{y}$', fontsize=16)
ax2.set_ylabel('$Q_{es}$', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('73 time units, all', fontsize=20)
ax1 = fig.add_subplot(121)
ax1.plot(fx_192_73[:97, 0], fx_192_73[:97, 1], label='192', marker='o')
ax1.plot(fx_128_73[:65, 0], fx_128_73[:65, 1], label='128')
ax1.plot(fx_96_73[:49, 0], fx_96_73[:49, 1], label='96', marker='x')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.set_xlabel('$k_{x}$', fontsize=16)
ax1.set_ylabel('$Q_{es}$', fontsize=16)
ax1.legend()
ax2 = fig.add_subplot(122)
ax2.plot(fx_192_73[97:, 0], fx_192_73[97:, 1], label='192', marker='o')
ax2.plot(fx_128_73[65:, 0], fx_128_73[65:, 1], label='128')
ax2.plot(fx_96_73[49:, 0], fx_96_73[49:, 1], label='96', marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$k_{y}$', fontsize=16)
ax2.set_ylabel('$Q_{es}$', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('153 time units, all', fontsize=20)
ax1 = fig.add_subplot(121)
ax1.plot(fx_128_153[:65, 0], fx_128_153[:65, 1], label='128')
ax1.plot(fx_96_153[:49, 0], fx_96_153[:49, 1], label='96', marker='x')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.set_xlabel('$k_{x}$', fontsize=16)
ax1.set_ylabel('$Q_{es}$', fontsize=16)
ax1.legend()
ax2 = fig.add_subplot(122)
ax2.plot(fx_128_153[65:, 0], fx_128_153[65:, 1], label='128')
ax2.plot(fx_96_153[49:, 0], fx_96_153[49:, 1], label='96', marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$k_{y}$', fontsize=16)
ax2.set_ylabel('$Q_{es}$', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('time evolution nkx0=96', fontsize=20)
ax1 = fig.add_subplot(121)
ax1.plot(fx_96_24[:49, 0], fx_96_24[:49, 1], label='24 time units', marker='x')
ax1.plot(fx_96_73[:49, 0], fx_96_73[:49, 1], label='73 time units', marker='x')
ax1.plot(fx_96_153[:49, 0], fx_96_153[:49, 1], label='153 time units', marker='x')
ax1.plot(fx_96_258[:49, 0], fx_96_258[:49, 1], label='258 time units', marker='x')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.set_xlabel('$k_{x}$', fontsize=16)
ax1.set_ylabel('$Q_{es}$', fontsize=16)
ax1.legend()
ax2 = fig.add_subplot(122)
ax2.plot(fx_96_24[49:, 0], fx_96_24[49:, 1], label='24 time units', marker='x')
ax2.plot(fx_96_73[49:, 0], fx_96_73[49:, 1], label='73 time units', marker='x')
ax2.plot(fx_96_153[49:, 0], fx_96_153[49:, 1], label='153 time units', marker='x')
ax2.plot(fx_96_258[49:, 0], fx_96_258[49:, 1], label='258 time units', marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$k_{y}$', fontsize=16)
ax2.set_ylabel('$Q_{es}$', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('time evolution nkx0=128', fontsize=20)
ax1 = fig.add_subplot(121)
plt.plot(fx_128_24[:65, 0], fx_128_24[:65, 1], label='24 time units', marker='x')
plt.plot(fx_128_73[:65, 0], fx_128_73[:65, 1], label='73 time units', marker='x')
plt.plot(fx_128_153[:65, 0], fx_128_153[:65, 1], label='153 time units', marker='x')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.set_xlabel('$k_{x}$', fontsize=16)
ax1.set_ylabel('$Q_{es}$', fontsize=16)
ax1.legend()
ax2 = fig.add_subplot(122)
plt.plot(fx_128_24[65:, 0], fx_128_24[65:, 1], label='24 time units', marker='x')
plt.plot(fx_128_73[65:, 0], fx_128_73[65:, 1], label='73 time units', marker='x')
plt.plot(fx_128_153[65:, 0], fx_128_153[65:, 1], label='153 time units', marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$k_{y}$', fontsize=16)
ax2.set_ylabel('$Q_{es}$', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('time evolution nkx0=192', fontsize=20)
ax1 = fig.add_subplot(121)
plt.plot(fx_192_24[:97, 0], fx_192_24[:97, 1], label='24 time units', marker='x')
plt.plot(fx_192_73[:97, 0], fx_192_73[:97, 1], label='73 time units', marker='x')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.set_xlabel('$k_{x}$', fontsize=16)
ax1.set_ylabel('$Q_{es}$', fontsize=16)
ax1.legend()
ax2 = fig.add_subplot(122)
plt.plot(fx_192_24[97:, 0], fx_192_24[97:, 1], label='24 time units', marker='x')
plt.plot(fx_192_73[97:, 0], fx_192_73[97:, 1], label='73 time units', marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('$k_{y}$', fontsize=16)
ax2.set_ylabel('$Q_{es}$', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(18, 7))
fig.suptitle('time evolution', fontsize=20)
ax1 = fig.add_subplot(121)
ax1.plot([kx_96_24, kx_96_73, kx_96_153, kx_96_258], [24, 73, 153, 258], label='nkx0=96', marker='X')
ax1.plot([kx_128_24, kx_128_73, kx_128_153], [24, 73, 153], label='nkx0=128', marker='X')
ax1.plot([kx_192_24, kx_192_73], [24, 73], label='nkx0=192', marker='X')
ax1.plot([kx_256_24], [24], label='nkx0=256', marker='X')
ax1.set_xlabel('Integ', fontsize=16)
ax1.set_ylabel('$k_{x}$', fontsize=16)
ax1.legend()


ax2 = fig.add_subplot(122)
ax2.plot([ky_96_24, ky_96_73, ky_96_153, ky_96_258], [24, 73, 153, 258], label='nkx0=96', marker='X')
ax2.plot([ky_128_24, ky_128_73, ky_128_153,], [24, 73, 153], label='nkx0=128', marker='X')
ax2.plot([ky_192_24, ky_192_73], [24, 73], label='nkx0=192', marker='X')
ax2.plot([ky_256_24],[24], label='nkx0=256', marker='X')
ax2.set_xlabel('Integ', fontsize=16)
ax2.set_ylabel('$k_{y}$', fontsize=16)
plt.show()
