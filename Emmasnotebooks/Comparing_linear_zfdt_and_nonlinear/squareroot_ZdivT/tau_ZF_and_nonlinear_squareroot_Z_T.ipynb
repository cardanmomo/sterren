# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])

# %%
nonlinear_squareroot_ZT = [(nonlinZ.values[0]/nonlinT.values[0])**(1/2),(nonlinZ.values[1]/nonlinT.values[1])**(1/2),
                           (nonlinZ.values[2]/nonlinT.values[2])**(1/2),(nonlinZ.values[3]/nonlinT.values[3])**(1/2),
                           (nonlinZ.values[4]/nonlinT.values[4])**(1/2),(nonlinZ.values[5]/nonlinT.values[5])**(1/2),
                           (nonlinZ.values[6]/nonlinT.values[6])**(1/2),(nonlinZ.values[7]/nonlinT.values[7])**(1/2),
                           (nonlinZ.values[8]/nonlinT.values[8])**(1/2),(nonlinZ.values[9]/nonlinT.values[9])**(1/2),
                           (nonlinZ.values[10]/nonlinT.values[10])**(1/2),(nonlinZ.values[11]/nonlinT.values[11])**(1/2),
                           (nonlinZ.values[12]/nonlinT.values[12])**(1/2),(nonlinZ.values[13]/nonlinT.values[13])**(1/2),
                           (nonlinZ.values[14]/nonlinT.values[14])**(1/2),(nonlinZ.values[15]/nonlinT.values[15])**(1/2),
                           (nonlinZ.values[16]/nonlinT.values[16])**(1/2),(nonlinZ.values[17]/nonlinT.values[17])**(1/2),
                           (nonlinZ.values[18]/nonlinT.values[18])**(1/2),(nonlinZ.values[19]/nonlinT.values[19])**(1/2),
                           (nonlinZ.values[20]/nonlinT.values[20])**(1/2),(nonlinZ.values[21]/nonlinT.values[21])**(1/2),
                           (nonlinZ.values[22]/nonlinT.values[22])**(1/2),(nonlinZ.values[23]/nonlinT.values[23])**(1/2),                       
                           (nonlinZ.values[24]/nonlinT.values[24])**(1/2),(nonlinZ.values[25]/nonlinT.values[25])**(1/2),
                           (nonlinZ.values[26]/nonlinT.values[26])**(1/2),(nonlinZ.values[27]/nonlinT.values[27])**(1/2),
                           (nonlinZ.values[28]/nonlinT.values[28])**(1/2)]
linear = [integ21,integ151,integ151,integ401,integ401,integ401,integ221,integ61,integ411,integ261,integ261,integ421,integ291,integ81,integ81,integ81,integ91,integ91,integ321,integ321,integ321,integ131,integ131,integ331,integ131,integ361,integ361,integ351,integ141]

# %%
import matplotlib.markers 
plt.scatter(linear[1],nonlinear_squareroot_ZT[1],color='magenta',label='hi, $s=0.5$, $L_x=110.997$, $\omega_{T i}=1.3$', marker='+',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[2],nonlinear_squareroot_ZT[2], color='magenta',label='hi, $s=0.5$, $L_x=110.997$, $\omega_{T i}=1.5$', marker='4',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[0],nonlinear_squareroot_ZT[0],color='purple',label='hi, $s=0.5$, $L_x=665.979$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

plt.scatter(linear[3],nonlinear_squareroot_ZT[3],color='darkred',label='hm, $s=0.5$, $L_x=310.957$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[4],nonlinear_squareroot_ZT[4], color='darkred',label='hm, $s=0.5$, $L_x=310.957$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[5],nonlinear_squareroot_ZT[5], color='darkred',label='hm, $s=0.5$, $L_x=310.957$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[6],nonlinear_squareroot_ZT[6],color='red',label='hm, $s=0.8$, $L_x=78.832$, $\omega_{T i}=2.3$', marker='x',s=400, cmap=None, alpha=1, linewidth=4, edgecolors=None)

plt.scatter(linear[7],nonlinear_squareroot_ZT[7],color='green',label='li, $s=0.5$, $L_x=340.925$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[8],nonlinear_squareroot_ZT[8], color='lightgreen',label='li, $s=0.5$, $L_x=681.850$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[10],nonlinear_squareroot_ZT[10], color='lime',label='li, $s=0.8$, $L_x=90.837$, $\omega_{T i}=1.5$', marker='4',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

plt.scatter(linear[12],nonlinear_squareroot_ZT[12],color='orange',label='lm, $s=0.5$, $L_x=136.837$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[11],nonlinear_squareroot_ZT[11],color='navajowhite',label='lm, $s=0.5$, $L_x=684.184$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

plt.scatter(linear[13],nonlinear_squareroot_ZT[13],color='blue',label='sd, $s=0.25$, $L_x=774.957$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[14],nonlinear_squareroot_ZT[14], color='blue',label='sd, $s=0.25$, $L_x=774.957$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[15],nonlinear_squareroot_ZT[15], color='blue',label='sd, $s=0.25$, $L_x=774.957$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[16],nonlinear_squareroot_ZT[16],color='grey',label='sd, $s=0.36$, $L_x=436.870$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[17],nonlinear_squareroot_ZT[17], color='grey',label='sd, $s=0.36$, $L_x=436.870$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[20],nonlinear_squareroot_ZT[20], color='cyan',label='sd, $s=0.5$, $L_x=260.633$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[23],nonlinear_squareroot_ZT[23],color='navy',label='sd, $s=0.6$, $L_x=138.185$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[21],nonlinear_squareroot_ZT[21],color='darkcyan',label='sd, $s=0.6$, $L_x=198.992$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[22],nonlinear_squareroot_ZT[22], color='darkcyan',label='sd, $s=0.6$, $L_x=198.992$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[24],nonlinear_squareroot_ZT[24], color='darkcyan',label='sd, $s=0.6$, $L_x=198.992$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[25],nonlinear_squareroot_ZT[25],color='dodgerblue',label='sd, $s=0.8$, $L_x=68.805$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[26],nonlinear_squareroot_ZT[26], color='dodgerblue',label='sd, $s=0.8$, $L_x=68.805$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[27],nonlinear_squareroot_ZT[27],color='aquamarine',label='sd, $s=0.8$, $L_x=137.610$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[28],nonlinear_squareroot_ZT[28],color='skyblue',label='sd, $s=0.9$, $L_x=59.952$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
#plt.xlabel(r'$\tau_{ZF}$',fontsize=20)
##plt.yticks(fontsize=20)
#plt.xticks(fontsize=20)
#plt.grid
#plt.ylabel(r'$\sqrt{\mathcal{Z} /\mathcal{T}}$',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4),fancybox=False, shadow=False, ncol=4,borderpad=1,labelspacing=1,fontsize=20)
#plt.tight_layout(rect=[0,0,3,2])
#plt.ylim([0,4])
#plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[2],nonlinear_squareroot_ZT[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[0],nonlinear_squareroot_ZT[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],nonlinear_squareroot_ZT[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z/T)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,4])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[10],nonlinear_squareroot_ZT[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],nonlinear_squareroot_ZT[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],nonlinear_squareroot_ZT[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z/T)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,4])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[14],nonlinear_squareroot_ZT[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],nonlinear_squareroot_ZT[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],nonlinear_squareroot_ZT[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[26],nonlinear_squareroot_ZT[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],nonlinear_squareroot_ZT[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],nonlinear_squareroot_ZT[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],nonlinear_squareroot_ZT[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],nonlinear_squareroot_ZT[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[25],nonlinear_squareroot_ZT[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[27],nonlinear_squareroot_ZT[27],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[28],nonlinear_squareroot_ZT[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[15],nonlinear_squareroot_ZT[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],nonlinear_squareroot_ZT[20], color='cyan',label='W7Xsds05 260.633', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[24],nonlinear_squareroot_ZT[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z/T)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,4])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[4],nonlinear_squareroot_ZT[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[6],nonlinear_squareroot_ZT[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[3],nonlinear_squareroot_ZT[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],nonlinear_squareroot_ZT[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z/T)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,4])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[12],nonlinear_squareroot_ZT[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],nonlinear_squareroot_ZT[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z/T)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,4])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)
