# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])
linear = [integ21,integ151,integ151,integ401,integ401,integ401,integ221,integ61,integ411,integ261,integ261,integ421,integ291,integ81,integ81,integ81,integ91,integ91,integ321,integ321,integ321,integ131,integ131,integ331,integ131,integ361,integ361,integ351,integ141]

nonlinear_squarerootZ_T = [((nonlinZ.values[0])**(1/2))/nonlinT.values[0],((nonlinZ.values[1])**(1/2))/nonlinT.values[1],
                           ((nonlinZ.values[2])**(1/2))/nonlinT.values[2],((nonlinZ.values[3])**(1/2))/nonlinT.values[3],
                           ((nonlinZ.values[4])**(1/2))/nonlinT.values[4],((nonlinZ.values[5])**(1/2))/nonlinT.values[5],
                           ((nonlinZ.values[6])**(1/2))/nonlinT.values[6],((nonlinZ.values[7])**(1/2))/nonlinT.values[7],
                           ((nonlinZ.values[8])**(1/2))/nonlinT.values[8],((nonlinZ.values[9])**(1/2))/nonlinT.values[9],
                           ((nonlinZ.values[10])**(1/2))/nonlinT.values[10],((nonlinZ.values[11])**(1/2))/nonlinT.values[11],
                           ((nonlinZ.values[12])**(1/2))/nonlinT.values[12],((nonlinZ.values[13])**(1/2))/nonlinT.values[13],
                           ((nonlinZ.values[14])**(1/2))/nonlinT.values[14],((nonlinZ.values[15])**(1/2))/nonlinT.values[15],
                           ((nonlinZ.values[16])**(1/2))/nonlinT.values[16],((nonlinZ.values[17])**(1/2))/nonlinT.values[17],
                           ((nonlinZ.values[18])**(1/2))/nonlinT.values[18],((nonlinZ.values[19])**(1/2))/nonlinT.values[19],
                           ((nonlinZ.values[20])**(1/2))/nonlinT.values[20],((nonlinZ.values[21])**(1/2))/nonlinT.values[21],
                           ((nonlinZ.values[22])**(1/2))/nonlinT.values[22],((nonlinZ.values[23])**(1/2))/nonlinT.values[23],
                           ((nonlinZ.values[24])**(1/2))/nonlinT.values[24],((nonlinZ.values[25])**(1/2))/nonlinT.values[25],
                           ((nonlinZ.values[26])**(1/2))/nonlinT.values[26],((nonlinZ.values[27])**(1/2))/nonlinT.values[27],
                           ((nonlinZ.values[28])**(1/2))/nonlinT.values[28]]

# %%
import matplotlib.markers
#plt.scatter(linear[2],nonlinear_squarerootZ_T[2], color='magenta',label='hi, $s=0.5$, $110.997$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[10],nonlinear_squarerootZ_T[10], color='lime',label='li, $s=0.8$, $90.837$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[14],nonlinear_squarerootZ_T[14], color='blue',label='sd, $s=0.25$, $774.957$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[17],nonlinear_squarerootZ_T[17], color='grey',label='sd, $s=0.36$, $436.870$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[22],nonlinear_squarerootZ_T[22], color='darkcyan',label='sd, $s=0.6$, $198.992$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[26],nonlinear_squarerootZ_T[26], color='dodgerblue',label='sd, $s=0.8$, $68.805$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[4],nonlinear_squarerootZ_T[4], color='darkred',label='hm, $s=0.5$, $310.957$', marker='2',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

plt.scatter(linear[0],nonlinear_squarerootZ_T[0],color='purple',label='hi, $s=0.5$, $665.979$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[1],nonlinear_squarerootZ_T[1],color='magenta',label='hi, $s=0.5$, $110.997$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[6],nonlinear_squarerootZ_T[6],color='red',label='hm, $s=0.8$, $78.832$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[7],nonlinear_squarerootZ_T[7],color='green',label='li, $s=0.5$, $340.925$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[12],nonlinear_squarerootZ_T[12],color='orange',label='lm, $s=0.5$, $136.837$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[13],nonlinear_squarerootZ_T[13],color='blue',label='sd, $s=0.25$, $774.957$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[16],nonlinear_squarerootZ_T[16],color='grey',label='sd, $s=0.36$, $436.87$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[21],nonlinear_squarerootZ_T[21],color='darkcyan',label='sd, $s=0.6$, $198.992$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[23],nonlinear_squarerootZ_T[23],color='navy',label='sd, $s=0.6$, $138.185$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[25],nonlinear_squarerootZ_T[25],color='dodgerblue',label='sd, $s=0.8$, $68.805$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[27],nonlinear_squarerootZ_T[27],color='aquamarine',label='sd, $s=0.8$, $137.610$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[28],nonlinear_squarerootZ_T[28],color='skyblue',label='sd, $s=0.9$, $59.952$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[3],nonlinear_squarerootZ_T[3],color='darkred',label='hm, $s=0.5$, $310.957$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[8],nonlinear_squarerootZ_T[8],color='lightgreen',label='li, $s=0.5$, $681.850$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[11],nonlinear_squarerootZ_T[11],color='navajowhite',label='lm, $s=0.5$, $684.184$', marker='1',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

#plt.scatter(linear[15],nonlinear_squarerootZ_T[15], color='blue',label='sd, $s=0.25$, $774.957$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
plt.scatter(linear[20],nonlinear_squarerootZ_T[20], color='cyan',label='sd, $s=0.5$, $260.633$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[24],nonlinear_squarerootZ_T[24], color='darkcyan',label='sd, $s=0.6$, $198.992$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)
#plt.scatter(linear[5],nonlinear_squarerootZ_T[5], color='darkred',label='hm, $s=0.5$, $310.957$', marker='3',s=700, cmap=None, alpha=1, linewidth=4, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel(r'$\tau_{ZF}$',fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.ylabel(r'$\sqrt{\mathcal{Z}} /\mathcal{T}$',fontsize=30)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3),fancybox=False, shadow=False, ncol=4,borderpad=0.7,labelspacing=0.8,fontsize=16)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([2,6])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-725e2b45c5a4> in <module>
#      35 plt.ylabel(r'$\sqrt{\mathcal{Z} /\mathcal{T}}$',fontsize=30)
#      36 plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3),fancybox=False, shadow=False, ncol=4,borderpad=0.7,labelspacing=0.8,fontsize=16)
# ---> 37 plt.tight_layout(rect=[0, 0, 3, 2])
#      38 plt.ylim([2,6])
#      39 plt.xlim([0,225])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1380         labels) will fit into. Default is (0, 0, 1, 1).
#    1381     """
# -> 1382     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1383
#    1384
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
# ...

# %%
plt.scatter(linear[2],nonlinear_squarerootZ_T[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[0],nonlinear_squarerootZ_T[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],nonlinear_squarerootZ_T[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z)/T',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-5,35])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[10],nonlinear_squarerootZ_T[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],nonlinear_squarerootZ_T[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],nonlinear_squarerootZ_T[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z)/T',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-5,35])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[14],nonlinear_squarerootZ_T[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],nonlinear_squarerootZ_T[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],nonlinear_squarerootZ_T[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[26],nonlinear_squarerootZ_T[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],nonlinear_squarerootZ_T[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],nonlinear_squarerootZ_T[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],nonlinear_squarerootZ_T[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],nonlinear_squarerootZ_T[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[25],nonlinear_squarerootZ_T[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[27],nonlinear_squarerootZ_T[27],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[28],nonlinear_squarerootZ_T[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[15],nonlinear_squarerootZ_T[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],nonlinear_squarerootZ_T[20], color='cyan',label='W7Xsds05 260.633', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[24],nonlinear_squarerootZ_T[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z)/T',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-5,35])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[4],nonlinear_squarerootZ_T[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[6],nonlinear_squarerootZ_T[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[3],nonlinear_squarerootZ_T[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],nonlinear_squarerootZ_T[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z)/T',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-5,35])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[12],nonlinear_squarerootZ_T[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],nonlinear_squarerootZ_T[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(Z)/T',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-5,35])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
import matplotlib.markers
plt.scatter(linear[2],nonlinear_squarerootZ_T[2], color='green',label='W7Xhis05 110.997 omt=1.5', marker='2',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[10],nonlinear_squarerootZ_T[10], color='green',label='W7Xlis08 90.837 omt=1.5', marker='3',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[14],nonlinear_squarerootZ_T[14], color='grey',label='W7Xsds025 774.957 omt=2', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],nonlinear_squarerootZ_T[17], color='darkgrey',label='W7Xsds036 436.87 omt=3', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],nonlinear_squarerootZ_T[22], color='grey',label='W7Xsds06 198.992 omt=2', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[26],nonlinear_squarerootZ_T[26], color='grey',label='W7Xsds08 68.805 omt=2', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[4],nonlinear_squarerootZ_T[4], color='grey',label='W7Xhms05 310.957 omt=2', marker='4',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(linear[0],nonlinear_squarerootZ_T[0],color='red',label='W7Xhis05 665.979 omt=1', marker='2',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],nonlinear_squarerootZ_T[1],color='magenta',label='W7Xhis05 110.997 omt=1.3', marker='2',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[6],nonlinear_squarerootZ_T[6],color='orange',label='W7Xhms08 78.832 omt=2.3', marker='4',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],nonlinear_squarerootZ_T[7],color='red',label='W7Xlis05 340.925 omt=1', marker='3',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[12],nonlinear_squarerootZ_T[12],color='grey',label='W7Xlms05 136.837 omt=2', marker='x',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],nonlinear_squarerootZ_T[13],color='red',label='W7Xsds025 774.957 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],nonlinear_squarerootZ_T[16],color='red',label='W7Xsds036 436.87 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],nonlinear_squarerootZ_T[21],color='red',label='W7Xsds06 198.992 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],nonlinear_squarerootZ_T[23],color='grey',label='W7Xsds06 138.185 omt=2', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[25],nonlinear_squarerootZ_T[25],color='red',label='W7Xsds08 68.805 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[27],nonlinear_squarerootZ_T[27],color='red',label='W7Xsds08 137.61 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[28],nonlinear_squarerootZ_T[28],color='red',label='W7Xsds09 59.952 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[3],nonlinear_squarerootZ_T[3],color='red',label='W7Xhms05 310.957 omt=1', marker='4',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],nonlinear_squarerootZ_T[8],color='red',label='W7Xlis05 681.85 omt=1', marker='3',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],nonlinear_squarerootZ_T[11],color='red',label='W7Xlms05 684.184 omt=1', marker='x',s=200, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(linear[15],nonlinear_squarerootZ_T[15], color='darkgrey',label='W7Xsds025 774.957 omt=3', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],nonlinear_squarerootZ_T[20], color='red',label='W7Xsds05 260.633 omt=1', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[24],nonlinear_squarerootZ_T[24], color='darkgrey',label='W7Xsds06 198.992 omt=3', marker='1',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],nonlinear_squarerootZ_T[5], color='darkgrey',label='W7Xhms05 310.957 omt=3', marker='4',s=600, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('sqrt(Z)/T',fontsize=20)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=4)
plt.tight_layout(rect=[0, 0, 4, 3])
plt.ylim([-2,35])
plt.xlim([0,200])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)
