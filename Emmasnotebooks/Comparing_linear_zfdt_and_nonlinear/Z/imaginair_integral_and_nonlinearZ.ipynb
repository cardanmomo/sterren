# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])

linear_imaginair = [integ23,integ153,integ153,integ403,integ403,integ403,integ223,integ63,integ413,integ263,integ263,integ423,integ293,integ83,integ83,integ83,integ93,integ93,integ323,integ323,integ323,integ133,integ133,integ333,integ133,integ363,integ363,integ353,integ143]

# %%
import matplotlib.markers
plt.scatter(linear_imaginair[2],nonlinZ.values[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[10],nonlinZ.values[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[14],nonlinZ.values[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[17],nonlinZ.values[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[22],nonlinZ.values[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[26],nonlinZ.values[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[4],nonlinZ.values[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(linear_imaginair[0],nonlinZ.values[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[1],nonlinZ.values[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[6],nonlinZ.values[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[7],nonlinZ.values[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[12],nonlinZ.values[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[13],nonlinZ.values[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[16],nonlinZ.values[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[21],nonlinZ.values[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[23],nonlinZ.values[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[25],nonlinZ.values[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[27],nonlinZ.values[27],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[28],nonlinZ.values[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[3],nonlinZ.values[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[8],nonlinZ.values[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[11],nonlinZ.values[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(linear_imaginair[15],nonlinZ.values[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[20],nonlinZ.values[20], color='cyan',label='W7Xsds05 260.633', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[24],nonlinZ.values[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[5],nonlinZ.values[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over imaginary part of linear $\phi$',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Z',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
#plt.ylim([-2,20])
#plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
###### not adjusted to new data

plt.scatter(linear_imaginair[2],nonlinearZ[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[0],nonlinearZ[0],color='purple',label='W7Xhis05 665.979', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[1],nonlinearZ[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over imaginary part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-100,125])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
###### not adjusted to new data

plt.scatter(linear_imaginair[6],nonlinearZ[6], color='lime',label='W7Xlis08 90.837', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[4],nonlinearZ[4],color='green',label='W7Xlis05 340.925', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[5],nonlinearZ[5],color='lime',label='W7Xlis08 90.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over imaginary part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-100,125])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
###### not adjusted to new data!
plt.scatter(linear_imaginair[9],nonlinearZ[9], color='blue',label='W7Xsds025 774.957', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[12],nonlinearZ[12], color='grey',label='W7Xsds036 436.87', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[14],nonlinearZ[14], color='cyan',label='W7Xsds05 260.633', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[17],nonlinearZ[17], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[21],nonlinearZ[21], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[8],nonlinearZ[8],color='blue',label='W7Xsds025 774.957', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[11],nonlinearZ[11],color='grey',label='W7Xsds036 436.87', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[13],nonlinearZ[13],color='cyan',label='W7Xsds05 260.633', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[16],nonlinearZ[16],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[18],nonlinearZ[18],color='navy',label='W7Xsds06 138.185', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[20],nonlinearZ[20],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[22],nonlinearZ[22],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[23],nonlinearZ[23],color='skyblue',label='W7Xsds09 59.952', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[10],nonlinearZ[10], color='blue',label='W7Xsds025 774.957', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[15],nonlinearZ[15], color='cyan',label='W7Xsds05 260.633', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[19],nonlinearZ[19], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over imaginary part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-100,125])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
###### not adjusted to new data!
plt.scatter(linear_imaginair[3],nonlinearZ[3],color='red',label='W7Xhms08 78.832', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_imaginair[7],nonlinearZ[7],color='orange',label='W7Xlms05 136.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over imaginary part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-100,125])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!
