# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])

T_div_squareroot_Z = [nonlinT.values[0]/((nonlinZ.values[0])**(1/2)),nonlinT.values[1]/((nonlinZ.values[1])**(1/2)),
                      nonlinT.values[2]/((nonlinZ.values[2])**(1/2)),nonlinT.values[3]/((nonlinZ.values[3])**(1/2)),
                      nonlinT.values[4]/((nonlinZ.values[4])**(1/2)),nonlinT.values[5]/((nonlinZ.values[5])**(1/2)),
                      nonlinT.values[6]/((nonlinZ.values[6])**(1/2)),nonlinT.values[7]/((nonlinZ.values[7])**(1/2)),
                      nonlinT.values[8]/((nonlinZ.values[8])**(1/2)),nonlinT.values[9]/((nonlinZ.values[9])**(1/2)),
                      nonlinT.values[10]/((nonlinZ.values[10])**(1/2)),nonlinT.values[11]/((nonlinZ.values[11])**(1/2)),
                      nonlinT.values[12]/((nonlinZ.values[12])**(1/2)),nonlinT.values[13]/((nonlinZ.values[13])**(1/2)),
                      nonlinT.values[14]/((nonlinZ.values[14])**(1/2)),nonlinT.values[15]/((nonlinZ.values[15])**(1/2)),
                      nonlinT.values[16]/((nonlinZ.values[16])**(1/2)),nonlinT.values[17]/((nonlinZ.values[17])**(1/2)),
                      nonlinT.values[18]/((nonlinZ.values[18])**(1/2)),nonlinT.values[19]/((nonlinZ.values[19])**(1/2)),
                      nonlinT.values[20]/((nonlinZ.values[20])**(1/2)),nonlinT.values[21]/((nonlinZ.values[21])**(1/2)),
                      nonlinT.values[22]/((nonlinZ.values[22])**(1/2)),nonlinT.values[23]/((nonlinZ.values[23])**(1/2)),
                      nonlinT.values[24]/((nonlinZ.values[24])**(1/2)),nonlinT.values[25]/((nonlinZ.values[25])**(1/2)),
                      nonlinT.values[26]/((nonlinZ.values[26])**(1/2)),nonlinT.values[27]/((nonlinZ.values[27])**(1/2)),
                      nonlinT.values[28]/((nonlinZ.values[28])**(1/2))]
linear = [integ21,integ151,integ151,integ401,integ401,integ401,integ221,integ61,integ411,integ261,integ261,integ421,integ291,integ81,integ81,integ81,integ91,integ91,integ321,integ321,integ321,integ131,integ131,integ331,integ131,integ361,integ361,integ351,integ141]

# %%
import matplotlib.markers
############## blocked all with omt =/= 1

#plt.scatter(linear[2],T_div_squareroot_Z[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[10],T_div_squareroot_Z[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[14],T_div_squareroot_Z[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[17],T_div_squareroot_Z[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[22],T_div_squareroot_Z[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[26],T_div_squareroot_Z[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[4],T_div_squareroot_Z[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)

plt.scatter(linear[0],T_div_squareroot_Z[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[1],T_div_squareroot_Z[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[6],T_div_squareroot_Z[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[7],T_div_squareroot_Z[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[12],T_div_squareroot_Z[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[13],T_div_squareroot_Z[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[16],T_div_squareroot_Z[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[21],T_div_squareroot_Z[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[23],T_div_squareroot_Z[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[25],T_div_squareroot_Z[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[27],T_div_squareroot_Z[27],color='aquamarine',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[28],T_div_squareroot_Z[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[3],T_div_squareroot_Z[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[8],T_div_squareroot_Z[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[11],T_div_squareroot_Z[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)

#markerstyle changed
#plt.scatter(linear[15],T_div_squareroot_Z[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear[20],T_div_squareroot_Z[20], color='cyan',label='W7Xsds05 260.633', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[24],T_div_squareroot_Z[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear[5],T_div_squareroot_Z[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel(r'$\tau_{ZF}$',fontsize=20)
plt.yticks([0,0.2,0.4,0.6],fontsize=20)
plt.xticks(fontsize=20)
plt.grid()
plt.ylabel(r'$\frac{\mathcal{T}}{\sqrt{\mathcal{Z}}}$',fontsize=30)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4),fancybox=False, shadow=False, ncol=4,borderpad=1.5,labelspacing=1.5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,0.6])
plt.xlim([0,225])
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/zfdt_vs_T_sqrtZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()

# %%
plt.scatter(linear[2],T_div_squareroot_Z[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[0],T_div_squareroot_Z[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],T_div_squareroot_Z[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('T/sqrt(Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-0.5,3])
plt.xlim([0,225])
plt.show()

# %%
plt.scatter(linear[10],T_div_squareroot_Z[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],T_div_squareroot_Z[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],T_div_squareroot_Z[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('T/sqrt(Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-0.5,3])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[14],T_div_squareroot_Z[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],T_div_squareroot_Z[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],T_div_squareroot_Z[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[26],T_div_squareroot_Z[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],T_div_squareroot_Z[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],T_div_squareroot_Z[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],T_div_squareroot_Z[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],T_div_squareroot_Z[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[25],T_div_squareroot_Z[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[27],T_div_squareroot_Z[27],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[28],T_div_squareroot_Z[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[15],T_div_squareroot_Z[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],T_div_squareroot_Z[20], color='cyan',label='W7Xsds05 260.633', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[24],T_div_squareroot_Z[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('T/sqrt(Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-0.5,3])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[4],T_div_squareroot_Z[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[6],T_div_squareroot_Z[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[3],T_div_squareroot_Z[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],T_div_squareroot_Z[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('T/sqrt(Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-0.5,3])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear[12],T_div_squareroot_Z[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],T_div_squareroot_Z[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('T/sqrt(Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([-0.5,3])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)
