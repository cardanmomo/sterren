# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])

squareroot_TdivZ = [(nonlinT.values[0]/nonlinZ.values[0])**(1/2),(nonlinT.values[1]/nonlinZ.values[1])**(1/2),
                           (nonlinT.values[2]/nonlinZ.values[2])**(1/2),(nonlinT.values[3]/nonlinZ.values[3])**(1/2),
                           (nonlinT.values[4]/nonlinZ.values[4])**(1/2),(nonlinT.values[5]/nonlinZ.values[5])**(1/2),
                           (nonlinT.values[6]/nonlinZ.values[6])**(1/2),(nonlinT.values[7]/nonlinZ.values[7])**(1/2),
                           (nonlinT.values[8]/nonlinZ.values[8])**(1/2),(nonlinT.values[9]/nonlinZ.values[9])**(1/2),
                           (nonlinT.values[10]/nonlinZ.values[10])**(1/2),(nonlinT.values[11]/nonlinZ.values[11])**(1/2),
                           (nonlinT.values[12]/nonlinZ.values[12])**(1/2),(nonlinT.values[13]/nonlinZ.values[13])**(1/2),
                           (nonlinT.values[14]/nonlinZ.values[14])**(1/2),(nonlinT.values[15]/nonlinZ.values[15])**(1/2),
                           (nonlinT.values[16]/nonlinZ.values[16])**(1/2),(nonlinT.values[17]/nonlinZ.values[17])**(1/2),
                           (nonlinT.values[18]/nonlinZ.values[18])**(1/2),(nonlinT.values[19]/nonlinZ.values[19])**(1/2),
                           (nonlinT.values[20]/nonlinZ.values[20])**(1/2),(nonlinT.values[21]/nonlinZ.values[21])**(1/2),
                           (nonlinT.values[22]/nonlinZ.values[22])**(1/2),(nonlinT.values[23]/nonlinZ.values[23])**(1/2),                       
                           (nonlinT.values[24]/nonlinZ.values[24])**(1/2),(nonlinT.values[25]/nonlinZ.values[25])**(1/2),
                           (nonlinT.values[26]/nonlinZ.values[26])**(1/2),(nonlinT.values[27]/nonlinZ.values[27])**(1/2),
                           (nonlinT.values[28]/nonlinZ.values[28])**(1/2)]
linear_real = [integ22,integ152,integ152,integ402,integ402,integ402,integ222,integ62,integ412,integ262,integ262,integ422,integ292,integ82,integ82,integ82,integ92,integ92,integ322,integ322,integ322,integ132,integ132,integ332,integ132,integ362,integ362,integ352,integ142]

# %%
import matplotlib.markers
#plt.scatter(linear_real[2],squareroot_TdivZ[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[10],squareroot_TdivZ[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[14],squareroot_TdivZ[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[17],squareroot_TdivZ[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[22],squareroot_TdivZ[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[26],squareroot_TdivZ[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[4],squareroot_TdivZ[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)

plt.scatter(linear_real[0],squareroot_TdivZ[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[1],squareroot_TdivZ[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[6],squareroot_TdivZ[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[7],squareroot_TdivZ[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[12],squareroot_TdivZ[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[13],squareroot_TdivZ[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[16],squareroot_TdivZ[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[21],squareroot_TdivZ[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[23],squareroot_TdivZ[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[25],squareroot_TdivZ[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[27],squareroot_TdivZ[27],color='aquamarine',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[28],squareroot_TdivZ[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[3],squareroot_TdivZ[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[8],squareroot_TdivZ[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[11],squareroot_TdivZ[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)

#markerstyle changed
#plt.scatter(linear_real[15],squareroot_TdivZ[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
plt.scatter(linear_real[20],squareroot_TdivZ[20], color='cyan',label='W7Xsds05 260.633', marker='1',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[24],squareroot_TdivZ[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)
#plt.scatter(linear_real[5],squareroot_TdivZ[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidth=7, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over Re[$\phi(t)/\phi(0)$]',fontsize=20)
plt.yticks([0.2,0.4,0.6,0.8],fontsize=20)
plt.xticks(fontsize=20)
plt.ylabel(r'$\sqrt{\mathcal{T} /\mathcal{Z}}$',fontsize=30)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4),fancybox=False, shadow=False, ncol=4,borderpad=1.5,labelspacing=1.5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0.2,0.8])
plt.xlim([0,225])
plt.grid()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/real_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear_real[2],squareroot_TdivZ[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[0],squareroot_TdivZ[0],color='purple',label='W7Xhis05 665.979', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[1],squareroot_TdivZ[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(T/Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,1.5])
plt.xlim([-10,200])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear_real[10],squareroot_TdivZ[10], color='lime',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[7],squareroot_TdivZ[7],color='green',label='W7Xlis05 340.925', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[8],squareroot_TdivZ[8],color='lightgreen',label='W7Xlis05 681.85', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(T/Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,1.5])
plt.xlim([-10,200])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear_real[14],squareroot_TdivZ[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[17],squareroot_TdivZ[17], color='grey',label='W7Xsds036 436.87', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[22],squareroot_TdivZ[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[26],squareroot_TdivZ[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[13],squareroot_TdivZ[13],color='blue',label='W7Xsds025 774.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[16],squareroot_TdivZ[16],color='grey',label='W7Xsds036 436.87', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[21],squareroot_TdivZ[21],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[23],squareroot_TdivZ[23],color='navy',label='W7Xsds06 138.185', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[25],squareroot_TdivZ[25],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[27],squareroot_TdivZ[27],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[28],squareroot_TdivZ[28],color='skyblue',label='W7Xsds09 59.952', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[15],squareroot_TdivZ[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[20],squareroot_TdivZ[20], color='cyan',label='W7Xsds05 260.633', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[24],squareroot_TdivZ[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(T/Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,1.5])
plt.xlim([-10,200])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear_real[4],squareroot_TdivZ[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[6],squareroot_TdivZ[6],color='red',label='W7Xhms08 78.832', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[3],squareroot_TdivZ[3],color='darkred',label='W7Xhms05 310.957', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[5],squareroot_TdivZ[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(T/Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,1.5])
plt.xlim([-10,200])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(linear_real[12],squareroot_TdivZ[12],color='orange',label='W7Xlms05 136.837', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[11],squareroot_TdivZ[11],color='navajowhite',label='W7Xlms05 684.184', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('sqrt(T/Z)',fontsize=25)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,1.5])
plt.xlim([-10,200])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)
