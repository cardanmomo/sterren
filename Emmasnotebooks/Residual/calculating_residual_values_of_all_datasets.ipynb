# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
    
data1 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/104.719/gamdiagions_act.dat')
E1 = (data1[:,1]*(1/data1[0, 1]))
e1 = (data1[:,2]*(1/data1[0, 1]))
t1 = data1[:,0]

data2 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/665.979/gamdiagions_act.dat')
E2 = (data2[:,1]*(1/data2[0, 1]))
e2 = (data2[:,2]*(1/data2[0, 1]))
t2 = data2[:,0]

data3 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/104.719/gamdiagions_act.dat')
E3 = (data3[:,1]*(1/data3[0, 1]))
e3 = (data3[:,2]*(1/data3[0, 1]))
t3 = data3[:,0]

data4 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/621.914/gamdiagions_act.dat')
E4 = (data4[:,1]*(1/data4[0, 1]))
e4 = (data4[:,2]*(1/data4[0, 1]))
t4 = data4[:,0]

data5 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/104.719/gamdiagions_act.dat')
E5 = (data5[:,1]*(1/data5[0, 1]))
e5 = (data5[:,2]*(1/data5[0, 1]))
t5 = data5[:,0]

data6 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/340.925/gamdiagions_act.dat')
E6 = (data6[:,1]*(1/data6[0, 1]))
e6 = (data6[:,2]*(1/data6[0, 1]))
t6 = data6[:,0]

data7 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/104.719/gamdiagions_act.dat')
E7 = (data7[:,1]*(1/data7[0, 1]))
e7 = (data7[:,2]*(1/data7[0, 1]))
t7 = data7[:,0]

data8 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/774.957/gamdiagions_act.dat')
E8 = (data8[:,1]*(1/data8[0, 1]))
e8 = (data8[:,2]*(1/data8[0, 1]))
t8 = data8[:,0]

data9 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/436.87/gamdiagions_act.dat')
E9 = (data9[:,1]*(1/data9[0, 1]))
e9 = (data9[:,2]*(1/data9[0, 1]))
t9 = data9[:,0]

data10 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/104.719/gamdiagions_act.dat')
E10 = (data10[:,1]*(1/data10[0, 1]))
e10 = (data10[:,2]*(1/data10[0, 1]))
t10 = data10[:,0]

data11 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/621.914/gamdiagions_act.dat')
E11 = (data11[:,1]*(1/data11[0, 1]))
e11 = (data11[:,2]*(1/data11[0, 1]))
t11 = data11[:,0]

data12 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/104.719/gamdiagions_act.dat')
E12 = (data12[:,1]*(1/data12[0, 1]))
e12 = (data12[:,2]*(1/data12[0, 1]))
t12 = data12[:,0]

data13 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/198.992/gamdiagions_act.dat')
E13 = (data13[:,1]*(1/data13[0, 1]))
e13 = (data13[:,2]*(1/data13[0, 1]))
t13 = data13[:,0]

data14 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/59.952/gamdiagions_act.dat')
E14 = (data14[:,1]*(1/data14[0, 1]))
e14 = (data14[:,2]*(1/data14[0, 1]))
t14 = data14[:,0]

data15 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/110.997/gamdiagions_act.dat')
E15 = (data15[:,1]*(1/data15[0, 1]))
e15 = (data15[:,2]*(1/data15[0, 1]))
t15 = data15[:,0]

data16 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis08/GAM/104.719/gamdiagions_act.dat')
E16 = (data16[:,1]*(1/data16[0, 1]))
e16 = (data16[:,2]*(1/data16[0, 1]))
t16 = data16[:,0]

data17 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/104.719/gamdiagions_act.dat')
E17 = (data17[:,1]*(1/data17[0, 1]))
e17 = (data17[:,2]*(1/data17[0, 1]))
t17 = data17[:,0]

data18 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/530.418/gamdiagions_act.dat')
E18 = (data18[:,1]*(1/data18[0, 1]))
e18 = (data18[:,2]*(1/data18[0, 1]))
t18 = data18[:,0]

data19 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/104.719/gamdiagions_act.dat')
E19 = (data19[:,1]*(1/data19[0, 1]))
e19 = (data19[:,2]*(1/data19[0, 1]))
t19 = data19[:,0]

data20 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/266.000/gamdiagions_act.dat')
E20 = (data20[:,1]*(1/data20[0, 1]))
e20 = (data20[:,2]*(1/data20[0, 1]))
t20 = data20[:,0]

data21 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/530.000/gamdiagions_act.dat')
E21 = (data21[:,1]*(1/data21[0, 1]))
e21 = (data21[:,2]*(1/data21[0, 1]))
t21 = data21[:,0]

data22 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/78.832/gamdiagions_act.dat')
E22 = (data22[:,1]*(1/data22[0, 1]))
e22 = (data22[:,2]*(1/data22[0, 1]))
t22 = data22[:,0]

data23 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis06/GAM/104.719/gamdiagions_act.dat')
E23 = (data23[:,1]*(1/data23[0, 1]))
e23 = (data23[:,2]*(1/data23[0, 1]))
t23 = data23[:,0]

data24 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis07/GAM/104.719/gamdiagions_act.dat')
E24 = (data24[:,1]*(1/data24[0, 1]))
e24 = (data24[:,2]*(1/data24[0, 1]))
t24 = data24[:,0]

data25 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/104.719/gamdiagions_act.dat')
E25 = (data25[:,1]*(1/data25[0, 1]))
e25 = (data25[:,2]*(1/data25[0, 1]))
t25 = data25[:,0]

data26 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/90.837/gamdiagions_act.dat')
E26 = (data26[:,1]*(1/data26[0, 1]))
e26 = (data26[:,2]*(1/data26[0, 1]))
t26 = data26[:,0]

data27 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis09/GAM/104.719/gamdiagions_act.dat')
E27 = (data27[:,1]*(1/data27[0, 1]))
e27 = (data27[:,2]*(1/data27[0, 1]))
t27 = data27[:,0]

data28 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/104.719/gamdiagions_act.dat')
E28 = (data28[:,1]*(1/data28[0, 1]))
e28 = (data28[:,2]*(1/data28[0, 1]))
t28 = data28[:,0]

data29 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/136.837/gamdiagions_act.dat')
E29 = (data29[:,1]*(1/data29[0, 1]))
e29 = (data29[:,2]*(1/data29[0, 1]))
t29 = data29[:,0]

data30 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/104.719/gamdiagions_act.dat')
E30 = (data30[:,1]*(1/data30[0, 1]))
e30 = (data30[:,2]*(1/data30[0, 1]))
t30 = data30[:,0]

data31 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/130.316/gamdiagions_act.dat')
E31 = (data31[:,1]*(1/data31[0, 1]))
e31 = (data31[:,2]*(1/data31[0, 1]))
t31 = data31[:,0]

data32 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/260.633/gamdiagions_act.dat')
E32 = (data32[:,1]*(1/data32[0, 1]))
e32 = (data32[:,2]*(1/data32[0, 1]))
t32 = data32[:,0]

data33 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/138.185/gamdiagions_act.dat')
E33 = (data33[:,1]*(1/data33[0, 1]))
e33 = (data33[:,2]*(1/data33[0, 1]))
t33 = data33[:,0]

data34 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/104.719/gamdiagions_act.dat')
E34 = (data34[:,1]*(1/data34[0, 1]))
e34 = (data34[:,2]*(1/data34[0, 1]))
t34 = data34[:,0]

data35 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/137.61/gamdiagions_act.dat')
E35 = (data35[:,1]*(1/data35[0, 1]))
e35 = (data35[:,2]*(1/data35[0, 1]))
t35 = data35[:,0]

data36 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/68.805/gamdiagions_act.dat')
E36 = (data36[:,1]*(1/data36[0, 1]))
e36 = (data36[:,2]*(1/data36[0, 1]))
t36 = data36[:,0]

data37 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/95.562/gamdiagions_act.dat')
E37 = (data37[:,1]*(1/data37[0, 1]))
e37 = (data37[:,2]*(1/data37[0, 1]))
t37 = data37[:,0]

data38 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/104.719/gamdiagions_act.dat')
E38 = (data38[:,1]*(1/data38[0, 1]))
e38 = (data38[:,2]*(1/data38[0, 1]))
t38 = data38[:,0]

data39 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms09/GAM/104.719/gamdiagions_act.dat')
E39 = (data39[:,1]*(1/data39[0, 1]))
e39 = (data39[:,2]*(1/data39[0, 1]))
t39 = data39[:,0]

data40 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/310.957_P/gamdiagions_act.dat')
E40 = (data40[:,1]*(1/data40[0, 1]))
e40 = (data40[:,2]*(1/data40[0, 1]))
t40 = data40[:,0]

data41 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/681.85_P/gamdiagions_act.dat')
E41 = (data41[:,1]*(1/data41[0, 1]))
e41 = (data41[:,2]*(1/data41[0, 1]))
t41 = data41[:,0]

data42 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/684.184_P/gamdiagions_act.dat')
E42 = (data42[:,1]*(1/data42[0, 1]))
e42 = (data42[:,2]*(1/data42[0, 1]))
t42 = data42[:,0]

Q1 = np.sqrt(E1**2+e1**2)
Q2 = np.sqrt(E2**2+e2**2)
Q3 = np.sqrt(E3**2+e3**2)
Q4 = np.sqrt(E4**2+e4**2)
Q5 = np.sqrt(E5**2+e5**2)
Q6 = np.sqrt(E6**2+e6**2)
Q7 = np.sqrt(E7**2+e7**2)
Q8 = np.sqrt(E8**2+e8**2)
Q9 = np.sqrt(E9**2+e9**2)
Q10 = np.sqrt(E10**2+e10**2)
Q11 = np.sqrt(E11**2+e11**2)
Q12 = np.sqrt(E12**2+e12**2)
Q13 = np.sqrt(E13**2+e13**2)
Q14 = np.sqrt(E14**2+e14**2)
Q15 = np.sqrt(E15**2+e15**2)
Q16 = np.sqrt(E16**2+e16**2)
Q17 = np.sqrt(E17**2+e17**2)
Q18 = np.sqrt(E18**2+e18**2)
Q19 = np.sqrt(E19**2+e19**2)
Q20 = np.sqrt(E20**2+e20**2)
Q21 = np.sqrt(E21**2+e21**2)
Q22 = np.sqrt(E22**2+e22**2)
Q23 = np.sqrt(E23**2+e23**2)
Q24 = np.sqrt(E24**2+e24**2)
Q25 = np.sqrt(E25**2+e25**2)
Q26 = np.sqrt(E26**2+e26**2)
Q27 = np.sqrt(E27**2+e27**2)
Q28 = np.sqrt(E28**2+e28**2)
Q29 = np.sqrt(E29**2+e29**2)
Q30 = np.sqrt(E30**2+e30**2)
Q31 = np.sqrt(E31**2+e31**2)
Q32 = np.sqrt(E32**2+e32**2)
Q33 = np.sqrt(E33**2+e33**2)
Q34 = np.sqrt(E34**2+e34**2)
Q35 = np.sqrt(E35**2+e35**2)
Q36 = np.sqrt(E36**2+e36**2)
Q37 = np.sqrt(E37**2+e37**2)
Q38 = np.sqrt(E38**2+e38**2)
Q39 = np.sqrt(E39**2+e39**2)
Q40 = np.sqrt(E40**2+e40**2)
Q41 = np.sqrt(E41**2+e41**2)
Q42 = np.sqrt(E42**2+e42**2)
# Out:
# loading successful!

# %%
#Assuming that the residual is the average value of Q from the point where the absolute value of the derivative of Q  becomes less than 0.00001 and stays below that value onwards till the end of the data
n1=0
teller1=0 #teller = counter
residual1=0
nfix1=0 # nfix is needed to make sure it avegares only over the right Q values
finalvaluedata1=4335 #needs to be adjusted per data set
while n1 < finalvaluedata1:
    if abs((Q1[n1+1]-Q1[n1])/(t1[n1+1]-t1[n1])) < 0.00001:#this number justified because the values that come out of this code are in the same order as estimated values by looking at the residual closely.
        teller1=teller1+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual1=(residual1*(n1-nfix1)+Q1[n1])/(n1+1-nfix1) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller1=0
        residual1=0
        nfix1 = (n1+1)
    n1=n1+1 
listofqvalues1=Q1[(n1-teller1):n1]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std1=np.std(listofqvalues1)
#print("The residual value of W7Xhis05 104.719  is:",residual1, "+-", std1)

n2=0
teller2=0
residual2=0
nfix2=0
finalvaluedata2=9538 
while n2 < finalvaluedata2:
    if abs((Q2[n2+1]-Q2[n2])/(t2[n2+1]-t2[n2])) < 0.00001:
        teller2=teller2+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual2=(residual2*(n2-nfix2)+Q2[n2])/(n2+1-nfix2) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller2=0
        residual2=0
        nfix2=(n2+1)
    n2=n2+1    
listofqvalues2=Q2[(n2-teller2):n2]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std2=np.std(listofqvalues2)
#print("The residual value of W7Xhis05 665.979  is:",residual2, "+-", std2)

n3=0
teller3=0
residual3=0
nfix3=0
finalvaluedata3=8784
while n3 < finalvaluedata3:
    if abs((Q3[n3+1]-Q3[n3])/(t3[n3+1]-t3[n3])) < 0.00001:
        teller3=teller3+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual3=(residual3*(n3-nfix3)+Q3[n3])/(n3+1-nfix3) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller3=0
        residual3=0
        nfix3=n3+1
    n3=n3+1 
listofqvalues3=Q3[(n3-teller3):n3]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std3=np.std(listofqvalues3)
#print("The residual value of W7Xhms05 104.719  is:",residual3, "+-", std3)

n4=0
teller4=0
residual4=0
nfix4=0
finalvaluedata4=8784 
while n4 < finalvaluedata4:
    if abs((Q4[n4+1]-Q4[n4])/(t4[n4+1]-t4[n4])) < 0.00001:
        teller4=teller4+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual4=(residual4*(n4-nfix4)+Q4[n4])/(n4+1-nfix4) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller4=0
        residual4=0
        nfix4=n4+1
    n4=n4+1    
listofqvalues4=Q4[(n4-teller4):n4]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std4=np.std(listofqvalues4)
#print("The residual value of W7Xhms05 621.914  is:",residual4, "+-", std4)

n5=0
teller5=0
residual5=0
nfix5=0
finalvaluedata5=3456
while n5 < finalvaluedata5:
    if abs((Q5[n5+1]-Q5[n5])/(t5[n5+1]-t5[n5])) < 0.00001:
        teller5=teller5+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual5=(residual5*(n5-nfix5)+Q5[n5])/(n5+1-nfix5) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller5=0
        residual5=0
        nfix5=n5+1
    n5=n5+1    
listofqvalues5=Q5[(n5-teller5):n5]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std5=np.std(listofqvalues5)
#print("The residual value of W7Xlis05 104.719  is:",residual5, "+-", std5)

n6=0
teller6=0
residual6=0
nfix6=0
finalvaluedata6=5945 
while n6 < finalvaluedata6:
    if abs((Q6[n6+1]-Q6[n6])/(t6[n6+1]-t6[n6])) < 0.00001:
        teller6=teller6+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual6=(residual6*(n6-nfix6)+Q6[n6])/(n6+1-nfix6) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller6=0
        residual6=0
        nfix6=n6+1
    n6=n6+1    
listofqvalues6=Q6[(n6-teller6):n6]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std6=np.std(listofqvalues6)
#print("The residual value of W7Xlis05 340.925  is:",residual6, "+-", std6)

n7=0
teller7=0
residual7=0
nfix7=0
finalvaluedata7=3731 
while n7 < finalvaluedata7:
    if abs((Q7[n7+1]-Q7[n7])/(t7[n7+1]-t7[n7])) < 0.00001:
        teller7=teller7+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual7=(residual7*(n7-nfix7)+Q7[n7])/(n7+1-nfix7) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller7=0
        residual7=0
        nfix7=n7+1
    n7=n7+1    
listofqvalues7=Q7[(n7-teller7):n7]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std7=np.std(listofqvalues7)
#print("The residual value of W7Xsds025 104.719 is:",residual7, "+-", std7)

n8=0
teller8=0
residual8=0
nfix8=0
finalvaluedata8=9901 
while n8 < finalvaluedata8:
    if abs((Q8[n8+1]-Q8[n8])/(t8[n8+1]-t8[n8])) < 0.00001:
        teller8=teller8+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual8=(residual8*(n8-nfix8)+Q8[n8])/(n8+1-nfix8) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller8=0
        residual8=0
        nfix8=n8+1
    n8=n8+1    
listofqvalues8=Q8[(n8-teller8):n8]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std8=np.std(listofqvalues8)
#print("The residual value of W7Xsds025 774.957 is:",residual8, "+-", std8)

n9=0
teller9=0
residual9=0
nfix9=0
finalvaluedata9=3807 
while n9 < finalvaluedata9:
    if abs((Q9[n9+1]-Q9[n9])/(t9[n9+1]-t9[n9])) < 0.00001:
        teller9=teller9+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual9=(residual9*(n9-nfix9)+Q9[n9])/(n9+1-nfix9) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller9=0
        residual9=0
        nfix9=n9+1
    n9=n9+1    
listofqvalues9=Q9[(n9-teller9):n9]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std9=np.std(listofqvalues9)
#print("The residual value of W7Xsds036  436.87 is:",residual9, "+-", std9)

n10=0
teller10=0
residual10=0
nfix10=0
finalvaluedata10=3968
while n10 < finalvaluedata10:
    if abs((Q10[n10+1]-Q10[n10])/(t10[n10+1]-t10[n10])) < 0.00001:
        teller10=teller10+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual10=(residual10*(n10-nfix10)+Q10[n10])/(n10+1-nfix10) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller10=0
        residual10=0
        nfix10=n10+1
    n10=n10+1    
listofqvalues10=Q10[(n10-teller10):n10]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std10=np.std(listofqvalues10)
#print("The residual value of W7Xsds05  104.719 is:",residual10, "+-", std10)

n11=0
teller11=0
residual11=0
nfix11=0
finalvaluedata11=3947
while n11 < finalvaluedata11:
    if abs((Q11[n11+1]-Q11[n11])/(t11[n11+1]-t11[n11])) < 0.00001:
        teller11=teller11+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual11=(residual11*(n11-nfix11)+Q11[n11])/(n11+1-nfix11)#to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else:
        teller11=0
        residual11=0
        nfix11 = (n11+1)
    n11=n11+1
listofqvalues11=Q11[(n11-teller11):n11]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std11=np.std(listofqvalues11)
#print("The residual value of W7Xsds05 621.914 is:",residual11, "+-", std11)

n12=0
teller12=0
residual12=0
nfix12=0
finalvaluedata12=4076
while n12 < finalvaluedata12:
    if abs((Q12[n12+1]-Q12[n12])/(t12[n12+1]-t12[n12])) < 0.00001:
        teller12=teller12+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual12=(residual12*(n12-nfix12)+Q12[n12])/(n12+1-nfix12) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller12=0
        residual12=0
        nfix12=n12+1
    n12=n12+1    
listofqvalues12=Q12[(n12-teller12):n12]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std12=np.std(listofqvalues12)
#print("The residual value of W7Xsds06  104.719 is:",residual12, "+-", std12)

n13=0
teller13=0
residual13=0
nfix13=0
finalvaluedata13=4054 
while n13 < finalvaluedata13:
    if abs((Q13[n13+1]-Q13[n13])/(t13[n13+1]-t13[n13])) < 0.00001:
        teller13=teller13+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual13=(residual13*(n13-nfix13)+Q13[n13])/(n13+1-nfix13) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller13=0
        residual13=0
        nfix12=n13+1
    n13=n13+1    
listofqvalues13=Q13[(n13-teller13):n13]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std13=np.std(listofqvalues13)
#print("The residual value of W7Xsds06  198.992 is:",residual13, "+-", std13)

n14=0
teller14=0
residual14=0
nfix14=0
finalvaluedata14=4438 
while n14 < finalvaluedata14:
    if abs((Q14[n14+1]-Q14[n14])/(t14[n14+1]-t14[n14])) < 0.00001:
        teller14=teller14+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual14=(residual14*(n14-nfix14)+Q14[n14])/(n14+1-nfix14) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller14=0
        residual14=0
        nfix14=n14+1
    n14=n14+1    
listofqvalues14=Q14[(n14-teller14):n14]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std14=np.std(listofqvalues14)
#print("The residual value of W7Xsds09   59.952 is:",residual14, "+-",std14)

n15=0
teller15=0
residual15=0
nfix15=0
finalvaluedata15=4335 
while n15 < finalvaluedata15:
    if abs((Q15[n15+1]-Q15[n15])/(t15[n15+1]-t15[n15])) < 0.00001:
        teller15=teller15+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual15=(residual15*(n15-nfix15)+Q15[n15])/(n15+1-nfix15) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller15=0
        residual15=0
        nfix15=n15+1
    n15=n15+1    
listofqvalues15=Q15[(n15-teller15):n15]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std15=np.std(listofqvalues15)
#print("The residual value of W7Xhis05   110.997 is:",residual15, "+-",std15)

n16=0
teller16=0
residual16=0
nfix16=0
finalvaluedata16=4777 
while n16 < finalvaluedata16:
    if abs((Q16[n16+1]-Q16[n16])/(t16[n16+1]-t16[n16])) < 0.00001:
        teller16=teller16+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual16=(residual16*(n16-nfix16)+Q16[n16])/(n16+1-nfix16) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller16=0
        residual16=0
        nfix16=n16+1
    n16=n16+1    
listofqvalues16=Q16[(n16-teller16):n16]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std16=np.std(listofqvalues16)
#print("The residual value of W7Xhis08 104.719  is:",residual16, "+-", std16)

n17=0
teller17=0
residual17=0
nfix17=0
finalvaluedata17=3947 
while n17 < finalvaluedata17:
    if abs((Q17[n17+1]-Q17[n17])/(t17[n17+1]-t17[n17])) < 0.00001:
        teller17=teller17+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual17=(residual17*(n17-nfix17)+Q17[n17])/(n17+1-nfix17) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller17=0
        residual17=0
        nfix17=n17+1
    n17=n17+1    
listofqvalues17=Q17[(n17-teller17):n17]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std17=np.std(listofqvalues17)
#print("The residual value of W7Xhms036 104.719 is:",residual17, "+-", std17)

n18=0
teller18=0
residual18=0
nfix18=0
finalvaluedata18=3927 
while n18 < finalvaluedata18:
    if abs((Q18[n18+1]-Q18[n18])/(t18[n18+1]-t18[n18])) < 0.00001:
        teller18=teller18+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual18=(residual18*(n18-nfix18)+Q18[n18])/(n18+1-nfix18) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller18=0
        residual18=0
        nfix18=n18+1
    n18=n18+1    
listofqvalues18=Q18[(n18-teller18):n18]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std18=np.std(listofqvalues18)
#print("The residual value of W7Xhms036 530.418 is:",residual18, "+-", std18)

n19=0
teller19=0
residual19=0
nfix19=0
finalvaluedata19=4360 
while n19 < finalvaluedata19:
    if abs((Q19[n19+1]-Q19[n19])/(t19[n19+1]-t19[n19])) < 0.00001:
        teller19=teller19+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual19=(residual19*(n19-nfix19)+Q19[n19])/(n19+1-nfix19) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller19=0
        residual19=0
        nfix19=n19+1
    n19=n19+1    
listofqvalues19=Q19[(n19-teller19):n19]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std19=np.std(listofqvalues19)
#print("The residual value of W7Xhms08  104.719 is:",residual19, "+-", std19)

n20=0
teller20=0
residual20=0
nfix20=0
finalvaluedata20=8721
while n20 < finalvaluedata20:
    if abs((Q20[n20+1]-Q20[n20])/(t20[n20+1]-t20[n20])) < 0.00001:
        teller20=teller20+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual20=(residual20*(n20-nfix20)+Q20[n20])/(n20+1-nfix20) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller20=0
        residual20=0
        nfix20=n20+1
    n20=n20+1    
listofqvalues20=Q20[(n20-teller20):n20]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std20=np.std(listofqvalues20)
#print("The residual value of W7Xhms08  266.000 is:",residual20, "+-", std20)

n21=0
teller21=0
residual21=0
nfix21=0
finalvaluedata21=8671
while n21 < finalvaluedata21:
    if abs((Q21[n21+1]-Q21[n21])/(t21[n21+1]-t21[n21])) < 0.00001:
        teller21=teller21+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual21=(residual21*(n21-nfix21)+Q21[n21])/(n21+1-nfix21) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller21=0
        residual21=0
        nfix21=(n21+1)
    n21=n21+1    
listofqvalues21=Q21[(n21-teller21):n21]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std21=np.std(listofqvalues21)
#print("The residual value of W7Xhms08 530.000  is:",residual21, "+-", std21)

n22=0
teller22=0
residual22=0
nfix22=0
finalvaluedata22=4360 
while n22 < finalvaluedata22:
    if abs((Q22[n22+1]-Q22[n22])/(t22[n22+1]-t22[n22])) < 0.00001:
        teller22=teller22+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual22=(residual22*(n22-nfix22)+Q22[n22])/(n22+1-nfix22) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller22=0
        residual22=0
        nfix22=(n22+1)
    n22=n22+1    
listofqvalues22=Q22[(n22-teller22):n22]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std22=np.std(listofqvalues22)
#print("The residual value of W7Xhms08 78.832  is:",residual22, "+-", std22)

n23=0
teller23=0
residual23=0
nfix23=0
finalvaluedata23=3555 
while n23 < finalvaluedata23:
    if abs((Q23[n23+1]-Q23[n23])/(t23[n23+1]-t23[n23])) < 0.00001:
        teller23=teller23+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual23=(residual23*(n23-nfix23)+Q23[n23])/(n23+1-nfix23) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller23=0
        residual23=0
        nfix23=(n23+1)
    n23=n23+1    
listofqvalues23=Q23[(n23-teller23):n23]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std23=np.std(listofqvalues23)
#print("The residual value of W7Xlis06 104.719  is:",residual23, "+-", std23)

n24=0
teller24=0
residual24=0
nfix24=0
finalvaluedata24=3641 
while n24 < finalvaluedata24:
    if abs((Q24[n24+1]-Q24[n24])/(t24[n24+1]-t24[n24])) < 0.00001:
        teller24=teller24+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual24=(residual24*(n24-nfix24)+Q24[n24])/(n24+1-nfix24) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller24=0
        residual24=0
        nfix24=(n24+1)
    n24=n24+1    
listofqvalues24=Q24[(n24-teller24):n24]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std24=np.std(listofqvalues24)
#print("The residual value of W7Xlis07 104.719  is:",residual24, "+-", std24)

n25=0
teller25=0
residual25=0
nfix25=0
finalvaluedata25=3731 
while n25 < finalvaluedata25:
    if abs((Q25[n25+1]-Q25[n25])/(t25[n25+1]-t25[n25])) < 0.00001:
        teller25=teller25+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual25=(residual25*(n25-nfix25)+Q25[n25])/(n25+1-nfix25) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller25=0
        residual25=0
        nfix25=(n25+1)
    n25=n25+1    
listofqvalues25=Q25[(n25-teller25):n25]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std25=np.std(listofqvalues25)
#print("The residual value of W7Xlis08 104.719  is:",residual25, "+-", std25)

n26=0
teller26=0
residual26=0
nfix26=0
finalvaluedata26=2488 
while n26 < finalvaluedata26:
    if abs((Q26[n26+1]-Q26[n26])/(t26[n26+1]-t26[n26])) < 0.00001:
        teller26=teller26+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual26=(residual26*(n26-nfix26)+Q26[n26])/(n26+1-nfix26) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller26=0
        residual26=0
        nfix26=(n26+1)
    n26=n26+1    
listofqvalues26=Q26[(n26-teller26):n26]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std26=np.std(listofqvalues26)
#print("The residual value of W7Xlis08 90.837  is:",residual26, "+-", std26)

n27=0
teller27=0
residual27=0
nfix27=0
finalvaluedata27=3827 
while n27 < finalvaluedata27:
    if abs((Q27[n27+1]-Q27[n27])/(t27[n27+1]-t27[n27])) < 0.00001:
        teller27=teller27+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual27=(residual27*(n27-nfix27)+Q27[n27])/(n27+1-nfix27) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller27=0
        residual27=0
        nfix27=(n27+1)
    n27=n27+1    
listofqvalues27=Q27[(n27-teller27):n27]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std27=np.std(listofqvalues27)
#print("The residual value of W7Xlis09 104.719  is:",residual27, "+-", std27)

n28=0
teller28=0
residual28=0
nfix28=0
finalvaluedata28=3695 
while n28 < finalvaluedata28:
    if abs((Q28[n28+1]-Q28[n28])/(t28[n28+1]-t28[n28])) < 0.00001:
        teller28=teller28+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual28=(residual28*(n28-nfix28)+Q28[n28])/(n28+1-nfix28) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller28=0
        residual28=0
        nfix28=(n28+1)
    n28=n28+1    
listofqvalues28=Q28[(n28-teller28):n28]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std28=np.std(listofqvalues28)
#print("The residual value of W7Xlms05 104.719  is:",residual28, "+-", std28)

n29=0
teller29=0
residual29=0
nfix29=0
finalvaluedata29=3694 
while n29 < finalvaluedata29:
    if abs((Q29[n29+1]-Q29[n29])/(t29[n29+1]-t29[n29])) < 0.00001:
        teller29=teller29+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual29=(residual29*(n29-nfix29)+Q29[n29])/(n29+1-nfix29) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller29=0
        residual29=0
        nfix29=(n29+1)
    n29=n29+1    
listofqvalues29=Q29[(n29-teller29):n29]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std29=np.std(listofqvalues29)
#print("The residual value of W7Xlms05 136.837  is:",residual29, "+-", std29)

n30=0
teller30=0
residual30=0
nfix30=0
finalvaluedata30=3827
while n30 < finalvaluedata30:
    if abs((Q30[n30+1]-Q30[n30])/(t30[n30+1]-t30[n30])) < 0.00001:
        teller30=teller30+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual30=(residual30*(n30-nfix30)+Q30[n30])/(n30+1-nfix30) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller30=0
        residual30=0
        nfix30=n30+1
    n30=n30+1 
listofqvalues30=Q30[(n30-teller30):n30]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std30=np.std(listofqvalues30)
#print("The residual value of W7Xsds036 104.719  is:",residual30, "+-", std30)

n31=0
teller31=0
residual31=0
nfix31=0
finalvaluedata31=3968
while n31 < finalvaluedata31:
    if abs((Q31[n31+1]-Q31[n31])/(t31[n31+1]-t31[n31])) < 0.00001:
        teller31=teller31+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual31=(residual31*(n31-nfix31)+Q31[n31])/(n31+1-nfix31) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller31=0
        residual31=0
        nfix31=n31+1
    n31=n31+1 
listofqvalues31=Q31[(n31-teller31):n31]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std31=np.std(listofqvalues31)
#print("The residual value of W7Xsds05 130.316  is:",residual31, "+-", std31)

n32=0
teller32=0
residual32=0
nfix32=0
finalvaluedata32=3947 
while n32 < finalvaluedata32:
    if abs((Q32[n32+1]-Q32[n32])/(t32[n32+1]-t32[n32])) < 0.00001:
        teller32=teller32+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual32=(residual32*(n32-nfix32)+Q32[n32])/(n32+1-nfix32) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller32=0
        residual32=0
        nfix32=(n32+1)
    n32=n32+1    
listofqvalues32=Q32[(n32-teller32):n32]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std32=np.std(listofqvalues32)
#print("The residual value of W7Xsds05 260.633  is:",residual32, "+-", std32)

n33=0
teller33=0
residual33=0
nfix33=0
finalvaluedata33=4054
while n33 < finalvaluedata33:
    if abs((Q33[n33+1]-Q33[n33])/(t33[n33+1]-t33[n33])) < 0.00001:
        teller33=teller33+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual33=(residual33*(n33-nfix33)+Q33[n33])/(n33+1-nfix33) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller33=0
        residual33=0
        nfix33=n33+1
    n33=n33+1 
listofqvalues33=Q33[(n33-teller33):n33]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std33=np.std(listofqvalues33)
#print("The residual value of W7Xsds06 138.185  is:",residual33, "+-", std33)

n34=0
teller34=0
residual34=0
nfix34=0
finalvaluedata34=4310
while n34 < finalvaluedata34:
    if abs((Q34[n34+1]-Q34[n34])/(t34[n34+1]-t34[n34])) < 0.00001:
        teller34=teller34+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual34=(residual34*(n34-nfix34)+Q34[n34])/(n34+1-nfix34) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller34=0
        residual34=0
        nfix34=n34+1
    n34=n34+1 
listofqvalues34=Q34[(n34-teller34):n34]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std34=np.std(listofqvalues34)
#print("The residual value of W7Xsds08 104.719  is:",residual34, "+-", std34)

n35=0
teller35=0
residual35=0
nfix35=0
finalvaluedata35=4310
while n35 < finalvaluedata35:
    if abs((Q35[n35+1]-Q35[n35])/(t35[n35+1]-t35[n35])) < 0.00001:
        teller35=teller35+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual35=(residual35*(n35-nfix35)+Q35[n35])/(n35+1-nfix35) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller35=0
        residual35=0
        nfix35=n35+1
    n35=n35+1 
listofqvalues35=Q35[(n35-teller35):n35]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std35=np.std(listofqvalues35)
#print("The residual value of W7Xsds08 137.61  is:",residual35, "+-", std35)

n36=0
teller36=0
residual36=0
nfix36=0
finalvaluedata36=4310
while n36 < finalvaluedata36:
    if abs((Q36[n36+1]-Q36[n36])/(t36[n36+1]-t36[n36])) < 0.00001:
        teller36=teller36+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual36=(residual36*(n36-nfix36)+Q36[n36])/(n36+1-nfix36) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller36=0
        residual36=0
        nfix36=n36+1
    n36=n36+1 
listofqvalues36=Q36[(n36-teller36):n36]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std36=np.std(listofqvalues36)
#print("The residual value of W7Xsds08 68.805  is:",residual36, "+-", std36)

n37=0
teller37=0
residual37=0
nfix37=0
finalvaluedata37=4310
while n37 < finalvaluedata37:
    if abs((Q37[n37+1]-Q37[n37])/(t37[n37+1]-t37[n37])) < 0.00001:
        teller37=teller37+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual37=(residual37*(n37-nfix37)+Q37[n37])/(n37+1-nfix37) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller37=0
        residual37=0
        nfix37=n37+1
    n37=n37+1 
listofqvalues37=Q37[(n37-teller37):n37]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std37=np.std(listofqvalues37)
#print("The residual value of W7Xsds08 95.562  is:",residual37, "+-", std37)

n38=0
teller38=0
residual38=0
nfix38=0
finalvaluedata38=4438
while n38 < finalvaluedata38:
    if abs((Q38[n38+1]-Q38[n38])/(t38[n38+1]-t38[n38])) < 0.00001:
        teller38=teller38+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual38=(residual38*(n38-nfix38)+Q38[n38])/(n38+1-nfix38) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller38=0
        residual38=0
        nfix38=n38+1
    n38=n38+1 
listofqvalues38=Q38[(n38-teller38):n38]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std38=np.std(listofqvalues38)
#print("The residual value of W7Xsds09 104.719  is:",residual38, "+-", std38)

n39=0
teller39=0
residual39=0
nfix39=0
finalvaluedata39=4121 
while n39 < finalvaluedata39:
    if abs((Q39[n39+1]-Q39[n39])/(t39[n39+1]-t39[n39])) < 0.00001:
        teller39=teller39+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual39=(residual39*(n39-nfix39)+Q39[n39])/(n39+1-nfix39) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller39=0
        residual39=0
        nfix39=(n39+1)
    n39=n39+1    
listofqvalues39=Q39[(n39-teller39):n39]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std39=np.std(listofqvalues39)
#print("The residual value of W7Xlms09 104.719  is:",residual39, "+-", std39)

n40=0
teller40=0
residual40=0
nfix40=0
finalvaluedata40=1063
while n40 < finalvaluedata40:
    if abs((Q40[n40+1]-Q40[n40])/(t40[n40+1]-t40[n40])) < 0.00001:
        teller40=teller40+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual40=(residual40*(n40-nfix40)+Q40[n40])/(n40+1-nfix40) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller40=0
        residual40=0
        nfix40=n40+1
    n40=n40+1 
listofqvalues40=Q40[(n40-teller40):n40]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std40=np.std(listofqvalues40)
#print("The residual value of W7Xhms05 310.957  is:",residual40, "+-", std40)

n41=0
teller41=0
residual41=0
nfix41=0
finalvaluedata41=7693
while n41 < finalvaluedata41:
    if abs((Q41[n41+1]-Q41[n41])/(t41[n41+1]-t41[n41])) < 0.00001:
        teller41=teller41+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual41=(residual41*(n41-nfix41)+Q41[n41])/(n41+1-nfix41) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller41=0
        residual41=0
        nfix41=n41+1
    n41=n41+1 
listofqvalues41=Q41[(n41-teller41):n41]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std41=np.std(listofqvalues41)
#print("The residual value of W7Xlis05 681.85  is:",residual41, "+-", std41)

n42=0
teller42=0
residual42=0
nfix42=0
finalvaluedata42=8249
while n42 < finalvaluedata42:
    if abs((Q42[n42+1]-Q42[n42])/(t42[n42+1]-t42[n42])) < 0.00001:
        teller42=teller42+1 #telt hoe lang de afgeleide binnen het bereik valt
        residual42=(residual42*(n42-nfix42)+Q42[n42])/(n42+1-nfix42) #to get as residual the average over all the Q values in the region where the absolute value of the derivative is less than 0.00001
    else: 
        teller42=0
        residual42=0
        nfix42=(n42+1)
    n42=n42+1    
listofqvalues42=Q42[(n42-teller42):n42]#necessary to use ':n' instead of just ':'. checked that mean of this list is the same as the residual determined by the code
std42=np.std(listofqvalues42)
#print("The residual value of W7Xlms05 684.184  is:",residual42, "+-", std42)

# %%
configuration = ['W7Xhis05 104.719','W7Xhis05 110.997','W7Xhis05 665.979','W7Xhis08 104.719','W7Xhms036 104.719',
                 'W7Xhms036 530.418','W7Xhms05 104.719','W7Xhms05 310.957','W7Xhms05 621.914','W7Xhms08 78.832',
                 'W7Xhms08 104.719','W7Xhms08 266.000','W7Xhms08 530.000','W7Xlis05 104.719','W7Xlis05 340.925',
                 'W7Xlis05 681.85','W7Xlis06 104.719','W7Xlis07 104.719','W7Xlis08 90.837','W7Xlis08 104.719',
                 'W7Xlis09 104.719','W7Xlms05 104.719','W7Xlms05 136.837','W7Xlms05 684.184','W7Xlms09 104.719',
                 'W7Xsds025 104.719','W7Xsds025 774.957','W7Xsds036 104.719','W7Xsds036 436.87','W7Xsds05 104.719',
                 'W7Xsds05 130.316','W7Xsds05 260.633','W7Xsds05 621.914','W7Xsds06 104.719','W7Xsds06 138.185',
                 'W7Xsds06 198.992','W7Xsds08 68.805','W7Xsds08 95.562','W7Xsds08 104.719','W7Xsds08 137.61',
                 'W7Xsds09 59.952','W7Xsds09 104.719']
residualvalue = [residual1,residual15,residual2,residual16,residual17,residual18,residual3,residual40,
                 residual4,residual22,residual19,residual20,residual21,residual5,residual6,residual41,
                 residual23,residual24,residual26,residual25,residual27,residual28,residual29,residual42,
                 residual39,residual7,residual8,residual30,residual9,residual10,residual31,residual32,
                 residual11,residual12,residual33,residual13,residual36,residual37,residual34,residual35,
                 residual14,residual38]
error = [std1,std15,std2,std16,std17,std18,std3,std40,std4,std22,std19,std20,std21,std5,std6,std41,std23,std24,std26,
         std25,std27,std28,std29,std42,std39,std7,std8,std30,std9,std10,std31,std32,std11,std12,std33,std13,std36,
         std37,std34,std35,std14,std38]
fig, ax = plt.subplots()
ax.bar(configuration, residualvalue, yerr=error,color=['purple','purple','purple','magenta', 'red', 'red','darkred',
                                                       'darkred','darkred','tomato', 'tomato','tomato', 'tomato',
                                                       'green','green','green','lime','darkgreen','lightgreen',
                                                       'lightgreen','mediumseagreen','orange','orange','orange',
                                                       'navajowhite','blue','blue','darkcyan','darkcyan','cyan',
                                                       'cyan','cyan','cyan','dodgerblue','dodgerblue','dodgerblue',
                                                       'navy','navy','navy','navy','deepskyblue','deepskyblue'],
       align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Residual value',fontsize=20)
ax.set_xlabel('Data set',fontsize=20)
ax.set_xticks(configuration)
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
ax.set_xticklabels(configuration,rotation=90)
ax.set_title('Residual value for each data set',fontsize=30)
ax.yaxis.grid(True)
plt.tight_layout(rect=[0, 0, 5, 4])
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residualvalues.png', format='png', dpi=1200)

# %%
#To compare all residuals with L_x=104.719 
#print("his05",residual1, "+-", std1)
#print("his08",residual16, "+-", std16)
#print("pauze")
#print("hms036",residual17, "+-", std17)
#print("hms05",residual3, "+-", std3)
#print("hms08",residual19,'+-',std19)
#print("pauze")
#print("lis05",residual5, "+-", std5)
#print("lis06",residual23, "+-", std23)
#print("lis07",residual24, "+-", std24)
#print("lis08",residual25, "+-", std25)
#print("lis09",residual27, "+-", std27)
#print("pauze")
#print("sds025",residual7, "+-", std7)
#print("sds036",residual30, "+-", std30)
#print("sds05",residual10, "+-", std10)
#print("sds06",residual12, "+-", std12)
#print("sds08",residual34, "+-", std34)
#print("sds09",residual38, "+-", std38)
#print("pauze")
#print("lms05",residual28, "+-", std28)
#print("lms09",residual39, "+-", std39)

# %% [markdown]
# residual values for all data with L_x=104.719
# configuration = ['W7Xhis05 104.719','W7Xhis08 104.719','W7Xhms036 104.719','W7Xhms05 104.719','W7Xhms08 104.719','W7Xlis05 104.719','W7Xlis06 104.719','W7Xlis07 104.719','W7Xlis08 104.719','W7Xlis09 104.719','W7Xlms05 104.719','W7Xlms09 104.719','W7Xsds025 104.719','W7Xsds036 104.719','W7Xsds05 104.719','W7Xsds06 104.719','W7Xsds08 104.719','W7Xsds09 104.719']
# residualvalue = [residual1,residual16,residual17,residual3,residual19,residual5,residual23,residual24,residual25,residual27,residual28,residual39,residual7,residual30,residual10,residual12,residual34,residual38]
# error = [std1,std16,std17,std3,std19,std5,std23,std24,std25,std27,std28,std39,std7,std30,std10,std12,std34,std38]
# fig, ax = plt.subplots()
# ax.bar(configuration, residualvalue, yerr=error,color=['purple','magenta', 'red', 'darkred','tomato', 'green','lime','darkgreen','lightgreen','mediumseagreen','orange','navajowhite','blue','darkcyan','cyan','dodgerblue','navy','deepskyblue'], align='center', alpha=0.5, ecolor='black', capsize=10)
# ax.set_ylabel('Residual value',fontsize=20)
# ax.set_xlabel('Data set',fontsize=20)
# ax.set_xticks(configuration)
# plt.yticks(fontsize=16)
# plt.xticks(fontsize=16)
# ax.set_xticklabels(configuration,rotation=90)
# ax.set_title('Residual value for data with $L_x=104.719$',fontsize=30)
# ax.yaxis.grid(True)
# plt.tight_layout(rect=[0, 0, 5, 4])
# #plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residualvalues104719.png', format='png', dpi=1200)

# %%
# to see the difference in number of values over which is averaged to determine the residual
configuration = ['W7Xhis05 104.719','W7Xhis05 110.997','W7Xhis05 665.979','W7Xhis08 104.719','W7Xhms036 104.719',
                 'W7Xhms036 530.418','W7Xhms05 104.719','W7Xhms05 310.957','W7Xhms05 621.914','W7Xhms08 78.832',
                 'W7Xhms08 104.719','W7Xhms08 266.000','W7Xhms08 530.000','W7Xlis05 104.719','W7Xlis05 340.925',
                 'W7Xlis05 681.85','W7Xlis06 104.719','W7Xlis07 104.719','W7Xlis08 90.837','W7Xlis08 104.719',
                 'W7Xlis09 104.719','W7Xlms05 104.719','W7Xlms05 136.837','W7Xlms05 684.184','W7Xlms09 104.719',
                 'W7Xsds025 104.719','W7Xsds025 774.957','W7Xsds036 104.719','W7Xsds036 436.87','W7Xsds05 104.719',
                 'W7Xsds05 130.316','W7Xsds05 260.633','W7Xsds05 621.914','W7Xsds06 104.719','W7Xsds06 138.185',
                 'W7Xsds06 198.992','W7Xsds08 68.805','W7Xsds08 95.562','W7Xsds08 104.719','W7Xsds08 137.61',
                 'W7Xsds09 59.952','W7Xsds09 104.719']
numberofvalues = [teller1,teller15,teller2,teller16,teller17,teller18,teller3,teller40,teller4,teller22,teller19,
                 teller20,teller21,teller5,teller6,teller41,teller23,teller24,teller26,teller25,teller27,teller28,
                  teller29,teller42,teller39,teller7,teller8,teller30,teller9,teller10,teller31,teller32,teller11,
                  teller12,teller33,teller13,teller36,teller37,teller34,teller35,teller14,teller38]
fig, ax = plt.subplots()
ax.bar(configuration, numberofvalues, color=['purple','purple','purple','magenta', 'red', 'red','darkred','darkred',
                                             'darkred','tomato', 'tomato','tomato', 'tomato','green','green','green',
                                             'lime','darkgreen','lightgreen','lightgreen','mediumseagreen','orange',
                                             'orange','orange','navajowhite','blue','blue','darkcyan','darkcyan',
                                             'cyan','cyan','cyan','cyan','dodgerblue','dodgerblue','dodgerblue',
                                             'navy','navy','navy','navy','deepskyblue','deepskyblue'], 
       align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Number of values',fontsize=20)
ax.set_xlabel('Data set',fontsize=20)
ax.set_xticks(configuration)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ax.set_xticklabels(configuration,rotation=90)
ax.set_title('Number of values over which is averaged to determine residual',fontsize=20)
ax.yaxis.grid(True)
plt.tight_layout(rect=[0, 0, 5, 4])

# %%
# to see the difference in number of values f different datasets
configuration = ['W7Xhis05 104.719','W7Xhis05 110.997','W7Xhis05 665.979','W7Xhis08 104.719','W7Xhms036 104.719',
                 'W7Xhms036 530.418','W7Xhms05 104.719','W7Xhms05 310.957','W7Xhms05 621.914','W7Xhms08 78.832',
                 'W7Xhms08 104.719','W7Xhms08 266.000','W7Xhms08 530.000','W7Xlis05 104.719','W7Xlis05 340.925',
                 'W7Xlis05 681.85','W7Xlis06 104.719','W7Xlis07 104.719','W7Xlis08 90.837','W7Xlis08 104.719',
                 'W7Xlis09 104.719','W7Xlms05 104.719','W7Xlms05 136.837','W7Xlms05 684.184','W7Xlms09 104.719',
                 'W7Xsds025 104.719','W7Xsds025 774.957','W7Xsds036 104.719','W7Xsds036 436.87','W7Xsds05 104.719',
                 'W7Xsds05 130.316','W7Xsds05 260.633','W7Xsds05 621.914','W7Xsds06 104.719','W7Xsds06 138.185',
                 'W7Xsds06 198.992','W7Xsds08 68.805','W7Xsds08 95.562','W7Xsds08 104.719','W7Xsds08 137.61',
                 'W7Xsds09 59.952','W7Xsds09 104.719']
numberofvalues = [finalvaluedata1,finalvaluedata15,finalvaluedata2,finalvaluedata16,finalvaluedata17,finalvaluedata18,finalvaluedata3,finalvaluedata40,finalvaluedata4,finalvaluedata22,finalvaluedata19,
                  finalvaluedata20,finalvaluedata21,finalvaluedata5,finalvaluedata6,finalvaluedata41,finalvaluedata23,finalvaluedata24,finalvaluedata26,finalvaluedata25,finalvaluedata27,finalvaluedata28,
                  finalvaluedata29,finalvaluedata42,finalvaluedata39,finalvaluedata7,finalvaluedata8,finalvaluedata30,finalvaluedata9,finalvaluedata10,finalvaluedata31,finalvaluedata32,finalvaluedata11,
                  finalvaluedata12,finalvaluedata33,finalvaluedata13,finalvaluedata36,finalvaluedata37,finalvaluedata34,finalvaluedata35,finalvaluedata14,finalvaluedata38]
fig, ax = plt.subplots()
ax.bar(configuration, numberofvalues, color=['purple','purple','purple','magenta', 'red', 'red','darkred','darkred',
                                             'darkred','tomato', 'tomato','tomato', 'tomato','green','green','green',
                                             'lime','darkgreen','lightgreen','lightgreen','mediumseagreen','orange',
                                             'orange','orange','navajowhite','blue','blue','darkcyan','darkcyan',
                                             'cyan','cyan','cyan','cyan','dodgerblue','dodgerblue','dodgerblue',
                                             'navy','navy','navy','navy','deepskyblue','deepskyblue'], 
       align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Number of values',fontsize=20)
ax.set_xlabel('Data set',fontsize=20)
ax.set_xticks(configuration)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ax.set_xticklabels(configuration,rotation=90)
ax.set_title('Number of values of dataset',fontsize=20)
ax.yaxis.grid(True)
plt.tight_layout(rect=[0, 0, 5, 4])
