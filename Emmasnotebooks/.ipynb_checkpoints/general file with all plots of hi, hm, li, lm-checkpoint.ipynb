# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data1 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/104.719/gamdiagions_act.dat')
E1 = (data1[:,1]*(1/data1[0, 1]))
e1 = (data1[:,2]*(1/data1[0, 1]))
t1 = data1[:,0]

data2 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/665.979/gamdiagions_act.dat')
E2 = (data2[:,1]*(1/data2[0, 1]))
e2 = (data2[:,2]*(1/data2[0, 1]))
t2 = data2[:,0]

data3 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/104.719/gamdiagions_act.dat')
E3 = (data3[:,1]*(1/data3[0, 1]))
e3 = (data3[:,2]*(1/data3[0, 1]))
t3 = data3[:,0]

data4 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/621.914/gamdiagions_act.dat')
E4 = (data4[:,1]*(1/data4[0, 1]))
e4 = (data4[:,2]*(1/data4[0, 1]))
t4 = data4[:,0]

data5 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/104.719/gamdiagions_act.dat')
E5 = (data5[:,1]*(1/data5[0, 1]))
e5 = (data5[:,2]*(1/data5[0, 1]))
t5 = data5[:,0]

data6 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/340.925/gamdiagions_act.dat')
E6 = (data6[:,1]*(1/data6[0, 1]))
e6 = (data6[:,2]*(1/data6[0, 1]))
t6 = data6[:,0]

data15 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/110.997/gamdiagions_act.dat')
E15 = (data15[:,1]*(1/data15[0, 1]))
e15 = (data15[:,2]*(1/data15[0, 1]))
t15 = data15[:,0]

data16 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis08/GAM/104.719/gamdiagions_act.dat')
E16 = (data16[:,1]*(1/data16[0, 1]))
e16 = (data16[:,2]*(1/data16[0, 1]))
t16 = data16[:,0]

data17 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/104.719/gamdiagions_act.dat')
E17 = (data17[:,1]*(1/data17[0, 1]))
e17 = (data17[:,2]*(1/data17[0, 1]))
t17 = data17[:,0]

data18 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/530.418/gamdiagions_act.dat')
E18 = (data18[:,1]*(1/data18[0, 1]))
e18 = (data18[:,2]*(1/data18[0, 1]))
t18 = data18[:,0]

data19 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/104.719/gamdiagions_act.dat')
E19 = (data19[:,1]*(1/data19[0, 1]))
e19 = (data19[:,2]*(1/data19[0, 1]))
t19 = data19[:,0]

data20 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/266.000/gamdiagions_act.dat')
E20 = (data20[:,1]*(1/data20[0, 1]))
e20 = (data20[:,2]*(1/data20[0, 1]))
t20 = data20[:,0]

data21 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/530.000/gamdiagions_act.dat')
E21 = (data21[:,1]*(1/data21[0, 1]))
e21 = (data21[:,2]*(1/data21[0, 1]))
t21 = data21[:,0]

data22 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/78.832/gamdiagions_act.dat')
E22 = (data22[:,1]*(1/data22[0, 1]))
e22 = (data22[:,2]*(1/data22[0, 1]))
t22 = data22[:,0]

data23 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis06/GAM/104.719/gamdiagions_act.dat')
E23 = (data23[:,1]*(1/data23[0, 1]))
e23 = (data23[:,2]*(1/data23[0, 1]))
t23 = data23[:,0]

data24 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis07/GAM/104.719/gamdiagions_act.dat')
E24 = (data24[:,1]*(1/data24[0, 1]))
e24 = (data24[:,2]*(1/data24[0, 1]))
t24 = data24[:,0]

data25 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/104.719/gamdiagions_act.dat')
E25 = (data25[:,1]*(1/data25[0, 1]))
e25 = (data25[:,2]*(1/data25[0, 1]))
t25 = data25[:,0]

data26 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/90.837/gamdiagions_act.dat')
E26 = (data26[:,1]*(1/data26[0, 1]))
e26 = (data26[:,2]*(1/data26[0, 1]))
t26 = data26[:,0]

data27 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis09/GAM/104.719/gamdiagions_act.dat')
E27 = (data27[:,1]*(1/data27[0, 1]))
e27 = (data27[:,2]*(1/data27[0, 1]))
t27 = data27[:,0]

data28 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/104.719/gamdiagions_act.dat')
E28 = (data28[:,1]*(1/data28[0, 1]))
e28 = (data28[:,2]*(1/data28[0, 1]))
t28 = data28[:,0]

data29 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/136.837/gamdiagions_act.dat')
E29 = (data29[:,1]*(1/data29[0, 1]))
e29 = (data29[:,2]*(1/data29[0, 1]))
t29 = data29[:,0]

#fig, ax1 = plt.subplots(figsize=(13, 7))
#plt.title('W7-X', fontsize=30)
#ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
#ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
#ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])

Q1 = np.sqrt(E1**2+e1**2)
#ax1.plot(t1, e1, linewidth=1, label=('Im W7Xhis05 104.719'))
#ax1.plot(t1, E1, linewidth=1, label=('Re W7Xhis05 104.719'))
#ax1.plot(t1, Q1, linewidth=1, label=('Mod W7Xhis05 104.719'))

Q2 = np.sqrt(E2**2+e2**2)
#ax1.plot(t2, e2, linewidth=1, label=('Im W7Xhis05 665.979'))
#ax1.plot(t2, E2, linewidth=1, label=('Re W7Xhis05 665.979'))
#ax1.plot(t2, Q2, linewidth=1, label=('Mod W7Xhis05 665.979'))

Q3 = np.sqrt(E3**2+e3**2)
#ax1.plot(t3, e3, linewidth=1, label=('Im W7Xhms05 104.719'))
#ax1.plot(t3, E3, linewidth=1, label=('Re W7Xhms05 104.719'))
#ax1.plot(t3, Q3, linewidth=1, label=('Mod W7Xhms05 104.719'))

Q4 = np.sqrt(E4**2+e4**2)
#ax1.plot(t4, e4, linewidth=1, label=('Im W7Xhms05 621.914'),linestyle='dotted')
#ax1.plot(t4, E4, linewidth=1, label=('Re W7Xhms05 621.914'),linestyle='dotted')
#ax1.plot(t4, Q4, linewidth=1, label=('Mod W7Xhms05 621.914'),linestyle='dotted')

Q5 = np.sqrt(E5**2+e5**2)
#ax1.plot(t5, e5, linewidth=1, label=('Im W7Xlis05 104.719'))
#ax1.plot(t5, E5, linewidth=1, label=('Re W7Xlis05 104.719'))
#ax1.plot(t5, Q5, linewidth=1, label=('Mod W7Xlis05 104.719'))

Q6 = np.sqrt(E6**2+e6**2)
#ax1.plot(t6, e6, linewidth=1, label=('Im W7Xlis05 340.925'))
#ax1.plot(t6, E6, linewidth=1, label=('Re W7Xlis05 340.925'))
#ax1.plot(t6, Q6, linewidth=1, label=('Mod W7Xlis05 340.925'))

Q15 = np.sqrt(E15**2+e15**2)
Q16 = np.sqrt(E16**2+e16**2)
Q17 = np.sqrt(E17**2+e17**2)
Q18 = np.sqrt(E18**2+e18**2)
Q19 = np.sqrt(E19**2+e19**2)
Q20 = np.sqrt(E20**2+e20**2)
Q21 = np.sqrt(E21**2+e21**2)
Q22 = np.sqrt(E22**2+e22**2)
Q23 = np.sqrt(E23**2+e23**2)
Q24 = np.sqrt(E24**2+e24**2)
Q25 = np.sqrt(E25**2+e25**2)
Q26 = np.sqrt(E26**2+e26**2)
Q27 = np.sqrt(E27**2+e27**2)
Q28 = np.sqrt(E28**2+e28**2)
Q29 = np.sqrt(E29**2+e29**2)

# %%
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota, s:0.5, $L_{x}$: 104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

Q1 = np.sqrt(E1**2+e1**2)
ax1.plot(t1, e1, linewidth=1, label=('Im W7Xhis05 104.719'))
ax1.plot(t1, E1, linewidth=1, label=('Re W7Xhis05 104.719'))
ax1.plot(t1, Q1, linewidth=1, label=('Mod W7Xhis05 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhis05_104719.pdf', format='pdf', dpi=1200)

fig, ax15 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota, s:0.5, $L_{x}$: 110.997', fontsize=30)
ax15.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax15.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax15.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax15.plot(t15, e15, linewidth=1, label=('Im W7Xhis05 110.997'))
ax15.plot(t15, E15, linewidth=1, label=('Re W7Xhis05 110.997'))
ax15.plot(t15, Q15, linewidth=1, label=('Mod W7Xhis05 110.997'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhis05_110997.pdf', format='pdf', dpi=1200)

fig, ax2 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota, s:0.5, $L_{x}$: 665.979', fontsize=30)
ax2.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax2.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax2.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

Q2 = np.sqrt(E2**2+e2**2)
ax2.plot(t2, e2, linewidth=1, label=('Im W7Xhis05 665.979'))
ax2.plot(t2, E2, linewidth=1, label=('Re W7Xhis05 665.979'))
ax2.plot(t2, Q2, linewidth=1, label=('Mod W7Xhis05 665.979'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhis05_665979.pdf', format='pdf', dpi=1200)

fig, ax16 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota, s:0.8, $L_{x}$: 104.719', fontsize=30)
ax16.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax16.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax16.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax16.plot(t16, e16, linewidth=1, label=('Im W7Xhis08 104.719'))
ax16.plot(t16, E16, linewidth=1, label=('Re W7Xhis08 104.719'))
ax16.plot(t16, Q16, linewidth=1, label=('Mod W7Xhis08 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhis08_104719.pdf', format='pdf', dpi=1200)

fig, ax17 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.36, $L_{x}$: 104.719', fontsize=30)
ax17.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax17.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax17.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax17.plot(t17, e17, linewidth=1, label=('Im W7Xhms036 104.719'))
ax17.plot(t17, E17, linewidth=1, label=('Re W7Xhms036 104.719'))
ax17.plot(t17, Q17, linewidth=1, label=('Mod W7Xhms036 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms036_104719.pdf', format='pdf', dpi=1200)

fig, ax18 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.36, $L_{x}$: 530.418', fontsize=30)
ax18.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax18.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax18.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax18.plot(t18, e18, linewidth=1, label=('Im W7Xhms036 530.418'))
ax18.plot(t18, E18, linewidth=1, label=('Re W7Xhms036 530.418'))
ax18.plot(t18, Q18, linewidth=1, label=('Mod W7Xhms036 530.418'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms036_530418.pdf', format='pdf', dpi=1200)

fig, ax3 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.5, $L_{x}$: 104.719', fontsize=30)
ax3.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax3.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax3.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

Q3 = np.sqrt(E3**2+e3**2)
ax3.plot(t3, e3, linewidth=1, label=('Im W7Xhms05 104.719'))
ax3.plot(t3, E3, linewidth=1, label=('Re W7Xhms05 104.719'))
ax3.plot(t3, Q3, linewidth=1, label=('Mod W7Xhms05 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms05_104719.pdf', format='pdf', dpi=1200)

fig, ax4 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.5, $L_{x}$: 621.914', fontsize=30)
ax4.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax4.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax4.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

Q4 = np.sqrt(E4**2+e4**2)
ax4.plot(t4, e4, linewidth=1, label=('Im W7Xhms05 621.914'))
ax4.plot(t4, E4, linewidth=1, label=('Re W7Xhms05 621.914'))
ax4.plot(t4, Q4, linewidth=1, label=('Mod W7Xhms05 621.914'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms05_621914.pdf', format='pdf', dpi=1200)

fig, ax22 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.8, $L_{x}$: 78.832', fontsize=30)
ax22.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax22.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax22.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax22.plot(t22, e22, linewidth=1, label=('Im W7Xhms08 78.832'))
ax22.plot(t22, E22, linewidth=1, label=('Re W7Xhms08 78.832'))
ax22.plot(t22, Q22, linewidth=1, label=('Mod W7Xhms08 78.832'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms08_78832.pdf', format='pdf', dpi=1200)

fig, ax19 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.8, $L_{x}$: 104.719', fontsize=30)
ax19.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax19.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax19.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax19.plot(t19, e19, linewidth=1, label=('Im W7Xhms08 104.719'))
ax19.plot(t19, E19, linewidth=1, label=('Re W7Xhms08 104.719'))
ax19.plot(t19, Q19, linewidth=1, label=('Mod W7Xhms08 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms08_104719.pdf', format='pdf', dpi=1200)

fig, ax20 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.8, $L_{x}$: 266.000', fontsize=30)
ax20.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax20.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax20.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax20.plot(t20, e20, linewidth=1, label=('Im W7Xhms08 266.000'))
ax20.plot(t20, E20, linewidth=1, label=('Re W7Xhms08 266.000'))
ax20.plot(t20, Q20, linewidth=1, label=('Mod W7Xhms08 266.000'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms08_266000.pdf', format='pdf', dpi=1200)

fig, ax21 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror, s:0.8, $L_{x}$: 530.000', fontsize=30)
ax21.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax21.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax21.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax21.plot(t21, e21, linewidth=1, label=('Im W7Xhms08 530.000'))
ax21.plot(t21, E21, linewidth=1, label=('Re W7Xhms08 530.000'))
ax21.plot(t21, Q21, linewidth=1, label=('Mod W7Xhms08 530.000'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xhms08_530000.pdf', format='pdf', dpi=1200)

fig, ax5 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.5, $L_{x}$: 104.719', fontsize=30)
ax5.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax5.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax5.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

Q5 = np.sqrt(E5**2+e5**2)
ax5.plot(t5, e5, linewidth=1, label=('Im W7Xlis05 104.719'))
ax5.plot(t5, E5, linewidth=1, label=('Re W7Xlis05 104.719'))
ax5.plot(t5, Q5, linewidth=1, label=('Mod W7Xlis05 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis05_104719.pdf', format='pdf', dpi=1200)

fig, ax6 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.5, $L_{x}$: 340.925', fontsize=30)
ax6.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax6.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax6.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

Q6 = np.sqrt(E6**2+e6**2)
ax6.plot(t6, e6, linewidth=1, label=('Im W7Xlis05 340.925'))
ax6.plot(t6, E6, linewidth=1, label=('Re W7Xlis05 340.925'))
ax6.plot(t6, Q6, linewidth=1, label=('Mod W7Xlis05 340.925'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis05_340925.pdf', format='pdf', dpi=1200)

fig, ax23 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.6, $L_{x}$: 104.719', fontsize=30)
ax23.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax23.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax23.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax23.plot(t23, e23, linewidth=1, label=('Im W7Xlis06 104.719'))
ax23.plot(t23, E23, linewidth=1, label=('Re W7Xlis06 104.719'))
ax23.plot(t23, Q23, linewidth=1, label=('Mod W7Xlis06 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis06_104719.pdf', format='pdf', dpi=1200)

fig, ax24 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.7, $L_{x}$: 104.719', fontsize=30)
ax24.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax24.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax24.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax24.plot(t24, e24, linewidth=1, label=('Im W7Xlis07 104.719'))
ax24.plot(t24, E24, linewidth=1, label=('Re W7Xlis07 104.719'))
ax24.plot(t24, Q24, linewidth=1, label=('Mod W7Xlis07 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis07_104719.pdf', format='pdf', dpi=1200)

fig, ax26 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.8, $L_{x}$: 90.837', fontsize=30)
ax26.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax26.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax26.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax26.plot(t26, e26, linewidth=1, label=('Im W7Xlis08 90.837'))
ax26.plot(t26, E26, linewidth=1, label=('Re W7Xlis08 90.837'))
ax26.plot(t26, Q26, linewidth=1, label=('Mod W7Xlis08 90.837'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis08_90837.pdf', format='pdf', dpi=1200)

fig, ax25 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.8, $L_{x}$: 104.719', fontsize=30)
ax25.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax25.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax25.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax25.plot(t25, e25, linewidth=1, label=('Im W7Xlis08 104.719'))
ax25.plot(t25, E25, linewidth=1, label=('Re W7Xlis08 104.719'))
ax25.plot(t25, Q25, linewidth=1, label=('Mod W7Xlis08 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis08_104719.pdf', format='pdf', dpi=1200)

fig, ax27 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota, s:0.9, $L_{x}$: 104.719', fontsize=30)
ax27.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax27.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax27.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax27.plot(t27, e27, linewidth=1, label=('Im W7Xlis09 104.719'))
ax27.plot(t27, E27, linewidth=1, label=('Re W7Xlis09 104.719'))
ax27.plot(t27, Q27, linewidth=1, label=('Mod W7Xlis09 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlis09_104719.pdf', format='pdf', dpi=1200)

fig, ax28 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Mirror, s:0.5, $L_{x}$: 104.719', fontsize=30)
ax28.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax28.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax28.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax28.plot(t28, e28, linewidth=1, label=('Im W7Xlms05 104.719'))
ax28.plot(t28, E28, linewidth=1, label=('Re W7Xlms05 104.719'))
ax28.plot(t28, Q28, linewidth=1, label=('Mod W7Xlms05 104.719'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlms05_104719.pdf', format='pdf', dpi=1200)

fig, ax29 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Mirror, s:0.5, $L_{x}$: 136.837', fontsize=30)
ax29.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax29.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax29.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,4100])

ax29.plot(t29, e29, linewidth=1, label=('Im W7Xlms05 136.837'))
ax29.plot(t29, E29, linewidth=1, label=('Re W7Xlms05 136.837'))
ax29.plot(t29, Q29, linewidth=1, label=('Mod W7Xlms05 136.837'))
plt.legend()
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xlms05_136837.pdf', format='pdf', dpi=1200)
