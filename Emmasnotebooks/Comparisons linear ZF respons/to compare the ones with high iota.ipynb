# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data1 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/104.719/gamdiagions_act.dat')
E1 = (data1[:,1]*(1/data1[0, 1]))
e1 = (data1[:,2]*(1/data1[0, 1]))
t1 = data1[:,0]

data2 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/665.979/gamdiagions_act.dat')
E2 = (data2[:,1]*(1/data2[0, 1]))
e2 = (data2[:,2]*(1/data2[0, 1]))
t2 = data2[:,0]

data15 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/110.997/gamdiagions_act.dat')
E15 = (data15[:,1]*(1/data15[0, 1]))
e15 = (data15[:,2]*(1/data15[0, 1]))
t15 = data15[:,0]

data16 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis08/GAM/104.719/gamdiagions_act.dat')
E16 = (data16[:,1]*(1/data16[0, 1]))
e16 = (data16[:,2]*(1/data16[0, 1]))
t16 = data16[:,0]

Q1 = np.sqrt(E1**2+e1**2)
Q2 = np.sqrt(E2**2+e2**2)
Q15 = np.sqrt(E15**2+e15**2)
Q16 = np.sqrt(E16**2+e16**2)

# %%
#plot of the modulus
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota Modulus of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,2200])

ax1.plot(t1, Q1, linewidth=2, label=('Mod W7Xhis05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t2, Q2, linewidth=2, label=('Mod W7Xhis05 665.979'),color='blue',linestyle='dashed')
ax1.plot(t15, Q15, linewidth=2, label=('Mod W7Xhis05 110.997'),color='blue')
ax1.plot(t16, Q16, linewidth=2, label=('Mod W7Xhis08 104.719'),color='pink',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of the real part
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota real part of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,2200])

ax1.plot(t1, E1, linewidth=2, label=('Re W7Xhis05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t2, E2, linewidth=2, label=('Re W7Xhis05 665.979'),color='blue',linestyle='dashed')
ax1.plot(t15, E15, linewidth=2, label=('Re W7Xhis05 110.997'),color='blue')
ax1.plot(t16, E16, linewidth=2, label=('Re W7Xhis08 104.719'),color='pink',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of the imaginary part
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota imaginary part of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,2200])

ax1.plot(t1, e1, linewidth=2, label=('Im W7Xhis05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t2, e2, linewidth=2, label=('Im W7Xhis05 665.979'),color='blue',linestyle='dashed')
ax1.plot(t15, e15, linewidth=2, label=('Im W7Xhis05 110.997'),color='blue')
ax1.plot(t16, e16, linewidth=2, label=('Im W7Xhis08 104.719'),color='pink',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of high iota s=0.5
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Iota s=0.5', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

#ax1.plot(t1, e1, linewidth=1, label=('Im W7Xhis05 104.719'),color='red',linestyle='dotted')
ax1.plot(t1, E1, linewidth=1, label=('Re W7Xhis05 104.719'),color='red',linestyle='dashed')
#ax1.plot(t1, Q1, linewidth=1, label=('Mod W7Xhis05 104.719'),color='red')
#ax1.plot(t15, e15, linewidth=1, label=('Im W7Xhis05 110.997'),color='blue',linestyle='dotted')
ax1.plot(t15, E15, linewidth=1, label=('Re W7Xhis05 110.997'),color='blue',linestyle='dashed')
#ax1.plot(t15, Q15, linewidth=1, label=('Mod W7Xhis05 110.997'),color='blue')
#ax1.plot(t2, e2, linewidth=1, label=('Im W7Xhis05 665.979'),color='green',linestyle='dotted')
ax1.plot(t2, E2, linewidth=1, label=('Re W7Xhis05 665.979'),color='green',linestyle='dashed')
#ax1.plot(t2, Q2, linewidth=1, label=('Mod W7Xhis05 665.979'),color='green')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)
