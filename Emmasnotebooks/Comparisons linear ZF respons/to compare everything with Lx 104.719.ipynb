# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data1 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/104.719/gamdiagions_act.dat')
E1 = (data1[:,1]*(1/data1[0, 1]))
e1 = (data1[:,2]*(1/data1[0, 1]))
t1 = data1[:,0]

data3 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/104.719/gamdiagions_act.dat')
E3 = (data3[:,1]*(1/data3[0, 1]))
e3 = (data3[:,2]*(1/data3[0, 1]))
t3 = data3[:,0]

data5 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/104.719/gamdiagions_act.dat')
E5 = (data5[:,1]*(1/data5[0, 1]))
e5 = (data5[:,2]*(1/data5[0, 1]))
t5 = data5[:,0]

data7 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/104.719/gamdiagions_act.dat')
E7 = (data7[:,1]*(1/data7[0, 1]))
e7 = (data7[:,2]*(1/data7[0, 1]))
t7 = data7[:,0]

data10 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/104.719/gamdiagions_act.dat')
E10 = (data10[:,1]*(1/data10[0, 1]))
e10 = (data10[:,2]*(1/data10[0, 1]))
t10 = data10[:,0]

data12 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/104.719/gamdiagions_act.dat')
E12 = (data12[:,1]*(1/data12[0, 1]))
e12 = (data12[:,2]*(1/data12[0, 1]))
t12 = data12[:,0]

data16 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis08/GAM/104.719/gamdiagions_act.dat')
E16 = (data16[:,1]*(1/data16[0, 1]))
e16 = (data16[:,2]*(1/data16[0, 1]))
t16 = data16[:,0]

data17 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/104.719/gamdiagions_act.dat')
E17 = (data17[:,1]*(1/data17[0, 1]))
e17 = (data17[:,2]*(1/data17[0, 1]))
t17 = data17[:,0]

data19 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/104.719/gamdiagions_act.dat')
E19 = (data19[:,1]*(1/data19[0, 1]))
e19 = (data19[:,2]*(1/data19[0, 1]))
t19 = data19[:,0]

data23 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis06/GAM/104.719/gamdiagions_act.dat')
E23 = (data23[:,1]*(1/data23[0, 1]))
e23 = (data23[:,2]*(1/data23[0, 1]))
t23 = data23[:,0]

data24 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis07/GAM/104.719/gamdiagions_act.dat')
E24 = (data24[:,1]*(1/data24[0, 1]))
e24 = (data24[:,2]*(1/data24[0, 1]))
t24 = data24[:,0]

data25 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/104.719/gamdiagions_act.dat')
E25 = (data25[:,1]*(1/data25[0, 1]))
e25 = (data25[:,2]*(1/data25[0, 1]))
t25 = data25[:,0]

data27 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis09/GAM/104.719/gamdiagions_act.dat')
E27 = (data27[:,1]*(1/data27[0, 1]))
e27 = (data27[:,2]*(1/data27[0, 1]))
t27 = data27[:,0]

data28 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/104.719/gamdiagions_act.dat')
E28 = (data28[:,1]*(1/data28[0, 1]))
e28 = (data28[:,2]*(1/data28[0, 1]))
t28 = data28[:,0]

data30 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/104.719/gamdiagions_act.dat')
E30 = (data30[:,1]*(1/data30[0, 1]))
e30 = (data30[:,2]*(1/data30[0, 1]))
t30 = data30[:,0]

data34 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/104.719/gamdiagions_act.dat')
E34 = (data34[:,1]*(1/data34[0, 1]))
e34 = (data34[:,2]*(1/data34[0, 1]))
t34 = data34[:,0]

data38 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/104.719/gamdiagions_act.dat')
E38 = (data38[:,1]*(1/data38[0, 1]))
e38 = (data38[:,2]*(1/data38[0, 1]))
t38 = data38[:,0]

# %%
#plot for all the moduli
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X modulus of $\phi$ with $L_x$=104.719 for different configurations', fontsize=20)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,600])

Q1 = np.sqrt(E1**2+e1**2)
ax1.plot(t1, Q1, linewidth=1, label=('Mod W7Xhis05 104.719'),color='grey',linestyle='dashed')

Q3 = np.sqrt(E3**2+e3**2)
ax1.plot(t3, Q3, linewidth=1, label=('Mod W7Xhms05 104.719'),color='blue',linestyle='dashed')

Q5 = np.sqrt(E5**2+e5**2)
ax1.plot(t5, Q5, linewidth=1, label=('Mod W7Xlis05 104.719'),color='pink',linestyle='dashed')

Q7 = np.sqrt(E7**2+e7**2)
#ax1.plot(t7, Q7, linewidth=1, label=('Mod W7Xsds025 104.719'),color='green')

Q10 = np.sqrt(E10**2+e10**2)
ax1.plot(t10, Q10, linewidth=1, label=('Mod W7Xsds05 104.719'),color='green',linestyle='dashed')

Q12 = np.sqrt(E12**2+e12**2)
#ax1.plot(t12, Q12, linewidth=1, label=('Mod W7Xsds06 104.719'),color='green',linestyle='-.')

Q16 = np.sqrt(E16**2+e16**2)
Q17 = np.sqrt(E17**2+e17**2)
Q19 = np.sqrt(E19**2+e19**2)
Q23 = np.sqrt(E23**2+e23**2)
Q24 = np.sqrt(E24**2+e24**2)
Q25 = np.sqrt(E25**2+e25**2)
Q27 = np.sqrt(E27**2+e27**2)
Q28 = np.sqrt(E28**2+e28**2)
Q30 = np.sqrt(E30**2+e30**2)
Q34 = np.sqrt(E34**2+e34**2)
Q38 = np.sqrt(E38**2+e38**2)

#ax1.plot(t16, Q16, linewidth=1, label=('Mod W7Xhis08 104.719'),color='grey',linestyle='dotted')
#ax1.plot(t17, Q17, linewidth=2, label=('Mod W7Xhms036 104.719'),color='blue')
#ax1.plot(t19, Q19, linewidth=1, label=('Mod W7Xhms08 104.719'),color='blue',linestyle='dotted')
#ax1.plot(t23, Q23, linewidth=1, label=('Mod W7Xlis06 104.719'),color='pink',linestyle='-.')
#ax1.plot(t24, Q24, linewidth=1, label=('Mod W7Xlis07 104.719'),color='pink')
#ax1.plot(t25, Q25, linewidth=1, label=('Mod W7Xlis08 104.719'),color='pink',linestyle='dotted')
#ax1.plot(t27, Q27, linewidth=2, label=('Mod W7Xlis09 104.719'),color='pink')
ax1.plot(t28, Q28, linewidth=1, label=('Mod W7Xlms05 104.719'),color='red',linestyle='dashed')
#ax1.plot(t30, Q30, linewidth=2, label=('Mod W7Xsds036 104.719'),color='green')
#ax1.plot(t34, Q34, linewidth=1, label=('Mod W7Xsds08 104.719'),color='green',linestyle='dotted')
#ax1.plot(t38, Q38, linewidth=1, label=('Mod W7Xsds09 104.719'),color='darkgreen')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)    

integ11 = (np.trapz(Q1,t1))
integ31 = (np.trapz(Q3,t3))
integ51 = (np.trapz(Q5,t5))
integ71 = (np.trapz(Q7,t7))
#integ101 = (np.trapz(Q10,t10))
integ121 = (np.trapz(Q12,t12))

#print("Integral over Q for W7Xhis05 104.719 is:", integ11)
#print("Integral over Q for W7Xhms05 104.719 is:", integ31)
#print("Integral over Q for W7Xlis05 104.719 is:", integ51)
#print("Integral over Q for W7Xsds025 104.719 is:", integ71)
#print("Integral over Q for W7Xsds05 104.719 is:", integ101)
#print("Integral over Q for W7Xsds06 104.719 is:", integ121)

# %%
#plot for all the real parts
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X real parts of $\phi$ with $L_x$=104.719 for different configurations', fontsize=20)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

ax1.plot(t1, E1, linewidth=1, label=('Re W7Xhis05 104.719'),color='grey',linestyle='dashed')
#ax1.plot(t3, E3, linewidth=1, label=('Re W7Xhms05 104.719'),color='blue',linestyle='dashed')
#ax1.plot(t5, E5, linewidth=1, label=('Re W7Xlis05 104.719'),color='pink',linestyle='dashed')
#ax1.plot(t7, E7, linewidth=1, label=('Re W7Xsds025 104.719'),color='green')
#ax1.plot(t10, E10, linewidth=1, label=('Re W7Xsds05 104.719'),color='green',linestyle='dashed')
#ax1.plot(t12, E12, linewidth=1, label=('Re W7Xsds06 104.719'),color='green',linestyle='-.')
ax1.plot(t16, E16, linewidth=1, label=('Re W7Xhis08 104.719'),color='grey',linestyle='dotted')
#ax1.plot(t17, E17, linewidth=2, label=('Re W7Xhms036 104.719'),color='blue')
#ax1.plot(t19, E19, linewidth=1, label=('Re W7Xhms08 104.719'),color='blue',linestyle='dotted')
#ax1.plot(t23, E23, linewidth=1, label=('Re W7Xlis06 104.719'),color='pink',linestyle='-.')
#ax1.plot(t24, E24, linewidth=1, label=('Re W7Xlis07 104.719'),color='pink')
#ax1.plot(t25, E25, linewidth=1, label=('Re W7Xlis08 104.719'),color='pink',linestyle='dotted')
#ax1.plot(t27, E27, linewidth=2, label=('Re W7Xlis09 104.719'),color='pink')
#ax1.plot(t28, E28, linewidth=1, label=('Re W7Xlms05 104.719'),color='red',linestyle='dashed')
#ax1.plot(t30, E30, linewidth=2, label=('Re W7Xsds036 104.719'),color='green')
#ax1.plot(t34, E34, linewidth=1, label=('Re W7Xsds08 104.719'),color='green',linestyle='dotted')
#ax1.plot(t38, E38, linewidth=1, label=('Re W7Xsds09 104.719'),color='darkgreen')


plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)    


integ12 = (np.trapz(E1,t1))
integ32 = (np.trapz(E3,t3))
integ52 = (np.trapz(E5,t5))
integ72 = (np.trapz(E7,t7))
#integ102 = (np.trapz(E10,t10))
integ122 = (np.trapz(E12,t12))

#print("Integral over E for W7Xhis05 104.719 is:", integ12)
#print("Integral over E for W7Xhms05 104.719 is:", integ32)
#print("Integral over E for W7Xlis05 104.719 is:", integ52)
#print("Integral over E for W7Xsds025 104.719 is:", integ72)
#print("Integral over E for W7Xsds05 104.719 is:", integ102)
#print("Integral over E for W7Xsds06 104.719 is:", integ122)

# %%
#plot for all the imaginairy parts
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X imaginary parts of $\phi$ with $L_x$=104.719 for different configurations', fontsize=20)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

ax1.plot(t1, e1, linewidth=1, label=('Im W7Xhis05 104.719'),color='grey',linestyle='dashed')
#ax1.plot(t3, e3, linewidth=1, label=('Im W7Xhms05 104.719'),color='blue',linestyle='dashed')
#ax1.plot(t5, e5, linewidth=1, label=('Im W7Xlis05 104.719'),color='pink',linestyle='dashed')
#ax1.plot(t7, e7, linewidth=1, label=('Im W7Xsds025 104.719'),color='green')
#ax1.plot(t10, e10, linewidth=1, label=('Im W7Xsds05 104.719'),color='green',linestyle='dashed')
#ax1.plot(t12, e12, linewidth=1, label=('Im W7Xsds06 104.719'),color='green',linestyle='-.')
#ax1.plot(t17, e17, linewidth=2, label=('Im W7Xhms036 104.719'),color='blue')
ax1.plot(t16, e16, linewidth=1, label=('Im W7Xhis08 104.719'),color='grey',linestyle='dotted')
#ax1.plot(t19, e19, linewidth=1, label=('Im W7Xhms08 104.719'),color='blue',linestyle='dotted')
#ax1.plot(t23, e23, linewidth=1, label=('Im W7Xlis06 104.719'),color='pink',linestyle='-.')
#ax1.plot(t24, e24, linewidth=1, label=('Im W7Xlis07 104.719'),color='pink')
#ax1.plot(t25, e25, linewidth=1, label=('Im W7Xlis08 104.719'),color='pink',linestyle='dotted')
#ax1.plot(t27, e27, linewidth=2, label=('Im W7Xlis09 104.719'),color='pink')
#ax1.plot(t28, e28, linewidth=1, label=('Im W7Xlms05 104.719'),color='red',linestyle='dashed')
#ax1.plot(t30, e30, linewidth=2, label=('Im W7Xsds036 104.719'),color='green')
#ax1.plot(t34, e34, linewidth=1, label=('Im W7Xsds08 104.719'),color='green',linestyle='dotted')
#ax1.plot(t38, e38, linewidth=1, label=('Im W7Xsds09 104.719'),color='darkgreen')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)    

integ13 = (np.trapz(e1,t1))
integ33 = (np.trapz(e3,t3))
integ53 = (np.trapz(e5,t5))
integ73 = (np.trapz(e7,t7))
#integ103 = (np.trapz(e10,t10))
integ123 = (np.trapz(e12,t12))

#print("Integral over e for W7Xhis05 104.719 is:", integ13)
#print("Integral over e for W7Xhms05 104.719 is:", integ33)
#print("Integral over e for W7Xlis05 104.719 is:", integ53)
#print("Integral over e for W7Xsds025 104.719 is:", integ73)
#print("Integral over e for W7Xsds05 104.719 is:", integ103)
#print("Integral over e for W7Xsds06 104.719 is:", integ123)

# %%
#plot for comparing different s coordinates modulus and real and imaginary part of standard config
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X Standard configuration $L_x$=104.719 Mod', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.ylim([0,0.6])
plt.xlim([0,800])

ax1.plot(t7, Q7, linewidth=2, label=('Mod W7Xsds025 104.719'),color='orange')
ax1.plot(t10, Q10, linewidth=2, label=('Mod W7Xsds05 104.719'),color='blue')
ax1.plot(t12, Q12, linewidth=2, label=('Mod W7Xsds06 104.719'),color='grey')
ax1.plot(t30, Q30, linewidth=2, label=('Mod W7Xsds036 104.719'),color='red')
ax1.plot(t34, Q34, linewidth=2, label=('Mod W7Xsds08 104.719'),color='pink')
ax1.plot(t38, Q38, linewidth=2, label=('Mod W7Xsds09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)    



fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X Standard configuration $L_x$=104.719 Im', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.ylim([-0.3,0.6])
plt.xlim([0,800])

ax1.plot(t7, e7, linewidth=1, label=('Im W7Xsds025 104.719'),color='orange')
ax1.plot(t10, e10, linewidth=1, label=('Im W7Xsds05 104.719'),color='blue')
ax1.plot(t12, e12, linewidth=1, label=('Im W7Xsds06 104.719'),color='grey')
ax1.plot(t30, e30, linewidth=1, label=('Im W7Xsds036 104.719'),color='red')
ax1.plot(t34, e34, linewidth=1, label=('Im W7Xsds08 104.719'),color='pink')
ax1.plot(t38, e38, linewidth=1, label=('Im W7Xsds09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot for comparing different s coordinates modulus of High Mirror
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X High Mirror $L_x$=104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

ax1.plot(t3, Q3, linewidth=2, label=('Mod W7Xhms05 104.719'),color='blue')
ax1.plot(t17, Q17, linewidth=2, label=('Mod W7Xhms036 104.719'),color='red')
ax1.plot(t19, Q19, linewidth=2, label=('Mod W7Xhms08 104.719'),color='pink')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot for comparing different s coordinates modulus of high iota
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X High Iota $L_x$=104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

ax1.plot(t1, Q1, linewidth=2, label=('Mod W7Xhis05 104.719'),color='blue')
ax1.plot(t16, Q16, linewidth=1, label=('Mod W7Xhis08 104.719'),color='pink')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot for comparing different s coordinates modulus of low iota
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X Low Iota $L_x$=104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

ax1.plot(t5, Q5, linewidth=2, label=('Mod W7Xlis05 104.719'),color='blue')
ax1.plot(t23, Q23, linewidth=2, label=('Mod W7Xlis06 104.719'),color='grey')
ax1.plot(t24, Q24, linewidth=2, label=('Mod W7Xlis07 104.719'),color='cyan')
ax1.plot(t25, Q25, linewidth=2, label=('Mod W7Xlis08 104.719'),color='pink')
ax1.plot(t27, Q27, linewidth=2, label=('Mod W7Xlis09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot with everything

################ not yet adjusted with new data sets ##################
fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X $L_x$=104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

Q1 = np.sqrt(E1**2+e1**2)
ax1.plot(t1, e1, linewidth=2, label=('Im W7Xhis05 104.719'),linestyle='dotted',color='grey')
ax1.plot(t1, E1, linewidth=2, label=('Re W7Xhis05 104.719'),linestyle='dashed',color='grey')
ax1.plot(t1, Q1, linewidth=2, label=('Mod W7Xhis05 104.719'),color='grey')

Q3 = np.sqrt(E3**2+e3**2)
ax1.plot(t3, e3, linewidth=2, label=('Im W7Xhms05 104.719'),linestyle='dotted',color='blue')
ax1.plot(t3, E3, linewidth=2, label=('Re W7Xhms05 104.719'),linestyle='dashed',color='blue')
ax1.plot(t3, Q3, linewidth=2, label=('Mod W7Xhms05 104.719'),color='blue')

Q5 = np.sqrt(E5**2+e5**2)
ax1.plot(t5, e5, linewidth=2, label=('Im W7Xlis05 104.719'),linestyle='dotted',color='yellow')
ax1.plot(t5, E5, linewidth=2, label=('Re W7Xlis05 104.719'),linestyle='dashed',color='yellow')
ax1.plot(t5, Q5, linewidth=2, label=('Mod W7Xlis05 104.719'),color='yellow')

Q7 = np.sqrt(E7**2+e7**2)
ax1.plot(t7, e7, linewidth=2, label=('Im W7Xsds025 104.719'),linestyle='dotted',color='green')
ax1.plot(t7, E7, linewidth=2, label=('Re W7Xsds025 104.719'),linestyle='dashed',color='green')
ax1.plot(t7, Q7, linewidth=2, label=('Mod W7Xsds025 104.719'),color='green')

#####onderstaande data (10) is niet van sds05 maar van hms05####
#Q10 = np.sqrt(E10**2+e10**2)
#ax1.plot(t10, e10, linewidth=2, label=('Im W7Xsds05 104.719'),linestyle='dotted')
#ax1.plot(t10, E10, linewidth=2, label=('Re W7Xsds05 104.719'),linestyle='dotted')
#ax1.plot(t10, Q10, linewidth=2, label=('Mod W7Xsds05 104.719'),linestyle='dotted')

Q12 = np.sqrt(E12**2+e12**2)
ax1.plot(t12, e12, linewidth=2, label=('Im W7Xsds06 104.719'),linestyle='dotted',color='red')
ax1.plot(t12, E12, linewidth=2, label=('Re W7Xsds06 104.719'),linestyle='dashed',color='red')
ax1.plot(t12, Q12, linewidth=2, label=('Mod W7Xsds06 104.719'),color='red')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)    

integ11 = (np.trapz(Q1,t1))
integ12 = (np.trapz(E1,t1))
integ13 = (np.trapz(e1,t1))
integ31 = (np.trapz(Q3,t3))
integ32 = (np.trapz(E3,t3))
integ33 = (np.trapz(e3,t3))
integ51 = (np.trapz(Q5,t5))
integ52 = (np.trapz(E5,t5))
integ53 = (np.trapz(e5,t5))
integ71 = (np.trapz(Q7,t7))
integ72 = (np.trapz(E7,t7))
integ73 = (np.trapz(e7,t7))
#integ101 = (np.trapz(Q10,t10))
#integ102 = (np.trapz(E10,t10))
#integ103 = (np.trapz(e10,t10))
integ121 = (np.trapz(Q12,t12))
integ122 = (np.trapz(E12,t12))
integ123 = (np.trapz(e12,t12))

#print("Integral over Q for W7Xhis05 104.719 is:", integ11)
#print("Integral over Q for W7Xhms05 104.719 is:", integ31)
#print("Integral over Q for W7Xlis05 104.719 is:", integ51)
#print("Integral over Q for W7Xsds025 104.719 is:", integ71)
#print("Integral over Q for W7Xsds05 104.719 is:", integ101)
#print("Integral over Q for W7Xsds06 104.719 is:", integ121)

#print("Integral over E for W7Xhis05 104.719 is:", integ12)
#print("Integral over E for W7Xhms05 104.719 is:", integ32)
#print("Integral over E for W7Xlis05 104.719 is:", integ52)
#print("Integral over E for W7Xsds025 104.719 is:", integ72)
#print("Integral over E for W7Xsds05 104.719 is:", integ102)
#print("Integral over E for W7Xsds06 104.719 is:", integ122)

#print("Integral over e for W7Xhis05 104.719 is:", integ13)
#print("Integral over e for W7Xhms05 104.719 is:", integ33)
#print("Integral over e for W7Xlis05 104.719 is:", integ53)
#print("Integral over e for W7Xsds025 104.719 is:", integ73)
#print("Integral over e for W7Xsds05 104.719 is:", integ103)
#print("Integral over e for W7Xsds06 104.719 is:", integ123)

# %%
#plot for comparing different s coordinates im part

###################### not yet adjusted with new data sets ##############

fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X $L_x$=104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

Q1 = np.sqrt(E1**2+e1**2)
ax1.plot(t1, e1, linewidth=2, label=('Im W7Xhis05 104.719'),color='yellow',linestyle='dashed')
#ax1.plot(t1, E1, linewidth=2, label=('Re W7Xhis05 104.719'),linestyle='dashed',color='grey')
#ax1.plot(t1, Q1, linewidth=2, label=('Mod W7Xhis05 104.719'),color='yellow',linestyle='dashed')

Q3 = np.sqrt(E3**2+e3**2)
ax1.plot(t3, e3, linewidth=2, label=('Im W7Xhms05 104.719'),linestyle='dotted',color='yellow')
#ax1.plot(t3, E3, linewidth=2, label=('Re W7Xhms05 104.719'),linestyle='dashed',color='blue')
#ax1.plot(t3, Q3, linewidth=2, label=('Mod W7Xhms05 104.719'),color='yellow',linestyle='dotted')

Q5 = np.sqrt(E5**2+e5**2)
ax1.plot(t5, e5, linewidth=2, label=('Im W7Xlis05 104.719'),color='yellow')
#ax1.plot(t5, E5, linewidth=2, label=('Re W7Xlis05 104.719'),linestyle='dashed',color='yellow')
#ax1.plot(t5, Q5, linewidth=2, label=('Mod W7Xlis05 104.719'),color='yellow')

Q7 = np.sqrt(E7**2+e7**2)
ax1.plot(t7, e7, linewidth=2, label=('Im W7Xsds025 104.719'),color='green')
#ax1.plot(t7, E7, linewidth=2, label=('Re W7Xsds025 104.719'),linestyle='dashed',color='green')
#ax1.plot(t7, Q7, linewidth=2, label=('Mod W7Xsds025 104.719'),color='green')

#####onderstaande data (10) is niet van sds05 maar van hms05####
#Q10 = np.sqrt(E10**2+e10**2)
#ax1.plot(t10, e10, linewidth=2, label=('Im W7Xsds05 104.719'),linestyle='dotted')
#ax1.plot(t10, E10, linewidth=2, label=('Re W7Xsds05 104.719'),linestyle='dotted')
#ax1.plot(t10, Q10, linewidth=2, label=('Mod W7Xsds05 104.719'),linestyle='dotted')

Q12 = np.sqrt(E12**2+e12**2)
ax1.plot(t12, e12, linewidth=2, label=('Im W7Xsds06 104.719'),color='red')
#ax1.plot(t12, E12, linewidth=2, label=('Re W7Xsds06 104.719'),linestyle='dashed',color='red')
#ax1.plot(t12, Q12, linewidth=2, label=('Mod W7Xsds06 104.719'),color='red')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot for comparing different s coordinates real part

###################### not yet adjusted with new data sets ##############

fig, ax1 = plt.subplots(figsize=(14, 8))
plt.title('W7-X $L_x$=104.719', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1250])

Q1 = np.sqrt(E1**2+e1**2)
#ax1.plot(t1, e1, linewidth=2, label=('Im W7Xhis05 104.719'),linestyle='dotted',color='grey')
ax1.plot(t1, E1, linewidth=2, label=('Re W7Xhis05 104.719'),linestyle='dashed',color='yellow')
#ax1.plot(t1, Q1, linewidth=2, label=('Mod W7Xhis05 104.719'),color='yellow',linestyle='dashed')

Q3 = np.sqrt(E3**2+e3**2)
#ax1.plot(t3, e3, linewidth=2, label=('Im W7Xhms05 104.719'),linestyle='dotted',color='blue')
ax1.plot(t3, E3, linewidth=2, label=('Re W7Xhms05 104.719'),linestyle='dotted',color='yellow')
#ax1.plot(t3, Q3, linewidth=2, label=('Mod W7Xhms05 104.719'),color='yellow',linestyle='dotted')

Q5 = np.sqrt(E5**2+e5**2)
#ax1.plot(t5, e5, linewidth=2, label=('Im W7Xlis05 104.719'),linestyle='dotted',color='yellow')
ax1.plot(t5, E5, linewidth=2, label=('Re W7Xlis05 104.719'),color='yellow')
#ax1.plot(t5, Q5, linewidth=2, label=('Mod W7Xlis05 104.719'),color='yellow')

Q7 = np.sqrt(E7**2+e7**2)
#ax1.plot(t7, e7, linewidth=2, label=('Im W7Xsds025 104.719'),linestyle='dotted',color='green')
ax1.plot(t7, E7, linewidth=2, label=('Re W7Xsds025 104.719'),color='green')
#ax1.plot(t7, Q7, linewidth=2, label=('Mod W7Xsds025 104.719'),color='green')

#####onderstaande data (10) is niet van sds05 maar van hms05####
#Q10 = np.sqrt(E10**2+e10**2)
#ax1.plot(t10, e10, linewidth=2, label=('Im W7Xsds05 104.719'),linestyle='dotted')
#ax1.plot(t10, E10, linewidth=2, label=('Re W7Xsds05 104.719'),linestyle='dotted')
#ax1.plot(t10, Q10, linewidth=2, label=('Mod W7Xsds05 104.719'),linestyle='dotted')

Q12 = np.sqrt(E12**2+e12**2)
#ax1.plot(t12, e12, linewidth=2, label=('Im W7Xsds06 104.719'),linestyle='dotted',color='red')
ax1.plot(t12, E12, linewidth=2, label=('Re W7Xsds06 104.719'),color='red')
#ax1.plot(t12, Q12, linewidth=2, label=('Mod W7Xsds06 104.719'),color='red')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)
