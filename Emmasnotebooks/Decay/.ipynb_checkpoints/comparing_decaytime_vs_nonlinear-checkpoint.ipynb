# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Decay\decay_parameters_of_all_data.ipynb
# Out:
# loading successful!
# C:\Users\s162605\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])

squareroot_TdivZ = [(nonlinT.values[0]/nonlinZ.values[0])**(1/2),(nonlinT.values[1]/nonlinZ.values[1])**(1/2),
                           (nonlinT.values[2]/nonlinZ.values[2])**(1/2),(nonlinT.values[3]/nonlinZ.values[3])**(1/2),
                           (nonlinT.values[4]/nonlinZ.values[4])**(1/2),(nonlinT.values[5]/nonlinZ.values[5])**(1/2),
                           (nonlinT.values[6]/nonlinZ.values[6])**(1/2),(nonlinT.values[7]/nonlinZ.values[7])**(1/2),
                           (nonlinT.values[8]/nonlinZ.values[8])**(1/2),(nonlinT.values[9]/nonlinZ.values[9])**(1/2),
                           (nonlinT.values[10]/nonlinZ.values[10])**(1/2),(nonlinT.values[11]/nonlinZ.values[11])**(1/2),
                           (nonlinT.values[12]/nonlinZ.values[12])**(1/2),(nonlinT.values[13]/nonlinZ.values[13])**(1/2),
                           (nonlinT.values[14]/nonlinZ.values[14])**(1/2),(nonlinT.values[15]/nonlinZ.values[15])**(1/2),
                           (nonlinT.values[16]/nonlinZ.values[16])**(1/2),(nonlinT.values[17]/nonlinZ.values[17])**(1/2),
                           (nonlinT.values[18]/nonlinZ.values[18])**(1/2),(nonlinT.values[19]/nonlinZ.values[19])**(1/2),
                           (nonlinT.values[20]/nonlinZ.values[20])**(1/2),(nonlinT.values[21]/nonlinZ.values[21])**(1/2),
                           (nonlinT.values[22]/nonlinZ.values[22])**(1/2),(nonlinT.values[23]/nonlinZ.values[23])**(1/2),                       
                           (nonlinT.values[24]/nonlinZ.values[24])**(1/2),(nonlinT.values[25]/nonlinZ.values[25])**(1/2),
                           (nonlinT.values[26]/nonlinZ.values[26])**(1/2),(nonlinT.values[27]/nonlinZ.values[27])**(1/2),
                           (nonlinT.values[28]/nonlinZ.values[28])**(1/2)]

# %%
import matplotlib.markers
######## index numbers really important to check
plt.scatter(bvalues[1],squareroot_TdivZ[1],color='magenta',label='hi, $s=0.5 $, $L_x=110.997$ $\omega_T=1.3$', marker='+',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[1],squareroot_TdivZ[2], color='magenta',label='hi, $s=0.5 $, $L_x=110.997$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[2],squareroot_TdivZ[0],color='purple',label='hi, $s=0.5$, $L_x=665.979$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.scatter(bvalues[7],squareroot_TdivZ[3],color='darkred',label='hm, $s=0.5 $, $L_x=310.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],squareroot_TdivZ[4], color='darkred',label='hm, $s=0.5 $, $L_x=310.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],squareroot_TdivZ[5], color='darkred',label='hm, $s=0.5 $, $L_x=310.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[9],squareroot_TdivZ[6],color='red',label='hm, $s=0.8 $, $L_x=78.832$ $\omega_T=2.3$', marker='x',s=400, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[14],squareroot_TdivZ[7],color='green',label='li, $s=0.5 $, $L_x=340.925$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[15],squareroot_TdivZ[8],color='lightgreen',label='li, $s=0.5 $, $L_x=681.850$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[18],squareroot_TdivZ[10], color='lime',label='li, $s=0.8 $, $L_x=90.837$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[22],squareroot_TdivZ[12],color='orange',label='lm, $s=0.5 $, $L_x=136.837$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[23],squareroot_TdivZ[11],color='navajowhite',label='lm, $s=0.5 $, $L_x=684.184$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[26],squareroot_TdivZ[13],color='blue',label='sd, $s=0.25$,  $L_x=774.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[26],squareroot_TdivZ[14], color='blue',label='sd, $s=0.25$,  $L_x=774.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[26],squareroot_TdivZ[15], color='blue',label='sd, $s=0.25$,  $L_x=774.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[28],squareroot_TdivZ[16],color='grey',label='sd, $s=0.36$,  $L_x=436.870$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[28],squareroot_TdivZ[17], color='grey',label='sd, $s=0.36$,  $L_x=436.87$  $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[31],squareroot_TdivZ[20], color='cyan',label='sd, $s=0.5 $, $L_x=260.633$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[34],squareroot_TdivZ[23],color='navy',label='sd, $s=0.6 $, $L_x=138.185$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],squareroot_TdivZ[21],color='darkcyan',label='sd, $s=0.6 $, $L_x=198.992$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],squareroot_TdivZ[22], color='darkcyan',label='sd, $s=0.6 $, $L_x=198.992$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],squareroot_TdivZ[24], color='darkcyan',label='sd, $s=0.6 $, $L_x=198.992$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[36],squareroot_TdivZ[25],color='dodgerblue',label='sd, $s=0.8 $, $L_x=68.805$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[36],squareroot_TdivZ[26], color='dodgerblue',label='sd, $s=0.8 $, $L_x=68.805$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[39],squareroot_TdivZ[27],color='aquamarine',label='sd, $s=0.8 $, $L_x=137.610$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[40],squareroot_TdivZ[28],color='skyblue',label='sd, $s=0.9 $, $L_x=59.952$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Decay time',fontsize=40)
plt.yticks(fontsize=40)
plt.xticks(fontsize=40)
plt.ylabel(r'$\sqrt{\mathcal{T} /\mathcal{Z}}$',fontsize=50)
#plt.ylim([0,1])
plt.xlim([0,0.09])
plt.tight_layout(rect=[0, 0, 5, 4])
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=4,borderpad=1,labelspacing=1,fontsize=45)
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/decaytime_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()

# %%
T_div_squareroot_Z = [nonlinT.values[0]/((nonlinZ.values[0])**(1/2)),nonlinT.values[1]/((nonlinZ.values[1])**(1/2)),
                      nonlinT.values[2]/((nonlinZ.values[2])**(1/2)),nonlinT.values[3]/((nonlinZ.values[3])**(1/2)),
                      nonlinT.values[4]/((nonlinZ.values[4])**(1/2)),nonlinT.values[5]/((nonlinZ.values[5])**(1/2)),
                      nonlinT.values[6]/((nonlinZ.values[6])**(1/2)),nonlinT.values[7]/((nonlinZ.values[7])**(1/2)),
                      nonlinT.values[8]/((nonlinZ.values[8])**(1/2)),nonlinT.values[9]/((nonlinZ.values[9])**(1/2)),
                      nonlinT.values[10]/((nonlinZ.values[10])**(1/2)),nonlinT.values[11]/((nonlinZ.values[11])**(1/2)),
                      nonlinT.values[12]/((nonlinZ.values[12])**(1/2)),nonlinT.values[13]/((nonlinZ.values[13])**(1/2)),
                      nonlinT.values[14]/((nonlinZ.values[14])**(1/2)),nonlinT.values[15]/((nonlinZ.values[15])**(1/2)),
                      nonlinT.values[16]/((nonlinZ.values[16])**(1/2)),nonlinT.values[17]/((nonlinZ.values[17])**(1/2)),
                      nonlinT.values[18]/((nonlinZ.values[18])**(1/2)),nonlinT.values[19]/((nonlinZ.values[19])**(1/2)),
                      nonlinT.values[20]/((nonlinZ.values[20])**(1/2)),nonlinT.values[21]/((nonlinZ.values[21])**(1/2)),
                      nonlinT.values[22]/((nonlinZ.values[22])**(1/2)),nonlinT.values[23]/((nonlinZ.values[23])**(1/2)),
                      nonlinT.values[24]/((nonlinZ.values[24])**(1/2)),nonlinT.values[25]/((nonlinZ.values[25])**(1/2)),
                      nonlinT.values[26]/((nonlinZ.values[26])**(1/2)),nonlinT.values[27]/((nonlinZ.values[27])**(1/2)),
                      nonlinT.values[28]/((nonlinZ.values[28])**(1/2))]

######## index numbers really important to check
plt.scatter(bvalues[1],T_div_squareroot_Z[2], color='magenta',label='hi s=0.5 $L_x=110.997$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[18],T_div_squareroot_Z[10], color='lime',label='li s=0.8 $L_x=90.837$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[26],T_div_squareroot_Z[14], color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[28],T_div_squareroot_Z[17], color='grey',label='sd s=0.36 $L_x=436.87$  $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],T_div_squareroot_Z[22], color='darkcyan',label='sd s=0.6 $L_x=198.992$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[36],T_div_squareroot_Z[26], color='dodgerblue',label='sd s=0.8 $L_x=68.805$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],T_div_squareroot_Z[4], color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[2],T_div_squareroot_Z[0],color='purple',label='hi $s=0.5$ $L_x=665.979$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[1],T_div_squareroot_Z[1],color='magenta',label='hi s=0.5 $L_x=110.997$ $\omega_T=1.3$', marker='+',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[9],T_div_squareroot_Z[6],color='red',label='hm s=0.8 $L_x=78.832$ $\omega_T=2.3$', marker='x',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[14],T_div_squareroot_Z[7],color='green',label='li s=0.5 $L_x=340.925$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[22],T_div_squareroot_Z[12],color='orange',label='lm s=0.5 $L_x=136.837$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[26],T_div_squareroot_Z[13],color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[28],T_div_squareroot_Z[16],color='grey',label='sd s=0.36 $L_x=436.870$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],T_div_squareroot_Z[21],color='darkcyan',label='sd s=0.6 $L_x=198.992$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[34],T_div_squareroot_Z[23],color='navy',label='sd s=0.6 $L_x=138.185$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[36],T_div_squareroot_Z[25],color='dodgerblue',label='sd s=0.8 $L_x=68.805$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[39],T_div_squareroot_Z[27],color='aquamarine',label='sd s=0.8 $L_x=137.610$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[40],T_div_squareroot_Z[28],color='skyblue',label='sd s=0.9 $L_x=59.952$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],T_div_squareroot_Z[3],color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[15],T_div_squareroot_Z[8],color='lightgreen',label='li s=0.5 $L_x=681.850$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[23],T_div_squareroot_Z[11],color='navajowhite',label='lm s=0.5 $L_x=684.184$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[26],T_div_squareroot_Z[15], color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[31],T_div_squareroot_Z[20], color='cyan',label='sd s=0.5 $L_x=260.633$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],T_div_squareroot_Z[24], color='darkcyan',label='sd s=0.6 $L_x=198.992$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],T_div_squareroot_Z[5], color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Decay time',fontsize=40)
plt.yticks(fontsize=40)
plt.xticks(fontsize=40)
plt.ylabel(r'$\frac{\mathcal{T}}{\sqrt{\mathcal{Z}}}$',fontsize=50)
#plt.ylim([0,1])
plt.xlim([0,0.09])
plt.tight_layout(rect=[0, 0, 5, 4])
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5,borderpad=1,labelspacing=0.8,fontsize=30)
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/decaytime_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()

# %%
###only omt=1
######## index numbers really important to check
#plt.scatter(bvalues[1],squareroot_TdivZ[2], color='magenta',label='hi s=0.5 $L_x=110.997$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[18],squareroot_TdivZ[10], color='lime',label='li s=0.8 $L_x=90.837$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[26],squareroot_TdivZ[14], color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[28],squareroot_TdivZ[17], color='grey',label='sd s=0.36 $L_x=436.87$  $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[35],squareroot_TdivZ[22], color='darkcyan',label='sd s=0.6 $L_x=198.992$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.scatter(bvalues[36],squareroot_TdivZ[26], color='dodgerblue',label='sd s=0.8 $L_x=68.805$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],squareroot_TdivZ[4], color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[2],squareroot_TdivZ[0],color='purple',label='hi $s=0.5$ $L_x=665.979$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[1],squareroot_TdivZ[1],color='magenta',label='hi s=0.5 $L_x=110.997$ $\omega_T=1.3$', marker='+',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[9],squareroot_TdivZ[6],color='red',label='hm s=0.8 $L_x=78.832$ $\omega_T=2.3$', marker='x',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[14],squareroot_TdivZ[7],color='green',label='li s=0.5 $L_x=340.925$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[22],squareroot_TdivZ[12],color='orange',label='lm s=0.5 $L_x=136.837$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[26],squareroot_TdivZ[13],color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[28],squareroot_TdivZ[16],color='grey',label='sd s=0.36 $L_x=436.870$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],squareroot_TdivZ[21],color='darkcyan',label='sd s=0.6 $L_x=198.992$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[34],squareroot_TdivZ[23],color='navy',label='sd s=0.6 $L_x=138.185$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[36],squareroot_TdivZ[25],color='dodgerblue',label='sd s=0.8 $L_x=68.805$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[39],squareroot_TdivZ[27],color='deepskyblue',label='sd s=0.8 $L_x=137.610$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[40],squareroot_TdivZ[28],color='skyblue',label='sd s=0.9 $L_x=59.952$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],squareroot_TdivZ[3],color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[15],squareroot_TdivZ[8],color='lightgreen',label='li s=0.5 $L_x=681.850$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[23],squareroot_TdivZ[11],color='navajowhite',label='lm s=0.5 $L_x=684.184$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.scatter(bvalues[26],squareroot_TdivZ[15], color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[31],squareroot_TdivZ[20], color='cyan',label='sd s=0.5 $L_x=260.633$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[35],squareroot_TdivZ[24], color='darkcyan',label='sd s=0.6 $L_x=198.992$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[7],squareroot_TdivZ[5], color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Decay time',fontsize=30)
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.ylabel(r'$\sqrt{\mathcal{T} /\mathcal{Z}}$',fontsize=30)
#plt.ylim([0,1])
#plt.xlim([0,0.030])
plt.tight_layout(rect=[0, 0, 5, 4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5,borderpad=1,labelspacing=0.8,fontsize=30)
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/decaytime_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()

# %%
####### only omt=1
T_div_squareroot_Z = [nonlinT.values[0]/((nonlinZ.values[0])**(1/2)),nonlinT.values[1]/((nonlinZ.values[1])**(1/2)),
                      nonlinT.values[2]/((nonlinZ.values[2])**(1/2)),nonlinT.values[3]/((nonlinZ.values[3])**(1/2)),
                      nonlinT.values[4]/((nonlinZ.values[4])**(1/2)),nonlinT.values[5]/((nonlinZ.values[5])**(1/2)),
                      nonlinT.values[6]/((nonlinZ.values[6])**(1/2)),nonlinT.values[7]/((nonlinZ.values[7])**(1/2)),
                      nonlinT.values[8]/((nonlinZ.values[8])**(1/2)),nonlinT.values[9]/((nonlinZ.values[9])**(1/2)),
                      nonlinT.values[10]/((nonlinZ.values[10])**(1/2)),nonlinT.values[11]/((nonlinZ.values[11])**(1/2)),
                      nonlinT.values[12]/((nonlinZ.values[12])**(1/2)),nonlinT.values[13]/((nonlinZ.values[13])**(1/2)),
                      nonlinT.values[14]/((nonlinZ.values[14])**(1/2)),nonlinT.values[15]/((nonlinZ.values[15])**(1/2)),
                      nonlinT.values[16]/((nonlinZ.values[16])**(1/2)),nonlinT.values[17]/((nonlinZ.values[17])**(1/2)),
                      nonlinT.values[18]/((nonlinZ.values[18])**(1/2)),nonlinT.values[19]/((nonlinZ.values[19])**(1/2)),
                      nonlinT.values[20]/((nonlinZ.values[20])**(1/2)),nonlinT.values[21]/((nonlinZ.values[21])**(1/2)),
                      nonlinT.values[22]/((nonlinZ.values[22])**(1/2)),nonlinT.values[23]/((nonlinZ.values[23])**(1/2)),
                      nonlinT.values[24]/((nonlinZ.values[24])**(1/2)),nonlinT.values[25]/((nonlinZ.values[25])**(1/2)),
                      nonlinT.values[26]/((nonlinZ.values[26])**(1/2)),nonlinT.values[27]/((nonlinZ.values[27])**(1/2)),
                      nonlinT.values[28]/((nonlinZ.values[28])**(1/2))]

######## index numbers really important to check
#plt.scatter(bvalues[1],T_div_squareroot_Z[2], color='magenta',label='hi s=0.5 $L_x=110.997$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[18],T_div_squareroot_Z[10], color='lime',label='li s=0.8 $L_x=90.837$ $\omega_T=1.5$', marker='4',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[26],T_div_squareroot_Z[14], color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[28],T_div_squareroot_Z[17], color='grey',label='sd s=0.36 $L_x=436.87$  $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[35],T_div_squareroot_Z[22], color='darkcyan',label='sd s=0.6 $L_x=198.992$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.scatter(bvalues[36],T_div_squareroot_Z[26], color='dodgerblue',label='sd s=0.8 $L_x=68.805$  $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
##plt.scatter(bvalues[7],T_div_squareroot_Z[4], color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[2],T_div_squareroot_Z[0],color='purple',label='hi $s=0.5$ $L_x=665.979$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[1],T_div_squareroot_Z[1],color='magenta',label='hi s=0.5 $L_x=110.997$ $\omega_T=1.3$', marker='+',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[9],T_div_squareroot_Z[6],color='red',label='hm s=0.8 $L_x=78.832$ $\omega_T=2.3$', marker='x',s=700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[14],T_div_squareroot_Z[7],color='green',label='li s=0.5 $L_x=340.925$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[22],T_div_squareroot_Z[12],color='orange',label='lm s=0.5 $L_x=136.837$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[26],T_div_squareroot_Z[13],color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[28],T_div_squareroot_Z[16],color='grey',label='sd s=0.36 $L_x=436.870$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[35],T_div_squareroot_Z[21],color='aquamarine',label='sd s=0.6 $L_x=198.992$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[34],T_div_squareroot_Z[23],color='navy',label='sd s=0.6 $L_x=138.185$ $\omega_T=2$', marker='2',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[36],T_div_squareroot_Z[25],color='dodgerblue',label='sd s=0.8 $L_x=68.805$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

plt.scatter(bvalues[39],T_div_squareroot_Z[27],color='indigo',label='sd s=0.8 $L_x=137.610$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[40],T_div_squareroot_Z[28],color='skyblue',label='sd s=0.9 $L_x=59.952$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
##plt.scatter(bvalues[7],T_div_squareroot_Z[3],color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[15],T_div_squareroot_Z[8],color='lightgreen',label='li s=0.5 $L_x=681.850$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[23],T_div_squareroot_Z[11],color='navajowhite',label='lm s=0.5 $L_x=684.184$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.scatter(bvalues[26],T_div_squareroot_Z[15], color='blue',label='sd s=0.25 $L_x=774.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
plt.scatter(bvalues[31],T_div_squareroot_Z[20], color='cyan',label='sd s=0.5 $L_x=260.633$ $\omega_T=1$', marker='1',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
#plt.scatter(bvalues[35],T_div_squareroot_Z[24], color='darkcyan',label='sd s=0.6 $L_x=198.992$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)
##plt.scatter(bvalues[7],T_div_squareroot_Z[5], color='darkred',label='hm s=0.5 $L_x=310.957$ $\omega_T=3$', marker='3',s=1700, cmap=None, alpha=1, linewidth=8, edgecolors=None)

#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Decay time',fontsize=30)
plt.yticks(fontsize=30)
plt.xticks(fontsize=30)
plt.ylabel(r'$\frac{\mathcal{T}}{\sqrt{\mathcal{Z}}}$',fontsize=40)
#plt.ylim([0,1])
#plt.xlim([0,0.030])
plt.tight_layout(rect=[0, 0, 5, 4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5,borderpad=1,labelspacing=0.8,fontsize=30)
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/decaytime_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()
