# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
s=[0.25,0.36,0.5,0.6,0.7,0.8,0.9,0.25,0.36,0.5,0.6,0.7,0.8,0.9,0.25,0.36,0.5,0.6,0.7,0.8,0.9,0.25,0.36,0.5,0.6,0.7,0.8,
   0.9,0.25,0.36,0.5,0.6,0.7,0.8,0.9]
shear=[-0.0608512,-0.1059195,-0.1801858,-0.2447718,-0.3162389,-0.3905507,-0.4651485,-0.0421379,-0.0754122,-0.1286351,
       -0.1709411,-0.2131663,-0.2537029,-0.2944365,-0.0413427,-0.0714914,-0.1173279,-0.1525157,-0.1870923,-0.2201747,
       -0.2536171,-0.0506642,-0.0881640,-0.1461596,-0.1916293,-0.2370827,-0.2808702,-0.3246174,-0.0516158,-0.0915604,
       -0.1534727,-0.2010183,-0.2472196,-0.2906768,-0.3335995]
plt.scatter(s[14],shear[14], color='orange',label='Low Iota', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[7],shear[7], color='blue',label='High Mirror', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[21],shear[21], color='purple',label='Low Mirror', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[28],shear[28], color='green',label='Standard Configuration', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[0],shear[0], color='red',label='High Iota', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[1],shear[1], color='red', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[2],shear[2], color='red', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[3],shear[3], color='red', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[4],shear[4], color='red', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

plt.scatter(s[5],shear[5], color='red', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[6],shear[6], color='red', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[8],shear[8], color='blue', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[9],shear[9], color='blue', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

plt.scatter(s[10],shear[10], color='blue', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[11],shear[11], color='blue', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[12],shear[12], color='blue',marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[13],shear[13], color='blue', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

plt.scatter(s[15],shear[15], color='orange', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[16],shear[16], color='orange', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[17],shear[17], color='orange', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[18],shear[18], color='orange', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[19],shear[19], color='orange',marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

plt.scatter(s[20],shear[20], color='orange', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[22],shear[22], color='purple', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[23],shear[23], color='purple', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[24],shear[24], color='purple', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

plt.scatter(s[25],shear[25], color='purple', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[26],shear[26], color='purple', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[27],shear[27], color='purple', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[29],shear[29], color='green', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

plt.scatter(s[30],shear[30], color='green', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[31],shear[31], color='green', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[32],shear[32], color='green', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[33],shear[33], color='green', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)
plt.scatter(s[34],shear[34], color='green', marker='o',s=200, cmap=None, alpha=1, linewidths=3, edgecolors=None)

#plt.plot(s, shear)
#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Normalized radius $s$',fontsize=25)
plt.yticks(fontsize=25)########################### at least 20 for report ##############
plt.xticks(fontsize=25)
plt.grid()
plt.ylabel('Global magnetic shear',fontsize=25)
plt.xlim([0.2,1])
plt.ylim([-0.5,0])
plt.tight_layout(rect=[0,0,3,2])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5, borderpad=1,labelspacing=0.8,fontsize=20)
plt.show()

# %%
label='sd s=0.6 $L_x=104.719$'
