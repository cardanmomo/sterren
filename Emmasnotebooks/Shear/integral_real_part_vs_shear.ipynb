# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datashear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\sheardata.csv')
shear = pd.DataFrame(datashear, columns= ['magnetic shear'])
#print(shear.values)

# %%
sheardata = [shear.values[0],shear.values[1],shear.values[2],shear.values[3],shear.values[4],shear.values[5],
             shear.values[6],shear.values[7],shear.values[8],shear.values[9],shear.values[10],shear.values[11],
             shear.values[12],shear.values[13],shear.values[14],shear.values[15],shear.values[16],shear.values[17],
             shear.values[18],shear.values[19],shear.values[20],shear.values[21],shear.values[22],shear.values[23],
             shear.values[24],shear.values[25],shear.values[26],shear.values[27],shear.values[28],shear.values[29],
             shear.values[30],shear.values[31],shear.values[32],shear.values[33],shear.values[34],shear.values[35],
             shear.values[36],shear.values[37],shear.values[38],shear.values[39],shear.values[40],shear.values[41]]

int_realpart = [integ12,integ22,integ152,integ162,integ172,integ182,integ32,integ42,integ402,integ192,integ202,
                integ212,integ222,integ52,integ62,integ412,integ232,integ242,integ252,integ262,integ272,integ282,
                integ292,integ422,integ392,integ72,integ82,integ92,integ302,integ102,integ112,integ312,integ322,
                integ122,integ132,integ332,integ342,integ352,integ362,integ372,integ142,integ382]

# %%
import matplotlib.markers

plt.scatter(int_realpart[0],shear.values[0], color='purple',label='hi s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[1],shear.values[1], color='purple',label='hi s=0.5 $L_x=665.979$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[2],shear.values[2], color='purple',label='hi s=0.5 $L_x=110.997$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[3],shear.values[3], color='magenta',label='hi s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[4],shear.values[4], color='red',label='hm s=0.36 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[5],shear.values[5], color='red',label='hm s=0.36 $L_x=530.418$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[6],shear.values[6], color='darkred',label='hm s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[7],shear.values[7], color='darkred',label='hm s=0.5 $L_x=621.914$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[8],shear.values[8], color='darkred',label='hm s=0.5 $L_x=310.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[9],shear.values[9], color='tomato',label='hm s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[10],shear.values[10], color='tomato',label='hm s=0.8 $L_x=266.000$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[11],shear.values[11], color='tomato',label='hm s=0.8 $L_x=530.000$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[12],shear.values[12], color='tomato',label='hm s=0.8 $L_x=78.832$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[13],shear.values[13], color='green',label='li s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[14],shear.values[14], color='green',label='li s=0.5 $L_x=340.925$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[15],shear.values[15], color='green',label='li s=0.5 $L_x=681.850$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[16],shear.values[16], color='lime',label='li s=0.6 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[17],shear.values[17], color='darkgreen',label='li s=0.7 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[18],shear.values[18], color='lightgreen',label='li s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[19],shear.values[19], color='lightgreen',label='li s=0.8 $L_x=90.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[20],shear.values[20], color='mediumseagreen',label='li s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[21],shear.values[21], color='orange',label='lm s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[22],shear.values[22], color='orange',label='lm s=0.5 $L_x=136.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[23],shear.values[23], color='orange',label='lm s=0.5 $L_x=684.184$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[24],shear.values[24], color='navajowhite',label='lm s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[25],shear.values[25], color='blue',label='sd s=0.25 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[26],shear.values[26], color='blue',label='sd s=0.25 $L_x=774.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[27],shear.values[27], color='darkcyan',label='sd s=0.36 $L_x=436.870$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[28],shear.values[28], color='darkcyan',label='sd s=0.36 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[29],shear.values[29], color='cyan',label='sd s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[30],shear.values[30], color='cyan',label='sd s=0.5 $L_x=621.914$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[31],shear.values[31], color='cyan',label='sd s=0.5 $L_x=130.316$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[32],shear.values[32], color='cyan',label='sd s=0.5 $L_x=260.633$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[33],shear.values[33], color='dodgerblue',label='sd s=0.6 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[34],shear.values[34], color='dodgerblue',label='sd s=0.6 $L_x=198.992$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[35],shear.values[35], color='dodgerblue',label='sd s=0.6 $L_x=138.185$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[36],shear.values[36], color='navy',label='sd s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[37],shear.values[37], color='navy',label='sd s=0.8 $L_x=137.610$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[38],shear.values[38], color='navy',label='sd s=0.8 $L_x=68.805$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[39],shear.values[39], color='navy',label='sd s=0.8 $L_x=95.562$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[40],shear.values[40], color='deepskyblue',label='sd s=0.9 $L_x=59.952$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[41],shear.values[41], color='deepskyblue',label='sd s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over the real part of $\phi$ until residual is reached',fontsize=25)
plt.yticks(fontsize=25)########################### at least 20 for report ##############
plt.xticks(fontsize=25)
plt.ylabel('Magnetic global shear',fontsize=25)
plt.ylim([-0.5,0.05])
plt.xlim([-10,210])
plt.tight_layout(rect=[0,0,5,4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6, borderpad=1,labelspacing=0.8,fontsize=20)
plt.show()
#rect=[0, 0, 5, 4])
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/realint_vs_gobalshear.pdf', format='pdf', dpi=1200)

# %%
plt.scatter(int_realpart[0],shear.values[0], color='purple',label='hi s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[1],shear.values[1], color='purple',label='hi s=0.5 $L_x=665.979$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[2],shear.values[2], color='purple',label='hi s=0.5 $L_x=110.997$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[3],shear.values[3], color='magenta',label='hi s=0.8 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[4],shear.values[4], color='red',label='hm s=0.36 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[5],shear.values[5], color='red',label='hm s=0.36 $L_x=530.418$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[6],shear.values[6], color='darkred',label='hm s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[7],shear.values[7], color='darkred',label='hm s=0.5 $L_x=621.914$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[8],shear.values[8], color='darkred',label='hm s=0.5 $L_x=310.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[9],shear.values[9], color='tomato',label='hm s=0.8 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[10],shear.values[10], color='tomato',label='hm s=0.8 $L_x=266.000$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[11],shear.values[11], color='tomato',label='hm s=0.8 $L_x=530.000$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[12],shear.values[12], color='tomato',label='hm s=0.8 $L_x=78.832$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[13],shear.values[13], color='green',label='li s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[14],shear.values[14], color='green',label='li s=0.5 $L_x=340.925$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[15],shear.values[15], color='green',label='li s=0.5 $L_x=681.850$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[16],shear.values[16], color='lime',label='li s=0.6 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[17],shear.values[17], color='darkgreen',label='li s=0.7 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[18],shear.values[18], color='lightgreen',label='li s=0.8 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[19],shear.values[19], color='lightgreen',label='li s=0.8 $L_x=90.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[20],shear.values[20], color='mediumseagreen',label='li s=0.9 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[21],shear.values[21], color='orange',label='lm s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[22],shear.values[22], color='orange',label='lm s=0.5 $L_x=136.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[23],shear.values[23], color='orange',label='lm s=0.5 $L_x=684.184$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[24],shear.values[24], color='navajowhite',label='lm s=0.9 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[25],shear.values[25], color='blue',label='sd s=0.25 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[26],shear.values[26], color='blue',label='sd s=0.25 $L_x=774.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[27],shear.values[27], color='darkcyan',label='sd s=0.36 $L_x=436.870$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[28],shear.values[28], color='darkcyan',label='sd s=0.36 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[29],shear.values[29], color='cyan',label='sd s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[30],shear.values[30], color='cyan',label='sd s=0.5 $L_x=621.914$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[31],shear.values[31], color='cyan',label='sd s=0.5 $L_x=130.316$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[32],shear.values[32], color='cyan',label='sd s=0.5 $L_x=260.633$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[33],shear.values[33], color='dodgerblue',label='sd s=0.6 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[34],shear.values[34], color='dodgerblue',label='sd s=0.6 $L_x=198.992$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[35],shear.values[35], color='dodgerblue',label='sd s=0.6 $L_x=138.185$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[36],shear.values[36], color='navy',label='sd s=0.8 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[37],shear.values[37], color='navy',label='sd s=0.8 $L_x=137.610$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[38],shear.values[38], color='navy',label='sd s=0.8 $L_x=68.805$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[39],shear.values[39], color='navy',label='sd s=0.8 $L_x=95.562$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[40],shear.values[40], color='deepskyblue',label='sd s=0.9 $L_x=59.952$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[41],shear.values[41], color='deepskyblue',label='sd s=0.9 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over the real part of $\phi$ until residual is reached',fontsize=25)
plt.yticks(fontsize=25)########################### at least 20 for report ##############
plt.xticks(fontsize=25)
plt.ylabel('Magnetic global shear',fontsize=25)
plt.ylim([-0.5,0.05])
plt.xlim([-10,210])
plt.tight_layout(rect=[0,0,5,4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6, borderpad=1,labelspacing=0.8,fontsize=20)
plt.show()
#rect=[0, 0, 5, 4])
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/realint_vs_gobalshear.pdf', format='pdf', dpi=1200)

# %%
import matplotlib.markers

plt.scatter(int_realpart[0],shear.values[0], color='purple',label='hi s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[1],shear.values[1], color='purple',label='hi s=0.5 $L_x=665.979$', marker='3',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[2],shear.values[2], color='purple',label='hi s=0.5 $L_x=110.997$', marker='2',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[3],shear.values[3], color='magenta',label='hi s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[4],shear.values[4], color='red',label='hm s=0.36 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[5],shear.values[5], color='red',label='hm s=0.36 $L_x=530.418$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[6],shear.values[6], color='darkred',label='hm s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[7],shear.values[7], color='darkred',label='hm s=0.5 $L_x=621.914$', marker='3',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[8],shear.values[8], color='darkred',label='hm s=0.5 $L_x=310.957$', marker='2',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[9],shear.values[9], color='tomato',label='hm s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[10],shear.values[10], color='tomato',label='hm s=0.8 $L_x=266.000$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[11],shear.values[11], color='tomato',label='hm s=0.8 $L_x=530.000$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[12],shear.values[12], color='tomato',label='hm s=0.8 $L_x=78.832$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[13],shear.values[13], color='green',label='li s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[14],shear.values[14], color='green',label='li s=0.5 $L_x=340.925$', marker='2',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[15],shear.values[15], color='green',label='li s=0.5 $L_x=681.850$', marker='3',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[16],shear.values[16], color='lime',label='li s=0.6 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[17],shear.values[17], color='darkgreen',label='li s=0.7 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[18],shear.values[18], color='lightgreen',label='li s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[19],shear.values[19], color='lightgreen',label='li s=0.8 $L_x=90.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[20],shear.values[20], color='mediumseagreen',label='li s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[21],shear.values[21], color='orange',label='lm s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[22],shear.values[22], color='orange',label='lm s=0.5 $L_x=136.837$', marker='2',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[23],shear.values[23], color='orange',label='lm s=0.5 $L_x=684.184$', marker='3',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[24],shear.values[24], color='navajowhite',label='lm s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[25],shear.values[25], color='blue',label='sd s=0.25 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[26],shear.values[26], color='blue',label='sd s=0.25 $L_x=774.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[27],shear.values[27], color='darkcyan',label='sd s=0.36 $L_x=436.870$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[28],shear.values[28], color='darkcyan',label='sd s=0.36 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[29],shear.values[29], color='cyan',label='sd s=0.5 $L_x=104.719$', marker='1',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_realpart[30],shear.values[30], color='cyan',label='sd s=0.5 $L_x=621.914$', marker='4',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[31],shear.values[31], color='cyan',label='sd s=0.5 $L_x=130.316$', marker='2',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_realpart[32],shear.values[32], color='cyan',label='sd s=0.5 $L_x=260.633$', marker='3',s=1700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[33],shear.values[33], color='dodgerblue',label='sd s=0.6 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[34],shear.values[34], color='dodgerblue',label='sd s=0.6 $L_x=198.992$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[35],shear.values[35], color='dodgerblue',label='sd s=0.6 $L_x=138.185$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[36],shear.values[36], color='navy',label='sd s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[37],shear.values[37], color='navy',label='sd s=0.8 $L_x=137.610$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[38],shear.values[38], color='navy',label='sd s=0.8 $L_x=68.805$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[39],shear.values[39], color='navy',label='sd s=0.8 $L_x=95.562$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.scatter(int_realpart[40],shear.values[40], color='deepskyblue',label='sd s=0.9 $L_x=59.952$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
#plt.scatter(int_realpart[41],shear.values[41], color='deepskyblue',label='sd s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over the real part of $\phi$ until residual is reached',fontsize=25)
plt.yticks(fontsize=25)########################### at least 20 for report ##############
plt.xticks(fontsize=25)
plt.ylabel('Magnetic global shear',fontsize=25)
plt.ylim([-0.5,0.05])
plt.xlim([-10,210])
plt.tight_layout(rect=[0,0,5,4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6, borderpad=1,labelspacing=0.8,fontsize=20)
plt.show()
#rect=[0, 0, 5, 4])
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/realint_vs_gobalshear.pdf', format='pdf', dpi=1200)

# %%
int_mod = [integ11,integ21,integ151,integ161,integ171,integ181,integ31,integ41,integ401,integ191,integ201,
                integ211,integ221,integ51,integ61,integ411,integ231,integ241,integ251,integ261,integ271,integ281,
                integ291,integ421,integ391,integ71,integ81,integ91,integ301,integ101,integ111,integ311,integ321,
                integ121,integ131,integ331,integ341,integ351,integ361,integ371,integ141,integ381]

plt.scatter(int_mod[0],shear.values[0], color='purple',label='hi s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[1],shear.values[1], color='purple',label='hi s=0.5 $L_x=665.979$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[2],shear.values[2], color='purple',label='hi s=0.5 $L_x=110.997$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[3],shear.values[3], color='magenta',label='hi s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[4],shear.values[4], color='red',label='hm s=0.36 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[5],shear.values[5], color='red',label='hm s=0.36 $L_x=530.418$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[6],shear.values[6], color='darkred',label='hm s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[7],shear.values[7], color='darkred',label='hm s=0.5 $L_x=621.914$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[8],shear.values[8], color='darkred',label='hm s=0.5 $L_x=310.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[9],shear.values[9], color='tomato',label='hm s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[10],shear.values[10], color='tomato',label='hm s=0.8 $L_x=266.000$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[11],shear.values[11], color='tomato',label='hm s=0.8 $L_x=530.000$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[12],shear.values[12], color='tomato',label='hm s=0.8 $L_x=78.832$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[13],shear.values[13], color='green',label='li s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[14],shear.values[14], color='green',label='li s=0.5 $L_x=340.925$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[15],shear.values[15], color='green',label='li s=0.5 $L_x=681.850$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[16],shear.values[16], color='lime',label='li s=0.6 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[17],shear.values[17], color='darkgreen',label='li s=0.7 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[18],shear.values[18], color='lightgreen',label='li s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[19],shear.values[19], color='lightgreen',label='li s=0.8 $L_x=90.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[20],shear.values[20], color='mediumseagreen',label='li s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[21],shear.values[21], color='orange',label='lm s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[22],shear.values[22], color='orange',label='lm s=0.5 $L_x=136.837$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[23],shear.values[23], color='orange',label='lm s=0.5 $L_x=684.184$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[24],shear.values[24], color='navajowhite',label='lm s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[25],shear.values[25], color='blue',label='sd s=0.25 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[26],shear.values[26], color='blue',label='sd s=0.25 $L_x=774.957$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[27],shear.values[27], color='darkcyan',label='sd s=0.36 $L_x=436.870$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[28],shear.values[28], color='darkcyan',label='sd s=0.36 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[29],shear.values[29], color='cyan',label='sd s=0.5 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[30],shear.values[30], color='cyan',label='sd s=0.5 $L_x=621.914$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[31],shear.values[31], color='cyan',label='sd s=0.5 $L_x=130.316$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[32],shear.values[32], color='cyan',label='sd s=0.5 $L_x=260.633$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[33],shear.values[33], color='dodgerblue',label='sd s=0.6 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[34],shear.values[34], color='dodgerblue',label='sd s=0.6 $L_x=198.992$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[35],shear.values[35], color='dodgerblue',label='sd s=0.6 $L_x=138.185$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[36],shear.values[36], color='navy',label='sd s=0.8 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[37],shear.values[37], color='navy',label='sd s=0.8 $L_x=137.610$', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[38],shear.values[38], color='navy',label='sd s=0.8 $L_x=68.805$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[39],shear.values[39], color='navy',label='sd s=0.8 $L_x=95.562$', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(int_mod[40],shear.values[40], color='deepskyblue',label='sd s=0.9 $L_x=59.952$', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(int_mod[41],shear.values[41], color='deepskyblue',label='sd s=0.9 $L_x=104.719$', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over the modulus of $\phi$ until residual is reached',fontsize=25)
plt.yticks(fontsize=25)########################### at least 20 for report ##############
plt.xticks(fontsize=25)
plt.ylabel('Magnetic global shear',fontsize=25)
#plt.ylim([-0.5,0.05])
#plt.xlim([-10,210])
plt.tight_layout(rect=[0,0,5,4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6, borderpad=1,labelspacing=0.8,fontsize=20)
plt.show()
#rect=[0, 0, 5, 4])
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/realint_vs_gobalshear.pdf', format='pdf', dpi=1200)
