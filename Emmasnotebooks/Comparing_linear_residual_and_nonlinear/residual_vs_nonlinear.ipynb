# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Residual\calculating_residual_values_of_all_datasets.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datanonlinear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\wendelstein_version3.csv')
nonlinT = pd.DataFrame(datanonlinear, columns= ['Turbulence'])
nonlinZ = pd.DataFrame(datanonlinear, columns= ['Zonal Flow'])

squareroot_TdivZ = [(nonlinT.values[0]/nonlinZ.values[0])**(1/2),(nonlinT.values[1]/nonlinZ.values[1])**(1/2),
                           (nonlinT.values[2]/nonlinZ.values[2])**(1/2),(nonlinT.values[3]/nonlinZ.values[3])**(1/2),
                           (nonlinT.values[4]/nonlinZ.values[4])**(1/2),(nonlinT.values[5]/nonlinZ.values[5])**(1/2),
                           (nonlinT.values[6]/nonlinZ.values[6])**(1/2),(nonlinT.values[7]/nonlinZ.values[7])**(1/2),
                           (nonlinT.values[8]/nonlinZ.values[8])**(1/2),(nonlinT.values[9]/nonlinZ.values[9])**(1/2),
                           (nonlinT.values[10]/nonlinZ.values[10])**(1/2),(nonlinT.values[11]/nonlinZ.values[11])**(1/2),
                           (nonlinT.values[12]/nonlinZ.values[12])**(1/2),(nonlinT.values[13]/nonlinZ.values[13])**(1/2),
                           (nonlinT.values[14]/nonlinZ.values[14])**(1/2),(nonlinT.values[15]/nonlinZ.values[15])**(1/2),
                           (nonlinT.values[16]/nonlinZ.values[16])**(1/2),(nonlinT.values[17]/nonlinZ.values[17])**(1/2),
                           (nonlinT.values[18]/nonlinZ.values[18])**(1/2),(nonlinT.values[19]/nonlinZ.values[19])**(1/2),
                           (nonlinT.values[20]/nonlinZ.values[20])**(1/2),(nonlinT.values[21]/nonlinZ.values[21])**(1/2),
                           (nonlinT.values[22]/nonlinZ.values[22])**(1/2),(nonlinT.values[23]/nonlinZ.values[23])**(1/2),                       
                           (nonlinT.values[24]/nonlinZ.values[24])**(1/2),(nonlinT.values[25]/nonlinZ.values[25])**(1/2),
                           (nonlinT.values[26]/nonlinZ.values[26])**(1/2),(nonlinT.values[27]/nonlinZ.values[27])**(1/2),
                           (nonlinT.values[28]/nonlinZ.values[28])**(1/2)]

residual = [residual2,residual15,residual15,residual40,residual40,residual40,residual22,residual6,residual41,residual26,
          residual26,residual42,residual29,residual8,residual8,residual8,residual9,residual9,residual32,residual32,
          residual32,residual13,residual13,residual33,residual13,residual36,residual36,residual35,residual14]

# %%
import matplotlib.markers
plt.scatter(residual[2],squareroot_TdivZ[2], color='magenta',label='W7Xhis05 110.997', marker='4',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[10],squareroot_TdivZ[10], color='lime',label='W7Xlis08 90.837', marker='4',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[14],squareroot_TdivZ[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[17],squareroot_TdivZ[17], color='grey',label='W7Xsds036 436.87', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[22],squareroot_TdivZ[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[26],squareroot_TdivZ[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[4],squareroot_TdivZ[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

plt.scatter(residual[0],squareroot_TdivZ[0],color='purple',label='hi, $s=0.5$, $L_x=665.979$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[1],squareroot_TdivZ[1],color='magenta',label='W7Xhis05 110.997', marker='+',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[6],squareroot_TdivZ[6],color='red',label='W7Xhms08 78.832', marker='x',s=400, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[7],squareroot_TdivZ[7],color='green',label='li, $s=0.5$, $L_x=340.925$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[12],squareroot_TdivZ[12],color='orange',label='W7Xlms05 136.837', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[13],squareroot_TdivZ[13],color='blue',label='sd, $s=0.25$, $L_x=774.957$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[16],squareroot_TdivZ[16],color='grey',label='sd, $s=0.36$, $L_x=436.870$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[21],squareroot_TdivZ[21],color='darkcyan',label='sd, $s=0.6$, $L_x=198.992$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[23],squareroot_TdivZ[23],color='navy',label='W7Xsds06 138.185', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[25],squareroot_TdivZ[25],color='dodgerblue',label='sd, $s=0.8$, $L_x=68.805$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[27],squareroot_TdivZ[27],color='aquamarine',label='sd, $s=0.8$, $L_x=137.610$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[28],squareroot_TdivZ[28],color='skyblue',label='sd, $s=0.9$, $L_x=59.952$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[3],squareroot_TdivZ[3],color='darkred',label='hm, $s=0.5$, $L_x=310.957$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[8],squareroot_TdivZ[8],color='lightgreen',label='li, $s=0.5$, $L_x=681.850$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[11],squareroot_TdivZ[11],color='navajowhite',label='lm, $s=0.5$, $L_x=684.184$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

#markerstyle changed
plt.scatter(residual[15],squareroot_TdivZ[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[20],squareroot_TdivZ[20], color='cyan',label='sd, $s=0.5$, $L_x=260.633$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[24],squareroot_TdivZ[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[5],squareroot_TdivZ[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Residual value',fontsize=20)
plt.yticks([0.3,0.6,0.9,1.2,1.5],fontsize=20)
plt.xticks([0,0.01,0.02,0.03,0.04],fontsize=20)
plt.ylabel(r'$\sqrt{\mathcal{T} /\mathcal{Z}}$',fontsize=30)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4),fancybox=False, shadow=False, ncol=5,borderpad=1.5,labelspacing=1.5)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0.3,1.5])
plt.grid()
plt.xlim([0,0.03])
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residual_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
T_div_squareroot_Z = [nonlinT.values[0]/((nonlinZ.values[0])**(1/2)),nonlinT.values[1]/((nonlinZ.values[1])**(1/2)),
                      nonlinT.values[2]/((nonlinZ.values[2])**(1/2)),nonlinT.values[3]/((nonlinZ.values[3])**(1/2)),
                      nonlinT.values[4]/((nonlinZ.values[4])**(1/2)),nonlinT.values[5]/((nonlinZ.values[5])**(1/2)),
                      nonlinT.values[6]/((nonlinZ.values[6])**(1/2)),nonlinT.values[7]/((nonlinZ.values[7])**(1/2)),
                      nonlinT.values[8]/((nonlinZ.values[8])**(1/2)),nonlinT.values[9]/((nonlinZ.values[9])**(1/2)),
                      nonlinT.values[10]/((nonlinZ.values[10])**(1/2)),nonlinT.values[11]/((nonlinZ.values[11])**(1/2)),
                      nonlinT.values[12]/((nonlinZ.values[12])**(1/2)),nonlinT.values[13]/((nonlinZ.values[13])**(1/2)),
                      nonlinT.values[14]/((nonlinZ.values[14])**(1/2)),nonlinT.values[15]/((nonlinZ.values[15])**(1/2)),
                      nonlinT.values[16]/((nonlinZ.values[16])**(1/2)),nonlinT.values[17]/((nonlinZ.values[17])**(1/2)),
                      nonlinT.values[18]/((nonlinZ.values[18])**(1/2)),nonlinT.values[19]/((nonlinZ.values[19])**(1/2)),
                      nonlinT.values[20]/((nonlinZ.values[20])**(1/2)),nonlinT.values[21]/((nonlinZ.values[21])**(1/2)),
                      nonlinT.values[22]/((nonlinZ.values[22])**(1/2)),nonlinT.values[23]/((nonlinZ.values[23])**(1/2)),
                      nonlinT.values[24]/((nonlinZ.values[24])**(1/2)),nonlinT.values[25]/((nonlinZ.values[25])**(1/2)),
                      nonlinT.values[26]/((nonlinZ.values[26])**(1/2)),nonlinT.values[27]/((nonlinZ.values[27])**(1/2)),
                      nonlinT.values[28]/((nonlinZ.values[28])**(1/2))]

import matplotlib.markers
plt.scatter(residual[2],T_div_squareroot_Z[2], color='magenta',label='hi, $s=0.5 $, $L_x=110.997$, $\omega_{T i}=1.5$', marker='4',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[0],T_div_squareroot_Z[0],color='purple',label='hi, $s=0.5$, $L_x=665.979$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[1],T_div_squareroot_Z[1],color='magenta',label='hi, $s=0.5 $, $L_x=110.997$, $\omega_{T i}=1.3$', marker='+',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

plt.scatter(residual[10],T_div_squareroot_Z[10], color='lime',label='li, $s=0.8 $, $L_x=90.837$, $\omega_{T i}=1.5$', marker='4',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[7],T_div_squareroot_Z[7],color='green',label='li, $s=0.5$, $L_x=340.925$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[8],T_div_squareroot_Z[8],color='lightgreen',label='li, $s=0.5$, $L_x=681.850$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

plt.scatter(residual[14],T_div_squareroot_Z[14], color='blue',label='sd, $s=0.25$, $ L_x=774.957$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[17],T_div_squareroot_Z[17], color='grey',label='sd, $s=0.36$, $ L_x=436.87$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[22],T_div_squareroot_Z[22], color='darkcyan',label='sd, $s=0.6 $, $L_x=198.992$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[26],T_div_squareroot_Z[26], color='dodgerblue',label='sd, $s=0.8 $, $L_x=68.805$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[13],T_div_squareroot_Z[13],color='blue',label='sd, $s=0.25$, $L_x=774.957$ , $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[16],T_div_squareroot_Z[16],color='grey',label='sd, $s=0.36$, $L_x=436.870$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[21],T_div_squareroot_Z[21],color='darkcyan',label='sd, $s=0.6$, $L_x=198.992$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[23],T_div_squareroot_Z[23],color='navy',label='sd, $s=0.6 $, $L_x=138.185$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[25],T_div_squareroot_Z[25],color='dodgerblue',label='sd, $s=0.8$, $L_x=68.805$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[27],T_div_squareroot_Z[27],color='aquamarine',label='sd, $s=0.8$, $L_x=137.610, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[28],T_div_squareroot_Z[28],color='skyblue',label='sd, $s=0.9$, $L_x=59.952$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[15],T_div_squareroot_Z[15], color='blue',label='sd, $s=0.25$, $L_x=774.957$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[20],T_div_squareroot_Z[20], color='cyan',label='sd, $s=0.5$, $L_x=260.633$ , $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[24],T_div_squareroot_Z[24], color='darkcyan',label='sd, $s=0.6 $, $L_x=198.992$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

plt.scatter(residual[4],T_div_squareroot_Z[4], color='darkred',label='hm, $s=0.5 $, $L_x=310.957$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[6],T_div_squareroot_Z[6],color='red',label='hm, $s=0.8 $, $L_x=78.832$, $\omega_{T i}=2.3$', marker='x',s=400, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[3],T_div_squareroot_Z[3],color='darkred',label='hm, $s=0.5$, $L_x=310.957$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[5],T_div_squareroot_Z[5], color='darkred',label='hm, $s=0.5 $, $L_x=310.957$, $\omega_{T i}=3$', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

plt.scatter(residual[12],T_div_squareroot_Z[12],color='orange',label='lm, $s=0.5 $, $L_x=136.837$, $\omega_{T i}=2$', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[11],T_div_squareroot_Z[11],color='navajowhite',label='lm, $s=0.5$, $L_x=684.184$, $\omega_{T i}=1$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Residual value',fontsize=20)
plt.yticks([0,0.5,1,1.5,2,2.5],fontsize=20)
plt.xticks([0,0.01,0.02,0.03],fontsize=20)
plt.ylabel(r'$\frac{\mathcal{T}}{\sqrt{\mathcal{Z}}}$',fontsize=30)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4),fancybox=False, shadow=False, ncol=3,borderpad=1.5,labelspacing=1.5,fontsize=25)
plt.tight_layout(rect=[0, 0, 3, 2])
plt.ylim([0,2.5])
plt.xlim([0,0.03])
plt.grid()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residual_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

# %%
nonlinear_squareroot_ZT = [(nonlinZ.values[0]/nonlinT.values[0])**(1/2),(nonlinZ.values[1]/nonlinT.values[1])**(1/2),
                           (nonlinZ.values[2]/nonlinT.values[2])**(1/2),(nonlinZ.values[3]/nonlinT.values[3])**(1/2),
                           (nonlinZ.values[4]/nonlinT.values[4])**(1/2),(nonlinZ.values[5]/nonlinT.values[5])**(1/2),
                           (nonlinZ.values[6]/nonlinT.values[6])**(1/2),(nonlinZ.values[7]/nonlinT.values[7])**(1/2),
                           (nonlinZ.values[8]/nonlinT.values[8])**(1/2),(nonlinZ.values[9]/nonlinT.values[9])**(1/2),
                           (nonlinZ.values[10]/nonlinT.values[10])**(1/2),(nonlinZ.values[11]/nonlinT.values[11])**(1/2),
                           (nonlinZ.values[12]/nonlinT.values[12])**(1/2),(nonlinZ.values[13]/nonlinT.values[13])**(1/2),
                           (nonlinZ.values[14]/nonlinT.values[14])**(1/2),(nonlinZ.values[15]/nonlinT.values[15])**(1/2),
                           (nonlinZ.values[16]/nonlinT.values[16])**(1/2),(nonlinZ.values[17]/nonlinT.values[17])**(1/2),
                           (nonlinZ.values[18]/nonlinT.values[18])**(1/2),(nonlinZ.values[19]/nonlinT.values[19])**(1/2),
                           (nonlinZ.values[20]/nonlinT.values[20])**(1/2),(nonlinZ.values[21]/nonlinT.values[21])**(1/2),
                           (nonlinZ.values[22]/nonlinT.values[22])**(1/2),(nonlinZ.values[23]/nonlinT.values[23])**(1/2),                       
                           (nonlinZ.values[24]/nonlinT.values[24])**(1/2),(nonlinZ.values[25]/nonlinT.values[25])**(1/2),
                           (nonlinZ.values[26]/nonlinT.values[26])**(1/2),(nonlinZ.values[27]/nonlinT.values[27])**(1/2),
                           (nonlinZ.values[28]/nonlinT.values[28])**(1/2)]

import matplotlib.markers
plt.scatter(residual[2],nonlinear_squareroot_ZT[2], color='magenta',label='W7Xhis05 110.997', marker='4',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[10],nonlinear_squareroot_ZT[10], color='lime',label='W7Xlis08 90.837', marker='4',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[14],nonlinear_squareroot_ZT[14], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[17],nonlinear_squareroot_ZT[17], color='grey',label='W7Xsds036 436.87', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[22],nonlinear_squareroot_ZT[22], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[26],nonlinear_squareroot_ZT[26], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[4],nonlinear_squareroot_ZT[4], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

plt.scatter(residual[0],nonlinear_squareroot_ZT[0],color='purple',label='hi, $s=0.5$, $L_x=665.979$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[1],nonlinear_squareroot_ZT[1],color='magenta',label='W7Xhis05 110.997', marker='+',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[6],nonlinear_squareroot_ZT[6],color='red',label='W7Xhms08 78.832', marker='x',s=400, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[7],nonlinear_squareroot_ZT[7],color='green',label='li, $s=0.5$, $L_x=340.925$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[12],nonlinear_squareroot_ZT[12],color='orange',label='W7Xlms05 136.837', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[13],nonlinear_squareroot_ZT[13],color='blue',label='sd, $s=0.25$, $L_x=774.957$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[16],nonlinear_squareroot_ZT[16],color='grey',label='sd, $s=0.36$, $L_x=436.870$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[21],nonlinear_squareroot_ZT[21],color='darkcyan',label='sd, $s=0.6$, $L_x=198.992$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[23],nonlinear_squareroot_ZT[23],color='navy',label='W7Xsds06 138.185', marker='2',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[25],nonlinear_squareroot_ZT[25],color='dodgerblue',label='sd, $s=0.8$, $L_x=68.805$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[27],nonlinear_squareroot_ZT[27],color='aquamarine',label='sd, $s=0.8$, $L_x=137.610$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[28],nonlinear_squareroot_ZT[28],color='skyblue',label='sd, $s=0.9$, $L_x=59.952$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[3],nonlinear_squareroot_ZT[3],color='darkred',label='hm, $s=0.5$, $L_x=310.957$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[8],nonlinear_squareroot_ZT[8],color='lightgreen',label='li, $s=0.5$, $L_x=681.850$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[11],nonlinear_squareroot_ZT[11],color='navajowhite',label='lm, $s=0.5$, $L_x=684.184$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)

#markerstyle changed
plt.scatter(residual[15],nonlinear_squareroot_ZT[15], color='blue',label='W7Xsds025 774.957', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[20],nonlinear_squareroot_ZT[20], color='cyan',label='sd, $s=0.5$, $L_x=260.633$', marker='1',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[24],nonlinear_squareroot_ZT[24], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
plt.scatter(residual[5],nonlinear_squareroot_ZT[5], color='darkred',label='W7Xhms05 310.957', marker='3',s=700, cmap=None, alpha=1, linewidth=5, edgecolors=None)
#plt.title('Nonlinear yy plotted against xx', fontsize=30)
plt.xlabel('Residual value',fontsize=20)
plt.yticks([0,0.5,1,1.5,2,2.5],fontsize=20)
plt.xticks([0,0.01,0.02,0.03],fontsize=20)
plt.ylabel(r'$\sqrt{\frac{\mathcal{Z}}{\mathcal{T}}}$',fontsize=30)
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4),fancybox=False, shadow=False, ncol=4,borderpad=1.5,labelspacing=1.5)#,fontsize=16)
plt.tight_layout(rect=[0, 0, 3, 2])
#plt.ylim([0,2.5])
plt.xlim([0,0.03])
plt.grid()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residual_vs_sqrtTdivZ.jpg', format='jpg', dpi=1200,bbox_inches="tight")
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)
