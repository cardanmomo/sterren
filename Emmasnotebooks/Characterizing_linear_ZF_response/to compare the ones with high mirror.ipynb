# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data3 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/104.719/gamdiagions_act.dat')
E3 = (data3[:,1]*(1/data3[0, 1]))
e3 = (data3[:,2]*(1/data3[0, 1]))
t3 = data3[:,0]

data4 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/621.914/gamdiagions_act.dat')
E4 = (data4[:,1]*(1/data4[0, 1]))
e4 = (data4[:,2]*(1/data4[0, 1]))
t4 = data4[:,0]

data17 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/104.719/gamdiagions_act.dat')
E17 = (data17[:,1]*(1/data17[0, 1]))
e17 = (data17[:,2]*(1/data17[0, 1]))
t17 = data17[:,0]

data18 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/530.418/gamdiagions_act.dat')
E18 = (data18[:,1]*(1/data18[0, 1]))
e18 = (data18[:,2]*(1/data18[0, 1]))
t18 = data18[:,0]

data19 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/104.719/gamdiagions_act.dat')
E19 = (data19[:,1]*(1/data19[0, 1]))
e19 = (data19[:,2]*(1/data19[0, 1]))
t19 = data19[:,0]

data20 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/266.000/gamdiagions_act.dat')
E20 = (data20[:,1]*(1/data20[0, 1]))
e20 = (data20[:,2]*(1/data20[0, 1]))
t20 = data20[:,0]

data21 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/530.000/gamdiagions_act.dat')
E21 = (data21[:,1]*(1/data21[0, 1]))
e21 = (data21[:,2]*(1/data21[0, 1]))
t21 = data21[:,0]

data22 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/78.832/gamdiagions_act.dat')
E22 = (data22[:,1]*(1/data22[0, 1]))
e22 = (data22[:,2]*(1/data22[0, 1]))
t22 = data22[:,0]

data40 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/310.957_P/gamdiagions_act.dat')
E40 = (data40[:,1]*(1/data40[0, 1]))
e40 = (data40[:,2]*(1/data40[0, 1]))
t40 = data40[:,0]

Q3 = np.sqrt(E3**2+e3**2)
Q4 = np.sqrt(E4**2+e4**2)
Q17 = np.sqrt(E17**2+e17**2)
Q18 = np.sqrt(E18**2+e18**2)
Q19 = np.sqrt(E19**2+e19**2)
Q20 = np.sqrt(E20**2+e20**2)
Q21 = np.sqrt(E21**2+e21**2)
Q22 = np.sqrt(E22**2+e22**2)
Q40 = np.sqrt(E40**2+e40**2)

# %%
#plot of the moduli
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror Modulus of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,2200])

ax1.plot(t17, Q17, linewidth=1, label=('Mod W7Xhms036 104.719'),color='red',linestyle='dotted')
#ax1.plot(t18, Q18, linewidth=1, label=('Mod W7Xhms036 530.418'),color='red')
ax1.plot(t3, Q3, linewidth=1, label=('Mod W7Xhms05 104.719'),color='blue',linestyle='dotted')
#ax1.plot(t40, Q40, linewidth=1, label=('Mod W7Xhms05 310.957'),color='blue',linestyle='dashed')
#ax1.plot(t4, Q4, linewidth=1, label=('Mod W7Xhms05 621.914'),color='blue')
#ax1.plot(t22, Q22, linewidth=1, label=('Mod W7Xhms08 78.832'),color='pink',linestyle='-.')
ax1.plot(t19, Q19, linewidth=1, label=('Mod W7Xhms08 104.719'),color='pink',linestyle='dotted')
#ax1.plot(t20, Q20, linewidth=1, label=('Mod W7Xhms08 266.000'),color='pink')
#ax1.plot(t21, Q21, linewidth=1, label=('Mod W7Xhms08 530.000'),color='pink',linestyle='dashed')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=3)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of the real parts
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror real part of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,2200])

ax1.plot(t17, E17, linewidth=1, label=('Re W7Xhms036 104.719'),color='red',linestyle='dotted')
ax1.plot(t18, E18, linewidth=1, label=('Re W7Xhms036 530.418'),color='red')
ax1.plot(t3, E3, linewidth=1, label=('Re W7Xhms05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t40, E40, linewidth=1, label=('Re W7Xhms05 310.957'),color='blue',linestyle='dashed')
ax1.plot(t4, E4, linewidth=1, label=('Re W7Xhms05 621.914'),color='blue')
ax1.plot(t22, E22, linewidth=1, label=('Re W7Xhms08 78.832'),color='pink',linestyle='-.')
ax1.plot(t19, E19, linewidth=1, label=('Re W7Xhms08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t20, E20, linewidth=1, label=('Re W7Xhms08 266.000'),color='pink')
ax1.plot(t21, E21, linewidth=1, label=('Re W7Xhms08 530.000'),color='pink',linestyle='dashed')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of the imaginary parts
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror imaginary part of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.xlim([-10,2200])

ax1.plot(t17, e17, linewidth=1, label=('Im W7Xhms036 104.719'),color='red',linestyle='dotted')
ax1.plot(t18, e18, linewidth=1, label=('Im W7Xhms036 530.418'),color='red')
ax1.plot(t3, e3, linewidth=1, label=('Im W7Xhms05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t40, e40, linewidth=1, label=('Im W7Xhms05 310.957'),color='blue',linestyle='dashed')
ax1.plot(t4, e4, linewidth=1, label=('Im W7Xhms05 621.914'),color='blue')
ax1.plot(t22, e22, linewidth=1, label=('Im W7Xhms08 78.832'),color='pink',linestyle='-.')
ax1.plot(t19, e19, linewidth=1, label=('Im W7Xhms08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t20, e20, linewidth=1, label=('Im W7Xhms08 266.000'),color='pink')
ax1.plot(t21, e21, linewidth=1, label=('Im W7Xhms08 530.000'),color='pink',linestyle='dashed')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=3)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of high mirror s=0.5
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror s=0.5', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

ax1.plot(t3, e3, linewidth=2, label=('Im W7Xhms05 104.719'),color='red',linestyle='dotted')
ax1.plot(t3, E3, linewidth=2, label=('Re W7Xhms05 104.719'),color='red',linestyle='dashed')
ax1.plot(t3, Q3, linewidth=2, label=('Mod W7Xhms05 104.719'),color='red')
ax1.plot(t40, e40, linewidth=2, label=('Im W7Xhms05 310.957'),color='green',linestyle='dotted')
ax1.plot(t40, E40, linewidth=2, label=('Re W7Xhms05 310.957'),color='green',linestyle='dashed')
ax1.plot(t40, Q40, linewidth=2, label=('Mod W7Xhms05 310.957'),color='green')
ax1.plot(t4, e4, linewidth=2, label=('Im W7Xhms05 621.914'),color='blue',linestyle='dotted')
ax1.plot(t4, E4, linewidth=2, label=('Re W7Xhms05 621.914'),color='blue',linestyle='dashed')
ax1.plot(t4, Q4, linewidth=2, label=('Mod W7Xhms05 621.914'),color='blue')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=3)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of high mirror s=0.8
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror s=0.8', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

#ax1.plot(t22, e22, linewidth=1, label=('Im W7Xhms08 78.832'),color='red',linestyle='dotted')
ax1.plot(t22, E22, linewidth=1, label=('Re W7Xhms08 78.832'),color='red',linestyle='dashed')
#ax1.plot(t22, Q22, linewidth=1, label=('Mod W7Xhms08 78.832'),color='red')
#ax1.plot(t19, e19, linewidth=1, label=('Im W7Xhms08 104.719'),color='blue',linestyle='dotted')
ax1.plot(t19, E19, linewidth=1, label=('Re W7Xhms08 104.719'),color='blue',linestyle='dashed')
#ax1.plot(t19, Q19, linewidth=1, label=('Mod W7Xhms08 104.719'),color='blue')
#ax1.plot(t20, e20, linewidth=1, label=('Im W7Xhms08 266.000'),color='orange',linestyle='dotted')
ax1.plot(t20, E20, linewidth=1, label=('Re W7Xhms08 266.000'),color='orange',linestyle='dashed')
#ax1.plot(t20, Q20, linewidth=1, label=('Mod W7Xhms08 266.000'),color='orange')
#ax1.plot(t21, e21, linewidth=1, label=('Im W7Xhms08 530.000'),color='grey',linestyle='dotted')
ax1.plot(t21, E21, linewidth=1, label=('Re W7Xhms08 530.000'),color='grey',linestyle='dashed')
#ax1.plot(t21, Q21, linewidth=1, label=('Mod W7Xhms08 530.000'),color='grey')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of high mirror s=0.36
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X High Mirror s=0.36', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

ax1.plot(t17, e17, linewidth=2, label=('Im W7Xhms036 104.719'),color='orange',linestyle='dotted')
ax1.plot(t17, E17, linewidth=2, label=('Re W7Xhms036 104.719'),color='orange',linestyle='dashed')
ax1.plot(t17, Q17, linewidth=2, label=('Mod W7Xhms036 104.719'),color='orange')
ax1.plot(t18, e18, linewidth=2, label=('Im W7Xhms036 530.418'),color='blue',linestyle='dotted')
ax1.plot(t18, E18, linewidth=2, label=('Re W7Xhms036 530.418'),color='blue',linestyle='dashed')
ax1.plot(t18, Q18, linewidth=2, label=('Mod W7Xhms036 530.418'),color='blue')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)
