# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data7 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/104.719/gamdiagions_act.dat')
E7 = (data7[:,1]*(1/data7[0, 1]))
e7 = (data7[:,2]*(1/data7[0, 1]))
t7 = data7[:,0]

data8 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/774.957/gamdiagions_act.dat')
E8 = (data8[:,1]*(1/data8[0, 1]))
e8 = (data8[:,2]*(1/data8[0, 1]))
t8 = data8[:,0]

data9 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/436.87/gamdiagions_act.dat')
E9 = (data9[:,1]*(1/data9[0, 1]))
e9 = (data9[:,2]*(1/data9[0, 1]))
t9 = data9[:,0]

data10 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/104.719/gamdiagions_act.dat')
E10 = (data10[:,1]*(1/data10[0, 1]))
e10 = (data10[:,2]*(1/data10[0, 1]))
t10 = data10[:,0]

data11 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/621.914/gamdiagions_act.dat')
E11 = (data11[:,1]*(1/data11[0, 1]))
e11 = (data11[:,2]*(1/data11[0, 1]))
t11 = data11[:,0]

data12 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/104.719/gamdiagions_act.dat')
E12 = (data12[:,1]*(1/data12[0, 1]))
e12 = (data12[:,2]*(1/data12[0, 1]))
t12 = data12[:,0]

data13 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/198.992/gamdiagions_act.dat')
E13 = (data13[:,1]*(1/data13[0, 1]))
e13 = (data13[:,2]*(1/data13[0, 1]))
t13 = data13[:,0]

data14 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/59.952/gamdiagions_act.dat')
E14 = (data14[:,1]*(1/data14[0, 1]))
e14 = (data14[:,2]*(1/data14[0, 1]))
t14 = data14[:,0]

data30 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/104.719/gamdiagions_act.dat')
E30 = (data30[:,1]*(1/data30[0, 1]))
e30 = (data30[:,2]*(1/data30[0, 1]))
t30 = data30[:,0]

data31 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/130.316/gamdiagions_act.dat')
E31 = (data31[:,1]*(1/data31[0, 1]))
e31 = (data31[:,2]*(1/data31[0, 1]))
t31 = data31[:,0]

data32 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/260.633/gamdiagions_act.dat')
E32 = (data32[:,1]*(1/data32[0, 1]))
e32 = (data32[:,2]*(1/data32[0, 1]))
t32 = data32[:,0]

data33 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/138.185/gamdiagions_act.dat')
E33 = (data33[:,1]*(1/data33[0, 1]))
e33 = (data33[:,2]*(1/data33[0, 1]))
t33 = data33[:,0]

data34 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/104.719/gamdiagions_act.dat')
E34 = (data34[:,1]*(1/data34[0, 1]))
e34 = (data34[:,2]*(1/data34[0, 1]))
t34 = data34[:,0]

data35 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/137.61/gamdiagions_act.dat')
E35 = (data35[:,1]*(1/data35[0, 1]))
e35 = (data35[:,2]*(1/data35[0, 1]))
t35 = data35[:,0]

data36 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/68.805/gamdiagions_act.dat')
E36 = (data36[:,1]*(1/data36[0, 1]))
e36 = (data36[:,2]*(1/data36[0, 1]))
t36 = data36[:,0]

data37 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/95.562/gamdiagions_act.dat')
E37 = (data37[:,1]*(1/data37[0, 1]))
e37 = (data37[:,2]*(1/data37[0, 1]))
t37 = data37[:,0]

data38 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/104.719/gamdiagions_act.dat')
E38 = (data38[:,1]*(1/data38[0, 1]))
e38 = (data38[:,2]*(1/data38[0, 1]))
t38 = data38[:,0]

Q7 = np.sqrt(E7**2+e7**2)
Q8 = np.sqrt(E8**2+e8**2)
Q9 = np.sqrt(E9**2+e9**2)
Q10 = np.sqrt(E10**2+e10**2)
Q11 = np.sqrt(E11**2+e11**2)
Q12 = np.sqrt(E12**2+e12**2)
Q13 = np.sqrt(E13**2+e13**2)
Q14 = np.sqrt(E14**2+e14**2)
Q30 = np.sqrt(E30**2+e30**2)
Q31 = np.sqrt(E31**2+e31**2)
Q32 = np.sqrt(E32**2+e32**2)
Q33 = np.sqrt(E33**2+e33**2)
Q34 = np.sqrt(E34**2+e34**2)
Q35 = np.sqrt(E35**2+e35**2)
Q36 = np.sqrt(E36**2+e36**2)
Q37 = np.sqrt(E37**2+e37**2)
Q38 = np.sqrt(E38**2+e38**2)

# %%
#PLOT FOR THE IMAGINARY PART
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard Configuration imaginary parts of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])

ax1.plot(t7, e7, linewidth=1, label=('Im W7Xsds025 104.719'),color='orange',linestyle='dotted')
ax1.plot(t8, e8, linewidth=1, label=('Im W7Xsds025 774.957'),color='orange')
ax1.plot(t9, e9, linewidth=1, label=('Im W7Xsds036 436.87'), color='red')
ax1.plot(t10, e10, linewidth=1, label=('Im W7Xsds05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t11, e11, linewidth=1, label=('Im W7Xsds05 621.914'),color='blue',linestyle='-.')
ax1.plot(t12, e12, linewidth=1, label=('Im W7Xsds06 104.719'), color='grey',linestyle='dotted')
ax1.plot(t13, e13, linewidth=1, label=('Im W7Xsds06 198.992'), color='grey')
ax1.plot(t14, e14, linewidth=1, label=('Im W7Xsds09 59.952'), color='green')
ax1.plot(t30, e30, linewidth=1, label=('Im W7Xsds036 104.719'), color='red',linestyle='dotted')
ax1.plot(t31, e31, linewidth=1, label=('Im W7Xsds05 130.316'),color='blue')
ax1.plot(t32, e32, linewidth=1, label=('Im W7Xsds05 260.633'),color='blue',linestyle='dashed')
ax1.plot(t33, e33, linewidth=1, label=('Im W7Xsds06 138.185'), color='grey',linestyle='dashed')
ax1.plot(t35, e35, linewidth=1, label=('Im W7Xsds08 137.61'),color='pink')
ax1.plot(t38, e38, linewidth=1, label=('Im W7Xsds09 104.719'), color='green',linestyle='dotted')
ax1.plot(t36, e36, linewidth=1, label=('Im W7Xsds08 68.805'),color='pink',linestyle='dashed')
ax1.plot(t37, e37, linewidth=1, label=('Im W7Xsds08 95.562'),color='pink',linestyle='-.')
ax1.plot(t34, e34, linewidth=1, label=('Im W7Xsds08 104.719'),color='pink',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.xlim([0,650])

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#PLOT FOR THE REAL PART
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard Configuration real parts of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])

ax1.plot(t7, E7, linewidth=1, label=('Re W7Xsds025 104.719'),color='orange',linestyle='dotted')
ax1.plot(t8, E8, linewidth=1, label=('Re W7Xsds025 774.957'),color='orange')
ax1.plot(t9, E9, linewidth=1, label=('Re W7Xsds036 436.87'), color='red')
ax1.plot(t10, E10, linewidth=1, label=('Re W7Xsds05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t11, E11, linewidth=1, label=('Re W7Xsds05 621.914'),color='blue',linestyle='-.')
ax1.plot(t12, E12, linewidth=1, label=('Re W7Xsds06 104.719'), color='grey',linestyle='dotted')
ax1.plot(t13, E13, linewidth=1, label=('Re W7Xsds06 198.992'), color='grey')
ax1.plot(t14, E14, linewidth=1, label=('Re W7Xsds09 59.952'), color='green')
ax1.plot(t30, E30, linewidth=1, label=('Re W7Xsds036 104.719'), color='red',linestyle='dotted')
ax1.plot(t31, E31, linewidth=1, label=('Re W7Xsds05 130.316'),color='blue')
ax1.plot(t32, E32, linewidth=1, label=('Re W7Xsds05 260.633'),color='blue',linestyle='dashed')
ax1.plot(t33, E33, linewidth=1, label=('Re W7Xsds06 138.185'), color='grey',linestyle='dashed')
ax1.plot(t36, E36, linewidth=1, label=('Re W7Xsds08 68.805'),color='pink',linestyle='dashed')
ax1.plot(t37, E37, linewidth=1, label=('Re W7Xsds08 95.562'),color='pink',linestyle='-.')
ax1.plot(t34, E34, linewidth=1, label=('Re W7Xsds08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t35, E35, linewidth=1, label=('Re W7Xsds08 137.61'),color='pink')
ax1.plot(t38, E38, linewidth=1, label=('Re W7Xsds09 104.719'), color='green',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.xlim([0,650])

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#PLOT FOR THE MODULUS
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard Configuration modulus of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])

ax1.plot(t7, Q7, linewidth=1, label=('Mod W7Xsds025 104.719'),color='orange',linestyle='dotted')
ax1.plot(t8, Q8, linewidth=1, label=('Mod W7Xsds025 774.957'),color='orange')
ax1.plot(t9, Q9, linewidth=1, label=('Mod W7Xsds036 436.87'), color='red')
ax1.plot(t10, Q10, linewidth=1, label=('Mod W7Xsds05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t11, Q11, linewidth=1, label=('Mod W7Xsds05 621.914'),color='blue',linestyle='-.')
ax1.plot(t12, Q12, linewidth=1, label=('Mod W7Xsds06 104.719'), color='grey',linestyle='dotted')
ax1.plot(t13, Q13, linewidth=1, label=('Mod W7Xsds06 198.992'), color='grey')
ax1.plot(t14, Q14, linewidth=1, label=('Mod W7Xsds09 59.952'), color='green')
ax1.plot(t30, Q30, linewidth=1, label=('Mod W7Xsds036 104.719'), color='red',linestyle='dotted')
ax1.plot(t31, Q31, linewidth=1, label=('Mod W7Xsds05 130.316'),color='blue')
ax1.plot(t32, Q32, linewidth=1, label=('Mod W7Xsds05 260.633'),color='blue',linestyle='dashed')
ax1.plot(t33, Q33, linewidth=1, label=('Mod W7Xsds06 138.185'), color='grey',linestyle='dashed')
ax1.plot(t36, Q36, linewidth=1, label=('Mod W7Xsds08 68.805'),color='pink',linestyle='dashed')
ax1.plot(t37, Q37, linewidth=1, label=('Mod W7Xsds08 95.562'),color='pink',linestyle='-.')
ax1.plot(t34, Q34, linewidth=1, label=('Mod W7Xsds08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t35, Q35, linewidth=1, label=('Mod W7Xsds08 137.61'),color='pink')
ax1.plot(t38, Q38, linewidth=1, label=('Mod W7Xsds09 104.719'), color='green',linestyle='dotted')


plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)
plt.xlim([0,650])

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of standard configuration s=0.25
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard configuration s=0.25', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

ax1.plot(t7, e7, linewidth=2, label=('Im W7Xsds025 104.719'),color='red',linestyle='dotted')
ax1.plot(t7, E7, linewidth=2, label=('Re W7Xsds025 104.719'),color='red',linestyle='dashed')
ax1.plot(t7, Q7, linewidth=2, label=('Mod W7Xsds025 104.719'),color='red')
ax1.plot(t8, e8, linewidth=2, label=('Im W7Xsds025 774.957'),color='blue',linestyle='dotted')
ax1.plot(t8, E8, linewidth=2, label=('Re W7Xsds025 774.957'),color='blue',linestyle='dashed')
ax1.plot(t8, Q8, linewidth=2, label=('Mod W7Xsds025 774.957'),color='blue')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of standard configuration s=0.36
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard configuration s=0.36', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

ax1.plot(t30, e30, linewidth=2, label=('Im W7Xsds036 104.719'),color='red',linestyle='dotted')
ax1.plot(t30, E30, linewidth=2, label=('Re W7Xsds036 104.719'),color='red',linestyle='dashed')
ax1.plot(t30, Q30, linewidth=2, label=('Mod W7Xsds036 104.719'),color='red')
ax1.plot(t9, e9, linewidth=2, label=('Im W7Xsds036 436.87'),color='blue',linestyle='dotted')
ax1.plot(t9, E9, linewidth=2, label=('Re W7Xsds036 436.87'),color='blue',linestyle='dashed')
ax1.plot(t9, Q9, linewidth=2, label=('Mod W7Xsds036 436.87'),color='blue')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of standard configuration s=0.5
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard configuration s=0.5', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

ax1.plot(t10, e10, linewidth=1, label=('Im W7Xsds05 104.719'),color='red',linestyle='dotted')
#ax1.plot(t10, E10, linewidth=1, label=('Re W7Xsds05 104.719'),color='red',linestyle='dashed')
ax1.plot(t10, Q10, linewidth=2, label=('Mod W7Xsds05 104.719'),color='red')
ax1.plot(t31, e31, linewidth=1, label=('Im W7Xsds05 130.316'),color='green',linestyle='dotted')
#ax1.plot(t31, E31, linewidth=1, label=('Re W7Xsds05 130.316'),color='green',linestyle='dashed')
ax1.plot(t31, Q31, linewidth=2, label=('Mod W7Xsds05 130.316'),color='green')
ax1.plot(t32, e32, linewidth=1, label=('Im W7Xsds05 260.633'),color='orange',linestyle='dotted')
#ax1.plot(t32, E32, linewidth=1, label=('Re W7Xsds05 260.633'),color='orange',linestyle='dashed')
ax1.plot(t32, Q32, linewidth=2, label=('Mod W7Xsds05 260.633'),color='orange')
ax1.plot(t11, e11, linewidth=1, label=('Im W7Xsds05 621.914'),color='blue',linestyle='dotted')
#ax1.plot(t11, E11, linewidth=1, label=('Re W7Xsds05 621.914'),color='blue',linestyle='dashed')
ax1.plot(t11, Q11, linewidth=2, label=('Mod W7Xsds05 621.914'),color='blue')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of standard configuration s=0.6
fig, ax1 = plt.subplots(figsize=(13, 7))
#plt.title('Linear Zonal  for standard configuration at $s=0.6$', fontsize=20)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=20)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=20)
ax1.tick_params(labelsize=20)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1500])

ax1.plot(t12, e12, linewidth=1, label=('Imaginary part, $L_x=104.719$'),color='red',linestyle='dotted')
ax1.plot(t12, E12, linewidth=1, label=('Real part, $L_x=104.719$'),color='red',linestyle='dashed')
ax1.plot(t12, Q12, linewidth=1, label=('Modulus, $L_x=104.719$'),color='red')
ax1.plot(t33, e33, linewidth=1, label=('Imaginary part, $L_x=138.185$'),color='blue',linestyle='dotted')
ax1.plot(t33, E33, linewidth=1, label=('Real part, $L_x=138.185$'),color='blue',linestyle='dashed')
ax1.plot(t33, Q33, linewidth=1, label=('Modulus, $L_x=138.185$'),color='blue')
ax1.plot(t13, e13, linewidth=1, label=('Imaginary part, $L_x=198.992$'),color='green', linestyle='dotted')
ax1.plot(t13, E13, linewidth=1, label=('Real part, $L_x=198.992$'),color='green', linestyle='dashed')
ax1.plot(t13, Q13, linewidth=1, label=('Modulus, $L_x=198.992$'),color='green')
fig.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.45, -0.2),fancybox=False, shadow=False, ncol=3,fontsize=16,borderpad=0.5,labelspacing=0.4)
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/goede/W7Xsds06.pdf', format='pdf', dpi=1200)
plt.show()

# %%
#plot of standard configuration s=0.8
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Standard configuration s=0.8', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,2000])

ax1.plot(t36, e36, linewidth=1, label=('Im W7Xsds08 68.805'),color='red',linestyle='dotted')
ax1.plot(t36, E36, linewidth=1, label=('Re W7Xsds08 68.805'),color='red',linestyle='dashed')
ax1.plot(t36, Q36, linewidth=1, label=('Mod W7Xsds08 68.805'),color='red')
ax1.plot(t37, e37, linewidth=1, label=('Im W7Xsds08 95.562'),color='blue',linestyle='dotted')
ax1.plot(t37, E37, linewidth=1, label=('Re W7Xsds08 95.562'),color='blue',linestyle='dashed')
ax1.plot(t37, Q37, linewidth=1, label=('Mod W7Xsds08 95.562'),color='blue')
ax1.plot(t34, e34, linewidth=1, label=('Im W7Xsds08 104.719'),color='green', linestyle='dotted')
ax1.plot(t34, E34, linewidth=1, label=('Re W7Xsds08 104.719'),color='green', linestyle='dashed')
ax1.plot(t34, Q34, linewidth=1, label=('Mod W7Xsds08 104.719'),color='green')
ax1.plot(t35, e35, linewidth=1, label=('Im W7Xsds08 137.61'),color='pink',linestyle='dotted')
ax1.plot(t35, E35, linewidth=1, label=('Re W7Xsds08 137.61'),color='pink',linestyle='dashed')
ax1.plot(t35, Q35, linewidth=1, label=('Mod W7Xsds08 137.61'),color='pink')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=4)
fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of standard configuration s=0.9
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X $\phi$ for standard configuration at $s=0.9$', fontsize=20)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([0,1500])

ax1.plot(t14, e14, linewidth=1, label=('Imaginary part $L_x=59.952$'),color='green', linestyle='dotted')
ax1.plot(t14, E14, linewidth=1, label=('Real part $L_x=59.952$'),color='green', linestyle='dashed')
ax1.plot(t14, Q14, linewidth=1, label=('Modulus $L_x=59.952$'),color='green')
ax1.plot(t38, e38, linewidth=1, label=('Imaginary part $L_x=104.719$'),color='red',linestyle='dotted')
ax1.plot(t38, E38, linewidth=1, label=('Real part $L_x=104.719$'),color='red',linestyle='dashed')
ax1.plot(t38, Q38, linewidth=1, label=('Modulus $L_x=104.719$'),color='red')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)
fig.tight_layout()
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/W7Xsds09.pdf', format='pdf', dpi=1200)
