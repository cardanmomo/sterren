# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data1 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/104.719/gamdiagions_act.dat')
E1 = (data1[:,1]*(1/data1[0, 1]))
e1 = (data1[:,2]*(1/data1[0, 1]))
t1 = data1[:,0]

data2 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/665.979/gamdiagions_act.dat')
E2 = (data2[:,1]*(1/data2[0, 1]))
e2 = (data2[:,2]*(1/data2[0, 1]))
t2 = data2[:,0]

data3 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/104.719/gamdiagions_act.dat')
E3 = (data3[:,1]*(1/data3[0, 1]))
e3 = (data3[:,2]*(1/data3[0, 1]))
t3 = data3[:,0]

data4 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/621.914/gamdiagions_act.dat')
E4 = (data4[:,1]*(1/data4[0, 1]))
e4 = (data4[:,2]*(1/data4[0, 1]))
t4 = data4[:,0]

data5 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/104.719/gamdiagions_act.dat')
E5 = (data5[:,1]*(1/data5[0, 1]))
e5 = (data5[:,2]*(1/data5[0, 1]))
t5 = data5[:,0]

data6 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/340.925/gamdiagions_act.dat')
E6 = (data6[:,1]*(1/data6[0, 1]))
e6 = (data6[:,2]*(1/data6[0, 1]))
t6 = data6[:,0]

data7 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/104.719/gamdiagions_act.dat')
E7 = (data7[:,1]*(1/data7[0, 1]))
e7 = (data7[:,2]*(1/data7[0, 1]))
t7 = data7[:,0]

data8 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds025/GAM/774.957/gamdiagions_act.dat')
E8 = (data8[:,1]*(1/data8[0, 1]))
e8 = (data8[:,2]*(1/data8[0, 1]))
t8 = data8[:,0]

data9 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/436.87/gamdiagions_act.dat')
E9 = (data9[:,1]*(1/data9[0, 1]))
e9 = (data9[:,2]*(1/data9[0, 1]))
t9 = data9[:,0]

data10 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/104.719/gamdiagions_act.dat')
E10 = (data10[:,1]*(1/data10[0, 1]))
e10 = (data10[:,2]*(1/data10[0, 1]))
t10 = data10[:,0]

#data11 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/new/w7xsds05_Lx-621.914/diag/gamdiagions_act.dat')
#E11 = (data11[:,1]*(1/data11[0, 1]))
#e11 = (data11[:,2]*(1/data11[0, 1]))
#t11 = data11[:,0]

data12 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/104.719/gamdiagions_act.dat')
E12 = (data12[:,1]*(1/data12[0, 1]))
e12 = (data12[:,2]*(1/data12[0, 1]))
t12 = data12[:,0]

data13 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/198.992/gamdiagions_act.dat')
E13 = (data13[:,1]*(1/data13[0, 1]))
e13 = (data13[:,2]*(1/data13[0, 1]))
t13 = data13[:,0]

data14 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/59.952/gamdiagions_act.dat')
E14 = (data14[:,1]*(1/data14[0, 1]))
e14 = (data14[:,2]*(1/data14[0, 1]))
t14 = data14[:,0]

data15 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis05/GAM/110.997/gamdiagions_act.dat')
E15 = (data15[:,1]*(1/data15[0, 1]))
e15 = (data15[:,2]*(1/data15[0, 1]))
t15 = data15[:,0]

data16 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhis08/GAM/104.719/gamdiagions_act.dat')
E16 = (data16[:,1]*(1/data16[0, 1]))
e16 = (data16[:,2]*(1/data16[0, 1]))
t16 = data16[:,0]

data17 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/104.719/gamdiagions_act.dat')
E17 = (data17[:,1]*(1/data17[0, 1]))
e17 = (data17[:,2]*(1/data17[0, 1]))
t17 = data17[:,0]

data18 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms036/GAM/530.418/gamdiagions_act.dat')
E18 = (data18[:,1]*(1/data18[0, 1]))
e18 = (data18[:,2]*(1/data18[0, 1]))
t18 = data18[:,0]

data19 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/104.719/gamdiagions_act.dat')
E19 = (data19[:,1]*(1/data19[0, 1]))
e19 = (data19[:,2]*(1/data19[0, 1]))
t19 = data19[:,0]

data20 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/266.000/gamdiagions_act.dat')
E20 = (data20[:,1]*(1/data20[0, 1]))
e20 = (data20[:,2]*(1/data20[0, 1]))
t20 = data20[:,0]

data21 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/530.000/gamdiagions_act.dat')
E21 = (data21[:,1]*(1/data21[0, 1]))
e21 = (data21[:,2]*(1/data21[0, 1]))
t21 = data21[:,0]

data22 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms08/GAM/78.832/gamdiagions_act.dat')
E22 = (data22[:,1]*(1/data22[0, 1]))
e22 = (data22[:,2]*(1/data22[0, 1]))
t22 = data22[:,0]

data23 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis06/GAM/104.719/gamdiagions_act.dat')
E23 = (data23[:,1]*(1/data23[0, 1]))
e23 = (data23[:,2]*(1/data23[0, 1]))
t23 = data23[:,0]

data24 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis07/GAM/104.719/gamdiagions_act.dat')
E24 = (data24[:,1]*(1/data24[0, 1]))
e24 = (data24[:,2]*(1/data24[0, 1]))
t24 = data24[:,0]

data25 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/104.719/gamdiagions_act.dat')
E25 = (data25[:,1]*(1/data25[0, 1]))
e25 = (data25[:,2]*(1/data25[0, 1]))
t25 = data25[:,0]

data26 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/90.837/gamdiagions_act.dat')
E26 = (data26[:,1]*(1/data26[0, 1]))
e26 = (data26[:,2]*(1/data26[0, 1]))
t26 = data26[:,0]

data27 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis09/GAM/104.719/gamdiagions_act.dat')
E27 = (data27[:,1]*(1/data27[0, 1]))
e27 = (data27[:,2]*(1/data27[0, 1]))
t27 = data27[:,0]

data28 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/104.719/gamdiagions_act.dat')
E28 = (data28[:,1]*(1/data28[0, 1]))
e28 = (data28[:,2]*(1/data28[0, 1]))
t28 = data28[:,0]

data29 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/136.837/gamdiagions_act.dat')
E29 = (data29[:,1]*(1/data29[0, 1]))
e29 = (data29[:,2]*(1/data29[0, 1]))
t29 = data29[:,0]

data30 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds036/GAM/104.719/gamdiagions_act.dat')
E30 = (data30[:,1]*(1/data30[0, 1]))
e30 = (data30[:,2]*(1/data30[0, 1]))
t30 = data30[:,0]

data31 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/130.316/gamdiagions_act.dat')
E31 = (data31[:,1]*(1/data31[0, 1]))
e31 = (data31[:,2]*(1/data31[0, 1]))
t31 = data31[:,0]

data32 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds05/GAM/260.633/gamdiagions_act.dat')
E32 = (data32[:,1]*(1/data32[0, 1]))
e32 = (data32[:,2]*(1/data32[0, 1]))
t32 = data32[:,0]

data33 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds06/GAM/138.185/gamdiagions_act.dat')
E33 = (data33[:,1]*(1/data33[0, 1]))
e33 = (data33[:,2]*(1/data33[0, 1]))
t33 = data33[:,0]

data34 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/104.719/gamdiagions_act.dat')
E34 = (data34[:,1]*(1/data34[0, 1]))
e34 = (data34[:,2]*(1/data34[0, 1]))
t34 = data34[:,0]

data35 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/137.61/gamdiagions_act.dat')
E35 = (data35[:,1]*(1/data35[0, 1]))
e35 = (data35[:,2]*(1/data35[0, 1]))
t35 = data35[:,0]

data36 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/68.805/gamdiagions_act.dat')
E36 = (data36[:,1]*(1/data36[0, 1]))
e36 = (data36[:,2]*(1/data36[0, 1]))
t36 = data36[:,0]

data37 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds08/GAM/95.562/gamdiagions_act.dat')
E37 = (data37[:,1]*(1/data37[0, 1]))
e37 = (data37[:,2]*(1/data37[0, 1]))
t37 = data37[:,0]

data38 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xsds09/GAM/104.719/gamdiagions_act.dat')
E38 = (data38[:,1]*(1/data38[0, 1]))
e38 = (data38[:,2]*(1/data38[0, 1]))
t38 = data38[:,0]

data39 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms09/GAM/104.719/gamdiagions_act.dat')
E39 = (data39[:,1]*(1/data39[0, 1]))
e39 = (data39[:,2]*(1/data39[0, 1]))
t39 = data39[:,0]

data40 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xhms05/GAM/310.957_P/gamdiagions_act.dat')
E40 = (data40[:,1]*(1/data40[0, 1]))
e40 = (data40[:,2]*(1/data40[0, 1]))
t40 = data40[:,0]

data41 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/681.85_P/gamdiagions_act.dat')
E41 = (data41[:,1]*(1/data41[0, 1]))
e41 = (data41[:,2]*(1/data41[0, 1]))
t41 = data41[:,0]

data42 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlms05/GAM/684.184_P/gamdiagions_act.dat')
E42 = (data42[:,1]*(1/data42[0, 1]))
e42 = (data42[:,2]*(1/data42[0, 1]))
t42 = data42[:,0]

Q1 = np.sqrt(E1**2+e1**2)
Q2 = np.sqrt(E2**2+e2**2)
Q3 = np.sqrt(E3**2+e3**2)
Q4 = np.sqrt(E4**2+e4**2)
Q5 = np.sqrt(E5**2+e5**2)
Q6 = np.sqrt(E6**2+e6**2)
Q7 = np.sqrt(E7**2+e7**2)
Q8 = np.sqrt(E8**2+e8**2)
Q9 = np.sqrt(E9**2+e9**2)
Q10 = np.sqrt(E10**2+e10**2)
#Q11 = np.sqrt(E11**2+e11**2)
Q12 = np.sqrt(E12**2+e12**2)
Q13 = np.sqrt(E13**2+e13**2)
Q14 = np.sqrt(E14**2+e14**2)
Q15 = np.sqrt(E15**2+e15**2)
Q16 = np.sqrt(E16**2+e16**2)
Q17 = np.sqrt(E17**2+e17**2)
Q18 = np.sqrt(E18**2+e18**2)
Q19 = np.sqrt(E19**2+e19**2)
Q20 = np.sqrt(E20**2+e20**2)
Q21 = np.sqrt(E21**2+e21**2)
Q22 = np.sqrt(E22**2+e22**2)
Q23 = np.sqrt(E23**2+e23**2)
Q24 = np.sqrt(E24**2+e24**2)
Q25 = np.sqrt(E25**2+e25**2)
Q26 = np.sqrt(E26**2+e26**2)
Q27 = np.sqrt(E27**2+e27**2)
Q28 = np.sqrt(E28**2+e28**2)
Q29 = np.sqrt(E29**2+e29**2)
Q30 = np.sqrt(E30**2+e30**2)
Q31 = np.sqrt(E31**2+e31**2)
Q32 = np.sqrt(E32**2+e32**2)
Q33 = np.sqrt(E33**2+e33**2)
Q34 = np.sqrt(E34**2+e34**2)
Q35 = np.sqrt(E35**2+e35**2)
Q36 = np.sqrt(E36**2+e36**2)
Q37 = np.sqrt(E37**2+e37**2)
Q38 = np.sqrt(E38**2+e38**2)
Q39 = np.sqrt(E39**2+e39**2)
Q40 = np.sqrt(E40**2+e40**2)
Q41 = np.sqrt(E41**2+e41**2)
Q42 = np.sqrt(E42**2+e42**2)

# %%
#ALL MODULUS
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Modulus of $\phi$ of different configurations', fontsize=20)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.ylim([0,0.7])
plt.xlim([-10,1250])

ax1.plot(t1, Q1, linewidth=1, label=('Mod W7Xhis05 104.719'),color='grey',linestyle='dotted')
ax1.plot(t2, Q2, linewidth=1, label=('Mod W7Xhis05 665.979'),color='grey',linestyle='dotted')
ax1.plot(t3, Q3, linewidth=1, label=('Mod W7Xhms05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t4, Q4, linewidth=1, label=('Mod W7Xhms05 621.914'),color='blue',linestyle='dotted')
ax1.plot(t5, Q5, linewidth=1, label=('Mod W7Xlis05 104.719'),color='pink',linestyle='dotted')
ax1.plot(t6, Q6, linewidth=1, label=('Mod W7Xlis05 340.925'),color='pink',linestyle='dotted')
ax1.plot(t7, Q7, linewidth=1, label=('Mod W7Xsds025 104.719'),color='green',linestyle='dotted')
ax1.plot(t8, Q8, linewidth=1, label=('Mod W7Xsds025 774.957'),color='green',linestyle='dotted')
ax1.plot(t9, Q9, linewidth=1, label=('Mod W7Xsds036 436.87'),color='green',linestyle='dotted')
ax1.plot(t10, Q10, linewidth=1, label=('Mod W7Xsds05 104.719'),color='green',linestyle='dotted')
#ax1.plot(t11, Q11, linewidth=1, label=('Mod W7Xsds05 621.914'),color='green',linestyle='dotted')
ax1.plot(t12, Q12, linewidth=1, label=('Mod W7Xsds06 104.719'),color='green',linestyle='dotted')
ax1.plot(t13, Q13, linewidth=1, label=('Mod W7Xsds06 198.992'),color='green',linestyle='dotted')
ax1.plot(t14, Q14, linewidth=1, label=('Mod W7Xsds09 59.952'),color='green',linestyle='dotted')
ax1.plot(t15, Q15, linewidth=1, label=('Mod W7Xhis05 110.997'),color='grey',linestyle='dotted')
ax1.plot(t16, Q16, linewidth=1, label=('Mod W7Xhis08 104.719'),color='grey',linestyle='dotted')
ax1.plot(t17, Q17, linewidth=1, label=('Mod W7Xhms036 104.719'),color='blue',linestyle='dotted')
ax1.plot(t18, Q18, linewidth=1, label=('Mod W7Xhms036 530.418'),color='blue',linestyle='dotted')
ax1.plot(t22, Q22, linewidth=1, label=('Mod W7Xhms08 78.832'),color='blue',linestyle='dotted')
ax1.plot(t19, Q19, linewidth=1, label=('Mod W7Xhms08 104.719'),color='blue',linestyle='dotted')
ax1.plot(t20, Q20, linewidth=1, label=('Mod W7Xhms08 266.000'),color='blue',linestyle='dotted')
ax1.plot(t21, Q21, linewidth=1, label=('Mod W7Xhms08 530.000'),color='blue',linestyle='dotted')
ax1.plot(t23, Q23, linewidth=1, label=('Mod W7Xlis06 104.719'),color='pink',linestyle='dotted')
ax1.plot(t24, Q24, linewidth=1, label=('Mod W7Xlis07 104.719'),color='pink',linestyle='dotted')
ax1.plot(t26, Q26, linewidth=1, label=('Mod W7Xlis08 90.837'),color='pink',linestyle='dotted')
ax1.plot(t25, Q25, linewidth=1, label=('Mod W7Xlis08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t27, Q27, linewidth=1, label=('Mod W7Xlis09 104.719'),color='pink',linestyle='dotted')
ax1.plot(t28, Q28, linewidth=1, label=('Mod W7Xlms05 104.719'),color='red',linestyle='dotted')
ax1.plot(t29, Q29, linewidth=1, label=('Mod W7Xlms05 136.837'),color='red',linestyle='dotted')
ax1.plot(t30, Q30, linewidth=1, label=('Mod W7Xsds036 104.719'),color='green',linestyle='dotted')
ax1.plot(t31, Q31, linewidth=1, label=('Mod W7Xsds05 130.316'),color='green',linestyle='dotted')
ax1.plot(t32, Q32, linewidth=1, label=('Mod W7Xsds05 260.633'),color='green',linestyle='dotted')
ax1.plot(t33, Q33, linewidth=1, label=('Mod W7Xsds06 138.185'),color='green',linestyle='dotted')
ax1.plot(t36, Q36, linewidth=1, label=('Mod W7Xsds08 68.805'),color='green',linestyle='dotted')
ax1.plot(t37, Q37, linewidth=1, label=('Mod W7Xsds08 95.562'),color='green',linestyle='dotted')
ax1.plot(t34, Q34, linewidth=1, label=('Mod W7Xsds08 104.719'),color='green',linestyle='dotted')
ax1.plot(t35, Q35, linewidth=1, label=('Mod W7Xsds08 137.61'),color='green',linestyle='dotted')
ax1.plot(t38, Q38, linewidth=1, label=('Mod W7Xsds09 104.719'),color='green',linestyle='dotted')
ax1.plot(t39, Q39, linewidth=1, label=('Mod W7Xlms09 104.719'),color='red',linestyle='dotted')
ax1.plot(t41, Q41, linewidth=1, label=('Mod W7Xlis05 681.85'),color='pink',linestyle='dotted')
ax1.plot(t40, Q40, linewidth=1, label=('Mod W7Xhms05 310.957'),color='blue',linestyle='dotted')
ax1.plot(t42, Q42, linewidth=1, label=('Mod W7Xlms05 684.184'),color='red',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#ALL REAL PART
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,1250])

ax1.plot(t1, E1, linewidth=1, label=('Re W7Xhis05 104.719'),color='grey',linestyle='dotted')
ax1.plot(t2, E2, linewidth=1, label=('Re W7Xhis05 665.979'),color='grey',linestyle='dotted')
ax1.plot(t3, E3, linewidth=1, label=('Re W7Xhms05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t4, E4, linewidth=1, label=('Re W7Xhms05 621.914'),color='blue',linestyle='dotted')
ax1.plot(t5, E5, linewidth=1, label=('Re W7Xlis05 104.719'),color='pink',linestyle='dotted')
ax1.plot(t6, E6, linewidth=1, label=('Re W7Xlis05 340.925'),color='pink',linestyle='dotted')
ax1.plot(t7, E7, linewidth=1, label=('Re W7Xsds025 104.719'),color='green',linestyle='dotted')
ax1.plot(t8, E8, linewidth=1, label=('Re W7Xsds025 774.957'),color='green',linestyle='dotted')
ax1.plot(t9, E9, linewidth=1, label=('Re W7Xsds036 436.87'),color='green',linestyle='dotted')
ax1.plot(t10, E10, linewidth=1, label=('Re W7Xsds05 104.719'),color='green',linestyle='dotted')
#ax1.plot(t11, E11, linewidth=1, label=('Re W7Xsds05 621.914'),color='green',linestyle='dotted')
ax1.plot(t12, E12, linewidth=1, label=('Re W7Xsds06 104.719'),color='green',linestyle='dotted')
ax1.plot(t13, E13, linewidth=1, label=('Re W7Xsds06 198.992'),color='green',linestyle='dotted')
ax1.plot(t14, E14, linewidth=1, label=('Re W7Xsds09 59.952'),color='green',linestyle='dotted')
ax1.plot(t15, E15, linewidth=1, label=('Re W7Xhis05 110.997'),color='grey',linestyle='dotted')
ax1.plot(t16, E16, linewidth=1, label=('Re W7Xhis08 104.719'),color='grey',linestyle='dotted')
ax1.plot(t17, E17, linewidth=1, label=('Re W7Xhms036 104.719'),color='blue',linestyle='dotted')
ax1.plot(t18, E18, linewidth=1, label=('Re W7Xhms036 530.418'),color='blue',linestyle='dotted')
ax1.plot(t22, E22, linewidth=1, label=('Re W7Xhms08 78.832'),color='blue',linestyle='dotted')
ax1.plot(t19, E19, linewidth=1, label=('Re W7Xhms08 104.719'),color='blue',linestyle='dotted')
ax1.plot(t20, E20, linewidth=1, label=('Re W7Xhms08 266.000'),color='blue',linestyle='dotted')
ax1.plot(t21, E21, linewidth=1, label=('Re W7Xhms08 530.000'),color='blue',linestyle='dotted')
ax1.plot(t23, E23, linewidth=1, label=('Re W7Xlis06 104.719'),color='pink',linestyle='dotted')
ax1.plot(t24, E24, linewidth=1, label=('Re W7Xlis07 104.719'),color='pink',linestyle='dotted')
ax1.plot(t26, E26, linewidth=1, label=('Re W7Xlis08 90.837'),color='pink',linestyle='dotted')
ax1.plot(t25, E25, linewidth=1, label=('Re W7Xlis08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t27, E27, linewidth=1, label=('Re W7Xlis09 104.719'),color='pink',linestyle='dotted')
ax1.plot(t28, E28, linewidth=1, label=('Re W7Xlms05 104.719'),color='red',linestyle='dotted')
ax1.plot(t29, E29, linewidth=1, label=('Re W7Xlms05 136.837'),color='red',linestyle='dotted')
ax1.plot(t30, E30, linewidth=1, label=('Re W7Xsds036 104.719'),color='green',linestyle='dotted')
ax1.plot(t31, E31, linewidth=1, label=('Re W7Xsds05 130.316'),color='green',linestyle='dotted')
ax1.plot(t32, E32, linewidth=1, label=('Re W7Xsds05 260.633'),color='green',linestyle='dotted')
ax1.plot(t33, E33, linewidth=1, label=('Re W7Xsds06 138.185'),color='green',linestyle='dotted')
ax1.plot(t36, E36, linewidth=1, label=('Re W7Xsds08 68.805'),color='green',linestyle='dotted')
ax1.plot(t37, E37, linewidth=1, label=('Re W7Xsds08 95.562'),color='green',linestyle='dotted')
ax1.plot(t34, E34, linewidth=1, label=('Re W7Xsds08 104.719'),color='green',linestyle='dotted')
ax1.plot(t35, E35, linewidth=1, label=('Re W7Xsds08 137.61'),color='green',linestyle='dotted')
ax1.plot(t38, E38, linewidth=1, label=('Re W7Xsds09 104.719'),color='green',linestyle='dotted')
ax1.plot(t39, E39, linewidth=1, label=('Re W7Xlms09 104.719'),color='red',linestyle='dotted')
ax1.plot(t41, E41, linewidth=1, label=('Re W7Xlis05 681.85'),color='pink',linestyle='dotted')
ax1.plot(t40, E40, linewidth=1, label=('Re W7Xhms05 310.957'),color='blue',linestyle='dotted')
ax1.plot(t42, E42, linewidth=1, label=('Re W7Xlms05 684.184'),color='red',linestyle='dotted')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#ALL IMAGINAIR PART
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,1250])

ax1.plot(t1, e1, linewidth=1, label=('Im W7Xhis05 104.719'),color='grey',linestyle='dotted')
ax1.plot(t2, e2, linewidth=1, label=('Im W7Xhis05 665.979'),color='grey',linestyle='dotted')
ax1.plot(t3, e3, linewidth=1, label=('Im W7Xhms05 104.719'),color='blue',linestyle='dotted')
ax1.plot(t4, e4, linewidth=1, label=('Im W7Xhms05 621.914'),color='blue',linestyle='dotted')
ax1.plot(t5, e5, linewidth=1, label=('Im W7Xlis05 104.719'),color='pink',linestyle='dotted')
ax1.plot(t6, e6, linewidth=1, label=('Im W7Xlis05 340.925'),color='pink',linestyle='dotted')
ax1.plot(t7, e7, linewidth=1, label=('Im W7Xsds025 104.719'),color='green',linestyle='dotted')
ax1.plot(t8, e8, linewidth=1, label=('Im W7Xsds025 774.957'),color='green',linestyle='dotted')
ax1.plot(t9, e9, linewidth=1, label=('Im W7Xsds036 436.87'),color='green',linestyle='dotted')
ax1.plot(t10, e10, linewidth=1, label=('Im W7Xsds05 104.719'),color='green',linestyle='dotted')
#ax1.plot(t11, e11, linewidth=1, label=('Im W7Xsds05 621.914'),color='green',linestyle='dotted')
ax1.plot(t12, e12, linewidth=1, label=('Im W7Xsds06 104.719'),color='green',linestyle='dotted')
ax1.plot(t13, e13, linewidth=1, label=('Im W7Xsds06 198.992'),color='green',linestyle='dotted')
ax1.plot(t14, e14, linewidth=1, label=('Im W7Xsds09 59.952'),color='green',linestyle='dotted')
ax1.plot(t15, e15, linewidth=1, label=('Im W7Xhis05 110.997'),color='grey',linestyle='dotted')
ax1.plot(t16, e16, linewidth=1, label=('Im W7Xhis08 104.719'),color='grey',linestyle='dotted')
ax1.plot(t17, e17, linewidth=1, label=('Im W7Xhms036 104.719'),color='blue',linestyle='dotted')
ax1.plot(t18, e18, linewidth=1, label=('Im W7Xhms036 530.418'),color='blue',linestyle='dotted')
ax1.plot(t22, e22, linewidth=1, label=('Im W7Xhms08 78.832'),color='blue',linestyle='dotted')
ax1.plot(t19, e19, linewidth=1, label=('Im W7Xhms08 104.719'),color='blue',linestyle='dotted')
ax1.plot(t20, e20, linewidth=1, label=('Im W7Xhms08 266.000'),color='blue',linestyle='dotted')
ax1.plot(t21, e21, linewidth=1, label=('Im W7Xhms08 530.000'),color='blue',linestyle='dotted')
ax1.plot(t23, e23, linewidth=1, label=('Im W7Xlis06 104.719'),color='pink',linestyle='dotted')
ax1.plot(t24, e24, linewidth=1, label=('Im W7Xlis07 104.719'),color='pink',linestyle='dotted')
ax1.plot(t26, e26, linewidth=1, label=('Im W7Xlis08 90.837'),color='pink',linestyle='dotted')
ax1.plot(t25, e25, linewidth=1, label=('Im W7Xlis08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t27, e27, linewidth=1, label=('Im W7Xlis09 104.719'),color='pink',linestyle='dotted')
ax1.plot(t28, e28, linewidth=1, label=('Im W7Xlms05 104.719'),color='red',linestyle='dotted')
ax1.plot(t29, e29, linewidth=1, label=('Im W7Xlms05 136.837'),color='red',linestyle='dotted')
ax1.plot(t30, e30, linewidth=1, label=('Im W7Xsds036 104.719'),color='green',linestyle='dotted')
ax1.plot(t31, e31, linewidth=1, label=('Im W7Xsds05 130.316'),color='green',linestyle='dotted')
ax1.plot(t32, e32, linewidth=1, label=('Im W7Xsds05 260.633'),color='green',linestyle='dotted')
ax1.plot(t33, e33, linewidth=1, label=('Im W7Xsds06 138.185'),color='green',linestyle='dotted')
ax1.plot(t36, e36, linewidth=1, label=('Im W7Xsds08 68.805'),color='green',linestyle='dotted')
ax1.plot(t37, e37, linewidth=1, label=('Im W7Xsds08 95.562'),color='green',linestyle='dotted')
ax1.plot(t34, e34, linewidth=1, label=('Im W7Xsds08 104.719'),color='green',linestyle='dotted')
ax1.plot(t35, e35, linewidth=1, label=('Im W7Xsds08 137.61'),color='green',linestyle='dotted')
ax1.plot(t38, e38, linewidth=1, label=('Im W7Xsds09 104.719'),color='green',linestyle='dotted')
ax1.plot(t39, e39, linewidth=1, label=('Im W7Xlms09 104.719'),color='red',linestyle='dotted')
ax1.plot(t41, e41, linewidth=1, label=('Im W7Xlis05 681.85'),color='pink',linestyle='dotted')
ax1.plot(t40, e40, linewidth=1, label=('Im W7Xhms05 310.957'),color='blue',linestyle='dotted')
ax1.plot(t42, e42, linewidth=1, label=('Im W7Xlms05 684.184'),color='red',linestyle='dotted')
plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=5)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)
