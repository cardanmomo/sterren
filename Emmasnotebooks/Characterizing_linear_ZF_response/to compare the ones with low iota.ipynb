# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Lissa.ipynb
# Out:
# loading successful!

# %%
data5 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/104.719/gamdiagions_act.dat')
E5 = (data5[:,1]*(1/data5[0, 1]))
e5 = (data5[:,2]*(1/data5[0, 1]))
t5 = data5[:,0]

data6 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/340.925/gamdiagions_act.dat')
E6 = (data6[:,1]*(1/data6[0, 1]))
e6 = (data6[:,2]*(1/data6[0, 1]))
t6 = data6[:,0]

data23 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis06/GAM/104.719/gamdiagions_act.dat')
E23 = (data23[:,1]*(1/data23[0, 1]))
e23 = (data23[:,2]*(1/data23[0, 1]))
t23 = data23[:,0]

data24 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis07/GAM/104.719/gamdiagions_act.dat')
E24 = (data24[:,1]*(1/data24[0, 1]))
e24 = (data24[:,2]*(1/data24[0, 1]))
t24 = data24[:,0]

data25 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/104.719/gamdiagions_act.dat')
E25 = (data25[:,1]*(1/data25[0, 1]))
e25 = (data25[:,2]*(1/data25[0, 1]))
t25 = data25[:,0]

data26 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis08/GAM/90.837/gamdiagions_act.dat')
E26 = (data26[:,1]*(1/data26[0, 1]))
e26 = (data26[:,2]*(1/data26[0, 1]))
t26 = data26[:,0]

data27 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis09/GAM/104.719/gamdiagions_act.dat')
E27 = (data27[:,1]*(1/data27[0, 1]))
e27 = (data27[:,2]*(1/data27[0, 1]))
t27 = data27[:,0]

data41 = pylab.loadtxt('C:/Users/s162605/Documents/Studie/JAAR3/BEP/sterren/IFERC/W7Xlis05/GAM/681.85_P/gamdiagions_act.dat')
E41 = (data41[:,1]*(1/data41[0, 1]))
e41 = (data41[:,2]*(1/data41[0, 1]))
t41 = data41[:,0]

Q5 = np.sqrt(E5**2+e5**2)
Q6 = np.sqrt(E6**2+e6**2)
Q23 = np.sqrt(E23**2+e23**2)
Q24 = np.sqrt(E24**2+e24**2)
Q25 = np.sqrt(E25**2+e25**2)
Q26 = np.sqrt(E26**2+e26**2)
Q27 = np.sqrt(E27**2+e27**2)
Q41 = np.sqrt(E41**2+e41**2)

# %%
#plot of the moduli / real parts
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,])
plt.xlim([-10,1000])

#ax1.plot(t5, E5, linewidth=1, label=('Re W7Xlis05 104.719'),color='blue')
#ax1.plot(t6, E6, linewidth=1, label=('Re W7Xlis05 340.925'),color='blue',linestyle='dotted')
#ax1.plot(t41, E41, linewidth=1, label=('Re W7Xlis05 681.85'),color='blue',linestyle='dashed')
#ax1.plot(t23, E23, linewidth=1, label=('Re W7Xlis06 104.719'),color='grey')
#ax1.plot(t24, E24, linewidth=1, label=('Re W7Xlis07 104.719'),color='cyan')
#ax1.plot(t26, E26, linewidth=1, label=('Re W7Xlis08 90.837'),color='pink',linestyle='dotted')
#ax1.plot(t25, E25, linewidth=1, label=('Re W7Xlis08 104.719'),color='pink')
#ax1.plot(t27, E27, linewidth=1, label=('Re W7Xlis09 104.719'),color='green')

ax1.plot(t5, Q5, linewidth=1, label=('Mod W7Xlis05 104.719'),color='blue')
ax1.plot(t6, Q6, linewidth=1, label=('Mod W7Xlis05 340.925'),color='blue',linestyle='dotted')
ax1.plot(t41, Q41, linewidth=1, label=('Mod W7Xlis05 681.85'),color='blue',linestyle='dashed')
ax1.plot(t23, Q23, linewidth=1, label=('Mod W7Xlis06 104.719'),color='grey')
ax1.plot(t24, Q24, linewidth=1, label=('Mod W7Xlis07 104.719'),color='cyan')
ax1.plot(t26, Q26, linewidth=1, label=('Mod W7Xlis08 90.837'),color='pink',linestyle='dotted')
ax1.plot(t25, Q25, linewidth=1, label=('Mod W7Xlis08 104.719'),color='pink')
ax1.plot(t27, Q27, linewidth=1, label=('Mod W7Xlis09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of the imaginary parts
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota imaginary parts of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,1200])

ax1.plot(t5, e5, linewidth=1, label=('Im W7Xlis05 104.719'),color='blue')
ax1.plot(t6, e6, linewidth=1, label=('Im W7Xlis05 340.925'),color='blue',linestyle='dotted')
ax1.plot(t41, e41, linewidth=1, label=('Im W7Xlis05 681.85'),color='blue',linestyle='dashed')
ax1.plot(t23, e23, linewidth=1, label=('Im W7Xlis06 104.719'),color='grey')
ax1.plot(t24, e24, linewidth=1, label=('Im W7Xlis07 104.719'),color='cyan')
ax1.plot(t26, e26, linewidth=1, label=('Im W7Xlis08 90.837'),color='pink',linestyle='dotted')
ax1.plot(t25, e25, linewidth=1, label=('Im W7Xlis08 104.719'),color='pink')
ax1.plot(t27, e27, linewidth=1, label=('Im W7Xlis09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of low iota s=0.5
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota s=0.5', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,1200])

ax1.plot(t5, e5, linewidth=2, label=('Im W7Xlis05 104.719'),color='cyan',linestyle='dotted')
ax1.plot(t5, E5, linewidth=2, label=('Re W7Xlis05 104.719'),color='cyan',linestyle='dashed')
ax1.plot(t5, Q5, linewidth=2, label=('Mod W7Xlis05 104.719'),color='cyan')
ax1.plot(t6, e6, linewidth=2, label=('Im W7Xlis05 340.925'),color='pink',linestyle='dotted')
ax1.plot(t6, E6, linewidth=2, label=('Re W7Xlis05 340.925'),color='pink',linestyle='dashed')
ax1.plot(t6, Q6, linewidth=2, label=('Mod W7Xlis05 340.925'),color='pink')
ax1.plot(t41, e41, linewidth=2, label=('Im W7Xlis05 681.85'),color='fuchsia',linestyle='dotted')
ax1.plot(t41, E41, linewidth=2, label=('Re W7Xlis05 681.85'),color='fuchsia',linestyle='dashed')
ax1.plot(t41, Q41, linewidth=2, label=('Mod W7Xlis05 681.85'),color='fuchsia')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of low iota s=0.8
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota s=0.8', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.1])
plt.xlim([-10,1200])

ax1.plot(t26, e26, linewidth=2, label=('Im W7Xlis08 90.837'),color='cyan',linestyle='dotted')
ax1.plot(t26, E26, linewidth=2, label=('Re W7Xlis08 90.837'),color='cyan',linestyle='dashed')
ax1.plot(t26, Q26, linewidth=2, label=('Mod W7Xlis08 90.837'),color='cyan')
ax1.plot(t25, e25, linewidth=2, label=('Im W7Xlis08 104.719'),color='pink',linestyle='dotted')
ax1.plot(t25, E25, linewidth=2, label=('Re W7Xlis08 104.719'),color='pink',linestyle='dashed')
ax1.plot(t25, Q25, linewidth=2, label=('Mod W7Xlis08 104.719'),color='pink')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)

# %%
#plot of low iota Lx=104.719
#plot of the moduli / real parts
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota $L_x = 104.719$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
plt.ylim([-0.1,0.2])
plt.xlim([0,1000])

ax1.plot(t5, E5, linewidth=2, label=('Re W7Xlis05 104.719'),color='blue')
ax1.plot(t23, E23, linewidth=1, label=('Re W7Xlis06 104.719'),color='grey')
ax1.plot(t24, E24, linewidth=1, label=('Re W7Xlis07 104.719'),color='cyan')
ax1.plot(t25, E25, linewidth=1, label=('Re W7Xlis08 104.719'),color='pink')
ax1.plot(t27, E27, linewidth=1, label=('Re W7Xlis09 104.719'),color='green')

#ax1.plot(t5, Q5, linewidth=1, label=('Mod W7Xlis05 104.719'),color='blue')
#ax1.plot(t23, Q23, linewidth=1, label=('Mod W7Xlis06 104.719'),color='grey')
#ax1.plot(t24, Q24, linewidth=1, label=('Mod W7Xlis07 104.719'),color='cyan')
#ax1.plot(t25, Q25, linewidth=1, label=('Mod W7Xlis08 104.719'),color='pink')
#ax1.plot(t27, Q27, linewidth=1, label=('Mod W7Xlis09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200) 

#plot of the imaginary parts
fig, ax1 = plt.subplots(figsize=(13, 7))
plt.title('W7-X Low Iota $L_x = 104.719$ imaginary parts of $\phi$', fontsize=30)
ax1.set_xlabel('Time ($a / v_{ti}$)',fontsize=16)
ax1.set_ylabel('$\phi (t) / \phi (0)$',fontsize=16)
ax1.axhline(y=0, color='black', linestyle='dashed')
#plt.ylim([0,0.2])
#plt.xlim([200,400])

ax1.plot(t5, e5, linewidth=1, label=('Im W7Xlis05 104.719'),color='blue')
ax1.plot(t23, e23, linewidth=1, label=('Im W7Xlis06 104.719'),color='grey')
ax1.plot(t24, e24, linewidth=1, label=('Im W7Xlis07 104.719'),color='cyan')
ax1.plot(t25, e25, linewidth=1, label=('Im W7Xlis08 104.719'),color='pink')
ax1.plot(t27, e27, linewidth=1, label=('Im W7Xlis09 104.719'),color='green')

plt.legend(loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=2)

fig.tight_layout()
#plt.savefig('../../CMSS_2018/Poster/Salpha_nlzf_plot.pdf', format='pdf', dpi=1200)
