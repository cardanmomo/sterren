# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
nonlinearT = [0.160191908,0.761999776,1.59266369,2.832615764,0.342548193,0.865735177,0.944807212,2.338129523,0.369014375,1.930288096,5.624242538,0.330627321,5.201439737,0.023917062,0.030479089,0.311666314,0.290796029,2.024493667,2.267726197,5.80117908,0.339727005,1.795064953,0.249874813,0.257770957]
nonlinearZ = [0.316027695,0.001384291,0.00252617,0.001278068,0.066100954,0.000660068,0.000659736,0.000430237,0.0000141,0.0000450,0.000105281,0.0000358,0.000260021,0.00000899,0.00000657,0.0000358,0.0000763,0.000429192,0.095636211,0.00065994,0.000511542,0.000782868,0.000203058,0.000623019]

# %%
nonlinear_squared_ZT = [(nonlinearZ[0]/nonlinearT[0])**(1/2),(nonlinearZ[1]/nonlinearT[1])**(1/2),(nonlinearZ[2]/nonlinearT[2])**(1/2),(nonlinearZ[3]/nonlinearT[3])**(1/2),(nonlinearZ[4]/nonlinearT[4])**(1/2),(nonlinearZ[5]/nonlinearT[5])**(1/2),(nonlinearZ[6]/nonlinearT[6])**(1/2),(nonlinearZ[7]/nonlinearT[7])**(1/2),(nonlinearZ[8]/nonlinearT[8])**(1/2),(nonlinearZ[9]/nonlinearT[9])**(1/2),(nonlinearZ[10]/nonlinearT[10])**(1/2),(nonlinearZ[11]/nonlinearT[11])**(1/2),(nonlinearZ[12]/nonlinearT[12])**(1/2),(nonlinearZ[13]/nonlinearT[13])**(1/2),(nonlinearZ[14]/nonlinearT[14])**(1/2),(nonlinearZ[15]/nonlinearT[15])**(1/2),(nonlinearZ[16]/nonlinearT[16])**(1/2),(nonlinearZ[17]/nonlinearT[17])**(1/2),(nonlinearZ[18]/nonlinearT[18])**(1/2),(nonlinearZ[19]/nonlinearT[19])**(1/2),(nonlinearZ[20]/nonlinearT[20])**(1/2),(nonlinearZ[21]/nonlinearT[21])**(1/2),(nonlinearZ[22]/nonlinearT[22])**(1/2),(nonlinearZ[23]/nonlinearT[23])**(1/2)]
linear = [integ21,integ151,integ151,integ221,integ61,integ261,integ261,integ291,integ81,integ81,integ81,integ91,integ91,integ321,integ321,integ321,integ131,integ131,integ331,integ131,integ361,integ361,integ351,integ141]

# %%
import matplotlib.markers
plt.scatter(linear[2],nonlinear_squared_ZT[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[6],nonlinear_squared_ZT[6], color='lime',label='W7Xlis08 90.837', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[9],nonlinear_squared_ZT[9], color='blue',label='W7Xsds025 774.957', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[12],nonlinear_squared_ZT[12], color='grey',label='W7Xsds036 436.87', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[14],nonlinear_squared_ZT[14], color='cyan',label='W7Xsds05 260.633', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],nonlinear_squared_ZT[17], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],nonlinear_squared_ZT[21], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[0],nonlinear_squared_ZT[0],color='purple',label='W7Xhis05 665.979', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],nonlinear_squared_ZT[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[3],nonlinear_squared_ZT[3],color='red',label='W7Xhms08 78.832', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[4],nonlinear_squared_ZT[4],color='green',label='W7Xlis05 340.925', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],nonlinear_squared_ZT[5],color='lime',label='W7Xlis08 90.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],nonlinear_squared_ZT[7],color='orange',label='W7Xlms05 136.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],nonlinear_squared_ZT[8],color='blue',label='W7Xsds025 774.957', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],nonlinear_squared_ZT[11],color='grey',label='W7Xsds036 436.87', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],nonlinear_squared_ZT[13],color='cyan',label='W7Xsds05 260.633', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],nonlinear_squared_ZT[16],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[18],nonlinear_squared_ZT[18],color='navy',label='W7Xsds06 138.185', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],nonlinear_squared_ZT[20],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],nonlinear_squared_ZT[22],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],nonlinear_squared_ZT[23],color='skyblue',label='W7Xsds09 59.952', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[10],nonlinear_squared_ZT[10], color='blue',label='W7Xsds025 774.957', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[15],nonlinear_squared_ZT[15], color='cyan',label='W7Xsds05 260.633', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[19],nonlinear_squared_ZT[19], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('square root of Z/T',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.2,1.5])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear[2],nonlinear_squared_ZT[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[0],nonlinear_squared_ZT[0],color='purple',label='W7Xhis05 665.979', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],nonlinear_squared_ZT[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('square root of Z/T',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.2,1.5])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear[6],nonlinear_squared_ZT[6], color='lime',label='W7Xlis08 90.837', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[4],nonlinear_squared_ZT[4],color='green',label='W7Xlis05 340.925', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],nonlinear_squared_ZT[5],color='lime',label='W7Xlis08 90.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('square root of Z/T',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.2,1.5])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear[9],nonlinear_squared_ZT[9], color='blue',label='W7Xsds025 774.957', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[12],nonlinear_squared_ZT[12], color='grey',label='W7Xsds036 436.87', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[14],nonlinear_squared_ZT[14], color='cyan',label='W7Xsds05 260.633', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],nonlinear_squared_ZT[17], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],nonlinear_squared_ZT[21], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],nonlinear_squared_ZT[8],color='blue',label='W7Xsds025 774.957', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],nonlinear_squared_ZT[11],color='grey',label='W7Xsds036 436.87', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],nonlinear_squared_ZT[13],color='cyan',label='W7Xsds05 260.633', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],nonlinear_squared_ZT[16],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[18],nonlinear_squared_ZT[18],color='navy',label='W7Xsds06 138.185', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],nonlinear_squared_ZT[20],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],nonlinear_squared_ZT[22],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],nonlinear_squared_ZT[23],color='skyblue',label='W7Xsds09 59.952', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[10],nonlinear_squared_ZT[10], color='blue',label='W7Xsds025 774.957', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[15],nonlinear_squared_ZT[15], color='cyan',label='W7Xsds05 260.633', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[19],nonlinear_squared_ZT[19], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('square root of Z/T',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.2,1.5])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear[3],nonlinear_squared_ZT[3],color='red',label='W7Xhms08 78.832', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],nonlinear_squared_ZT[7],color='orange',label='W7Xlms05 136.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('square root of Z/T',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.2,1.5])
plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!
