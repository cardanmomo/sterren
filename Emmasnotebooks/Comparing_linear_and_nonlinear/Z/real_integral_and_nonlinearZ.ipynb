# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
nonlinearT = [0.160191908,0.761999776,1.59266369,2.832615764,0.342548193,0.865735177,0.944807212,2.338129523,0.369014375,1.930288096,5.624242538,0.330627321,5.201439737,0.023917062,0.030479089,0.311666314,0.290796029,2.024493667,2.267726197,5.80117908,0.339727005,1.795064953,0.249874813,0.257770957]
nonlinearZ = [0.316027695,0.001384291,0.00252617,0.001278068,0.066100954,0.000660068,0.000659736,0.000430237,0.0000141,0.0000450,0.000105281,0.0000358,0.000260021,0.00000899,0.00000657,0.0000358,0.0000763,0.000429192,0.095636211,0.00065994,0.000511542,0.000782868,0.000203058,0.000623019]

linear_real = [integ22,integ152,integ152,integ222,integ62,integ262,integ262,integ292,integ82,integ82,integ82,integ92,integ92,integ322,integ322,integ322,integ132,integ132,integ332,integ132,integ362,integ362,integ352,integ142]

# %%
import matplotlib.markers
plt.scatter(linear_real[2],nonlinearZ[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[6],nonlinearZ[6], color='lime',label='W7Xlis08 90.837', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[9],nonlinearZ[9], color='blue',label='W7Xsds025 774.957', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[12],nonlinearZ[12], color='grey',label='W7Xsds036 436.87', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[14],nonlinearZ[14], color='cyan',label='W7Xsds05 260.633', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[17],nonlinearZ[17], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[21],nonlinearZ[21], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[0],nonlinearZ[0],color='purple',label='W7Xhis05 665.979', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[1],nonlinearZ[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[3],nonlinearZ[3],color='red',label='W7Xhms08 78.832', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[4],nonlinearZ[4],color='green',label='W7Xlis05 340.925', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[5],nonlinearZ[5],color='lime',label='W7Xlis08 90.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[7],nonlinearZ[7],color='orange',label='W7Xlms05 136.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[8],nonlinearZ[8],color='blue',label='W7Xsds025 774.957', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[11],nonlinearZ[11],color='grey',label='W7Xsds036 436.87', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[13],nonlinearZ[13],color='cyan',label='W7Xsds05 260.633', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[16],nonlinearZ[16],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[18],nonlinearZ[18],color='navy',label='W7Xsds06 138.185', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[20],nonlinearZ[20],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[22],nonlinearZ[22],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[23],nonlinearZ[23],color='skyblue',label='W7Xsds09 59.952', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[10],nonlinearZ[10], color='blue',label='W7Xsds025 774.957', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[15],nonlinearZ[15], color='cyan',label='W7Xsds05 260.633', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[19],nonlinearZ[19], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-10,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear_real[2],nonlinearZ[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[0],nonlinearZ[0],color='purple',label='W7Xhis05 665.979', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[1],nonlinearZ[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-10,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear_real[6],nonlinearZ[6], color='lime',label='W7Xlis08 90.837', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[4],nonlinearZ[4],color='green',label='W7Xlis05 340.925', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[5],nonlinearZ[5],color='lime',label='W7Xlis08 90.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-10,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear_real[9],nonlinearZ[9], color='blue',label='W7Xsds025 774.957', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[12],nonlinearZ[12], color='grey',label='W7Xsds036 436.87', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[14],nonlinearZ[14], color='cyan',label='W7Xsds05 260.633', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[17],nonlinearZ[17], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[21],nonlinearZ[21], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[8],nonlinearZ[8],color='blue',label='W7Xsds025 774.957', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[11],nonlinearZ[11],color='grey',label='W7Xsds036 436.87', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[13],nonlinearZ[13],color='cyan',label='W7Xsds05 260.633', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[16],nonlinearZ[16],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[18],nonlinearZ[18],color='navy',label='W7Xsds06 138.185', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[20],nonlinearZ[20],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[22],nonlinearZ[22],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[23],nonlinearZ[23],color='skyblue',label='W7Xsds09 59.952', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[10],nonlinearZ[10], color='blue',label='W7Xsds025 774.957', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[15],nonlinearZ[15], color='cyan',label='W7Xsds05 260.633', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[19],nonlinearZ[19], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-10,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!

# %%
import matplotlib.markers
plt.scatter(linear_real[3],nonlinearZ[3],color='red',label='W7Xhms08 78.832', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear_real[7],nonlinearZ[7],color='orange',label='W7Xlms05 136.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Integral over real part of linear $\phi$',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('Nonlinear data',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
plt.ylim([-0.05,0.35])
plt.xlim([-10,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!
