# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Zonal_flow_decay_time\barplots_zonal_flow_decay_time.ipynb
# Out:
# loading successful!

# %%
nonlinearT = [0.160191908,0.761999776,1.59266369,2.832615764,0.342548193,0.865735177,0.944807212,2.338129523,0.369014375,1.930288096,5.624242538,0.330627321,5.201439737,0.023917062,0.030479089,0.311666314,0.290796029,2.024493667,2.267726197,5.80117908,0.339727005,1.795064953,0.249874813,0.257770957]
nonlinearZ = [0.316027695,0.001384291,0.00252617,0.001278068,0.066100954,0.000660068,0.000659736,0.000430237,0.0000141,0.0000450,0.000105281,0.0000358,0.000260021,0.00000899,0.00000657,0.0000358,0.0000763,0.000429192,0.095636211,0.00065994,0.000511542,0.000782868,0.000203058,0.000623019]
nonlinear_squareroot_Z_T = [((nonlinearZ[0])**(1/2))/nonlinearT[0],((nonlinearZ[1])**(1/2))/nonlinearT[1],((nonlinearZ[2])**(1/2))/nonlinearT[2],((nonlinearZ[3])**(1/2))/nonlinearT[3],((nonlinearZ[4])**(1/2))/nonlinearT[4],((nonlinearZ[5])**(1/2))/nonlinearT[5],((nonlinearZ[6])**(1/2))/nonlinearT[6],((nonlinearZ[7])**(1/2))/nonlinearT[7],((nonlinearZ[8])**(1/2))/nonlinearT[8],((nonlinearZ[9])**(1/2))/nonlinearT[9],((nonlinearZ[10])**(1/2))/nonlinearT[10],((nonlinearZ[11])**(1/2))/nonlinearT[11],((nonlinearZ[12])**(1/2))/nonlinearT[12],((nonlinearZ[13])**(1/2))/nonlinearT[13],((nonlinearZ[14])**(1/2))/nonlinearT[14],((nonlinearZ[15])**(1/2))/nonlinearT[15],((nonlinearZ[16])**(1/2))/nonlinearT[16],((nonlinearZ[17])**(1/2))/nonlinearT[17],((nonlinearZ[18])**(1/2))/nonlinearT[18],((nonlinearZ[19])**(1/2))/nonlinearT[19],((nonlinearZ[20])**(1/2))/nonlinearT[20],((nonlinearZ[21])**(1/2))/nonlinearT[21],((nonlinearZ[22])**(1/2))/nonlinearT[22],((nonlinearZ[23])**(1/2))/nonlinearT[23]]
linear = [integ21,integ151,integ151,integ221,integ61,integ261,integ261,integ291,integ81,integ81,integ81,integ91,integ91,integ321,integ321,integ321,integ131,integ131,integ331,integ131,integ361,integ361,integ351,integ141]

# %%
import matplotlib.markers
plt.scatter(linear[2],nonlinear_squareroot_Z_T[2], color='magenta',label='W7Xhis05 110.997', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[6],nonlinear_squareroot_Z_T[6], color='lime',label='W7Xlis08 90.837', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[9],nonlinear_squareroot_Z_T[9], color='blue',label='W7Xsds025 774.957', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[12],nonlinear_squareroot_Z_T[12], color='grey',label='W7Xsds036 436.87', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[14],nonlinear_squareroot_Z_T[14], color='cyan',label='W7Xsds05 260.633', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[17],nonlinear_squareroot_Z_T[17], color='darkcyan',label='W7Xsds06 198.992', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[21],nonlinear_squareroot_Z_T[21], color='dodgerblue',label='W7Xsds08 68.805', marker='2',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[0],nonlinear_squareroot_Z_T[0],color='purple',label='W7Xhis05 665.979', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[1],nonlinear_squareroot_Z_T[1],color='magenta',label='W7Xhis05 110.997', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[3],nonlinear_squareroot_Z_T[3],color='red',label='W7Xhms08 78.832', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[4],nonlinear_squareroot_Z_T[4],color='green',label='W7Xlis05 340.925', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[5],nonlinear_squareroot_Z_T[5],color='lime',label='W7Xlis08 90.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[7],nonlinear_squareroot_Z_T[7],color='orange',label='W7Xlms05 136.837', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[8],nonlinear_squareroot_Z_T[8],color='blue',label='W7Xsds025 774.957', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[11],nonlinear_squareroot_Z_T[11],color='grey',label='W7Xsds036 436.87', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[13],nonlinear_squareroot_Z_T[13],color='cyan',label='W7Xsds05 260.633', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[16],nonlinear_squareroot_Z_T[16],color='darkcyan',label='W7Xsds06 198.992', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[18],nonlinear_squareroot_Z_T[18],color='navy',label='W7Xsds06 138.185', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[20],nonlinear_squareroot_Z_T[20],color='dodgerblue',label='W7Xsds08 68.805', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[22],nonlinear_squareroot_Z_T[22],color='deepskyblue',label='W7Xsds08 137.61', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[23],nonlinear_squareroot_Z_T[23],color='skyblue',label='W7Xsds09 59.952', marker='1',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[10],nonlinear_squareroot_Z_T[10], color='blue',label='W7Xsds025 774.957', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[15],nonlinear_squareroot_Z_T[15], color='cyan',label='W7Xsds05 260.633', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(linear[19],nonlinear_squareroot_Z_T[19], color='darkcyan',label='W7Xsds06 198.992', marker='3',s=500, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('Zonal flow decay time',fontsize=10)
#plt.yticks(fontsize=18)
plt.ylabel('T/square root of Z',fontsize=10)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6)
plt.tight_layout
#rect=[0, 0, 4, 3]
#plt.ylim([-0.2,1.5])
#plt.xlim([0,225])
plt.show()
#plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/tau_ZF_comparison.pdf', format='pdf', dpi=1200)

#eenheden checken!
