# %%
# %run C:\Users\s162605\Documents\Studie\JAAR3\BEP\sterren\Emmasnotebooks\Residual\calculating_residual_values_of_all_datasets.ipynb
# Out:
# loading successful!

# %%
import pandas as pd
datashear = pd.read_csv (r'C:\Users\s162605\Documents\Studie\JAAR3\BEP\Data\sheardata.csv')
shear = pd.DataFrame(datashear, columns= ['magnetic shear'])
#print(shear.values)

# %%
sheardata = [shear.values[0],shear.values[1],shear.values[2],shear.values[3],shear.values[4],shear.values[5],
             shear.values[6],shear.values[7],shear.values[8],shear.values[9],shear.values[10],shear.values[11],
             shear.values[12],shear.values[13],shear.values[14],shear.values[15],shear.values[16],shear.values[17],
             shear.values[18],shear.values[19],shear.values[20],shear.values[21],shear.values[22],shear.values[23],
             shear.values[24],shear.values[25],shear.values[26],shear.values[27],shear.values[28],shear.values[29],
             shear.values[30],shear.values[31],shear.values[32],shear.values[33],shear.values[34],shear.values[35],
             shear.values[36],shear.values[37],shear.values[38],shear.values[39],shear.values[40],shear.values[41]]

residual = [residual1,residual2,residual15,residual16,residual17,residual18,residual3,residual4,residual40,residual19,
            residual20,residual21,residual22,residual5,residual6,residual41,residual23,residual24,residual25,
            residual26,residual27,residual28,residual29,residual42,residual39,residual7,residual8,residual9,
            residual30,residual10,residual11,residual31,residual32,residual12,residual13,residual33,residual34,
            residual35,residual36,residual37,residual14,residual38]

# %%
import matplotlib.markers

plt.scatter(residual[0],shear.values[0], color='purple',label='W7Xhis05 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[1],shear.values[1], color='purple',label='W7Xhis05 665.979', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[2],shear.values[2], color='purple',label='W7Xhis05 110.997', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[3],shear.values[3], color='magenta',label='W7Xhis08 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[4],shear.values[4], color='red',label='W7Xhms036 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[5],shear.values[5], color='red',label='W7Xhms036 530.418', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[6],shear.values[6], color='darkred',label='W7Xhms05 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[7],shear.values[7], color='darkred',label='W7Xhms05 621.914', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[8],shear.values[8], color='darkred',label='W7Xhms05 310.957', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[9],shear.values[9], color='tomato',label='W7Xhms08 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[10],shear.values[10], color='tomato',label='W7Xhms08 266.000', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[11],shear.values[11], color='tomato',label='W7Xhms08 530.000', marker='4',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[12],shear.values[12], color='tomato',label='W7Xhms08 78.832', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[13],shear.values[13], color='green',label='W7Xlis05 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[14],shear.values[14], color='green',label='W7Xlis05 340.925', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[15],shear.values[15], color='green',label='W7Xlis05 681.850', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[16],shear.values[16], color='lime',label='W7Xlis06 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[17],shear.values[17], color='darkgreen',label='W7Xlis07 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[18],shear.values[18], color='lightgreen',label='W7Xlis08 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[19],shear.values[19], color='lightgreen',label='W7Xlis08 90.837', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[20],shear.values[20], color='mediumseagreen',label='W7Xlis09 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[21],shear.values[21], color='orange',label='W7Xlms05 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[22],shear.values[22], color='orange',label='W7Xlms05 136.837', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[23],shear.values[23], color='orange',label='W7Xlms05 684.184', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[24],shear.values[24], color='navajowhite',label='W7Xlms09 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[25],shear.values[25], color='blue',label='W7Xsds025 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[26],shear.values[26], color='blue',label='W7Xsds025 774.957', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[27],shear.values[27], color='darkcyan',label='W7Xsds036 436.870', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[28],shear.values[28], color='darkcyan',label='W7Xsds036 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[29],shear.values[29], color='cyan',label='W7Xsds05 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[30],shear.values[30], color='cyan',label='W7Xsds05 621.914', marker='4',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[31],shear.values[31], color='cyan',label='W7Xsds05 130.316', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[32],shear.values[32], color='cyan',label='W7Xsds05 260.633', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[33],shear.values[33], color='dodgerblue',label='W7Xsds06 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[34],shear.values[34], color='dodgerblue',label='W7Xsds06 198.992', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[35],shear.values[35], color='dodgerblue',label='W7Xsds06 138.185', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[36],shear.values[36], color='navy',label='W7Xsds08 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[37],shear.values[37], color='navy',label='W7Xsds08 137.610', marker='4',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[38],shear.values[38], color='navy',label='W7Xsds08 68.805', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[39],shear.values[39], color='navy',label='W7Xsds08 95.562', marker='3',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[40],shear.values[40], color='deepskyblue',label='W7Xsds09 59.952', marker='2',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[41],shear.values[41], color='deepskyblue',label='W7Xsds09 104.719', marker='1',s=300, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('residual value',fontsize=10)
plt.yticks(fontsize=10)########################### at least 20 for report ##############
plt.xticks(fontsize=10)
plt.ylabel('Magnetic global shear',fontsize=10)
plt.xlim([-0.0025,0.03])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6, borderpad=1,labelspacing=1,fontsize=10)
plt.tight_layout()#(rect=[0, 0, 4, 3,])
#plt.ylim([-2,20])
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residual_vs_gobalshear.pdf', format='pdf', dpi=1200)
plt.show()

# %%
import matplotlib.markers

plt.scatter(residual[0],shear.values[0], color='purple',label='W7Xhis05 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[1],shear.values[1], color='purple',label='W7Xhis05 665.979', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[2],shear.values[2], color='purple',label='W7Xhis05 110.997', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[3],shear.values[3], color='magenta',label='W7Xhis08 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[4],shear.values[4], color='red',label='W7Xhms036 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[5],shear.values[5], color='red',label='W7Xhms036 530.418', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[6],shear.values[6], color='darkred',label='W7Xhms05 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[7],shear.values[7], color='darkred',label='W7Xhms05 621.914', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[8],shear.values[8], color='darkred',label='W7Xhms05 310.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[9],shear.values[9], color='tomato',label='W7Xhms08 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[10],shear.values[10], color='tomato',label='W7Xhms08 266.000', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[11],shear.values[11], color='tomato',label='W7Xhms08 530.000', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[12],shear.values[12], color='tomato',label='W7Xhms08 78.832', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[13],shear.values[13], color='green',label='W7Xlis05 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[14],shear.values[14], color='green',label='W7Xlis05 340.925', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[15],shear.values[15], color='green',label='W7Xlis05 681.850', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[16],shear.values[16], color='lime',label='W7Xlis06 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[17],shear.values[17], color='darkgreen',label='W7Xlis07 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[18],shear.values[18], color='lightgreen',label='W7Xlis08 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[19],shear.values[19], color='lightgreen',label='W7Xlis08 90.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[20],shear.values[20], color='mediumseagreen',label='W7Xlis09 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[21],shear.values[21], color='orange',label='W7Xlms05 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[22],shear.values[22], color='orange',label='W7Xlms05 136.837', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[23],shear.values[23], color='orange',label='W7Xlms05 684.184', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[24],shear.values[24], color='navajowhite',label='W7Xlms09 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[25],shear.values[25], color='blue',label='W7Xsds025 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[26],shear.values[26], color='blue',label='W7Xsds025 774.957', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[27],shear.values[27], color='darkcyan',label='W7Xsds036 436.870', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[28],shear.values[28], color='darkcyan',label='W7Xsds036 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[29],shear.values[29], color='cyan',label='W7Xsds05 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[30],shear.values[30], color='cyan',label='W7Xsds05 621.914', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[31],shear.values[31], color='cyan',label='W7Xsds05 130.316', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[32],shear.values[32], color='cyan',label='W7Xsds05 260.633', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[33],shear.values[33], color='dodgerblue',label='W7Xsds06 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[34],shear.values[34], color='dodgerblue',label='W7Xsds06 198.992', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[35],shear.values[35], color='dodgerblue',label='W7Xsds06 138.185', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[36],shear.values[36], color='navy',label='W7Xsds08 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[37],shear.values[37], color='navy',label='W7Xsds08 137.610', marker='4',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[38],shear.values[38], color='navy',label='W7Xsds08 68.805', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[39],shear.values[39], color='navy',label='W7Xsds08 95.562', marker='3',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

plt.scatter(residual[40],shear.values[40], color='deepskyblue',label='W7Xsds09 59.952', marker='2',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)
plt.scatter(residual[41],shear.values[41], color='deepskyblue',label='W7Xsds09 104.719', marker='1',s=700, cmap=None, alpha=1, linewidths=5, edgecolors=None)

#plt.title('Nonlinear xx plotted against $\tau_{ZF}$', fontsize=30)
plt.xlabel('residual value',fontsize=25)
plt.yticks(fontsize=25)########################### at least 20 for report ##############
plt.xticks(fontsize=25)
plt.ylabel('Magnetic global shear',fontsize=25)
plt.xlim([-0.0025,0.03])
plt.tight_layout(rect=[0, 0, 5, 4])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=6, borderpad=1,labelspacing=0.8,fontsize=20)
plt.savefig('C:/Users/s162605/Documents/Studie/JAAR3/BEP/figures/residual_vs_gobalshear.pdf', format='pdf', dpi=1200)
plt.show()
